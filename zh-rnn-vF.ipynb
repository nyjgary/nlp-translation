# %%
import numpy as np 
import pandas as pd 
import torch
from data_processing import generate_vocab, process_data, create_dataloaders
from model import get_pretrained_emb, EncoderRNN, DecoderRNN, DecoderAttnRNN, EncoderDecoder, EncoderDecoderAttn
from train_eval import evaluate, train_and_eval, summarize_results, plot_single_learning_curve, load_experiment_log
import pickle as pkl 
from datetime import datetime
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# params required for generating data loaders 

SRC_LANG = 'zh'
TARG_LANG = 'en'

SRC_MAX_SENTENCE_LEN = 10
TARG_MAX_SENTENCE_LEN = 10
SRC_VOCAB_SIZE = 30000 
TARG_VOCAB_SIZE = 30000 

BATCH_SIZE = 64

# %%
# takes a long time to process, save to pickle for reimport in future 
# vocab = generate_vocab(SRC_LANG, TARG_LANG, SRC_VOCAB_SIZE, TARG_VOCAB_SIZE)
# vocab_filename = "{}-{}-vocab.p".format(SRC_LANG, TARG_LANG)
# pkl.dump(vocab, open(vocab_filename, "wb"))

# %%
# reload from pickle 
vocab_filename = "{}-{}-vocab.p".format(SRC_LANG, TARG_LANG)
vocab = pkl.load(open(vocab_filename, "rb"))
data = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, filter_long=False)
data_minibatch = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, sample_limit=BATCH_SIZE, filter_long=False) 
data_minitrain = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, sample_limit=1000, filter_long=False)

# %%
# create dataloaders 
loaders_full = create_dataloaders(data, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)
loaders_minibatch = create_dataloaders(data_minibatch, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)
loaders_minitrain = create_dataloaders(data_minitrain, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)

# %%
# model architecture params 
NETWORK_TYPE = 'rnn'
RNN_CELL_TYPE = 'gru'
NUM_LAYERS = 2 
ENC_HIDDEN_DIM = 512
DEC_HIDDEN_DIM = 2 * ENC_HIDDEN_DIM 
TEACHER_FORCING_RATIO = 1
CLIP_GRAD_MAX_NORM = 1
ENC_DROPOUT = 0 
DEC_DROPOUT = 0  
ATTENTION_TYPE = 'without'

# training params  
NUM_EPOCHS = 10 
LR = 0.00015 
OPTIMIZER = 'Adam'
LAZY_TRAIN = False

# name the model and experiment 
if NETWORK_TYPE == 'rnn': 
    EXPERIMENT_NAME = '{}-rnn-{}-attn'.format(SRC_LANG, ATTENTION_TYPE)
elif NETWORK_TYPE == 'cnn': 
    EXPERIMENT_NAME = '{}-cnn'.format(SRC_LANG)
MODEL_NAME = '{}-{}'.format(EXPERIMENT_NAME, datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

# %%
# store as dict to save to results later 
params = {'experiment_name': EXPERIMENT_NAME,'model_name': MODEL_NAME, 'src_lang': SRC_LANG, 'targ_lang': TARG_LANG, 
          'rnn_cell_type': RNN_CELL_TYPE, 'src_max_sentence_len': SRC_MAX_SENTENCE_LEN, 
          'targ_max_sentence_len': TARG_MAX_SENTENCE_LEN, 'src_vocab_size': SRC_VOCAB_SIZE, 
          'targ_vocab_size': TARG_VOCAB_SIZE, 'num_layers': NUM_LAYERS, 'enc_hidden_dim': ENC_HIDDEN_DIM, 
          'dec_hidden_dim': DEC_HIDDEN_DIM, 'teacher_forcing_ratio': TEACHER_FORCING_RATIO, 
          'clip_grad_max_norm': CLIP_GRAD_MAX_NORM, 'enc_dropout': ENC_DROPOUT, 'dec_dropout': DEC_DROPOUT, 
          'attention_type': ATTENTION_TYPE, 'batch_size': BATCH_SIZE, 'num_epochs': NUM_EPOCHS, 
          'learning_rate': LR, 'optimizer': OPTIMIZER, 'lazy_train': LAZY_TRAIN}

# %%
# define model 

encoder = EncoderRNN(rnn_cell_type=RNN_CELL_TYPE, enc_hidden_dim=ENC_HIDDEN_DIM, num_layers=NUM_LAYERS, 
                     src_max_sentence_len=SRC_MAX_SENTENCE_LEN, enc_dropout=ENC_DROPOUT, 
                     pretrained_word2vec=get_pretrained_emb(vocab[SRC_LANG]['word2vec'], vocab[SRC_LANG]['token2id']))

if ATTENTION_TYPE == 'without': 
    # without attention 
    decoder = DecoderRNN(dec_hidden_dim=DEC_HIDDEN_DIM, enc_hidden_dim=ENC_HIDDEN_DIM, num_layers=NUM_LAYERS,
                         targ_vocab_size=TARG_VOCAB_SIZE, targ_max_sentence_len=TARG_MAX_SENTENCE_LEN, 
                         pretrained_word2vec=get_pretrained_emb(vocab[TARG_LANG]['word2vec'], 
                                                                vocab[TARG_LANG]['token2id']))
    model = EncoderDecoder(encoder, decoder, vocab[TARG_LANG]['token2id']).to(device)
    
else: 
    # with attention 
    decoder = DecoderAttnRNN(rnn_cell_type=RNN_CELL_TYPE, dec_hidden_dim=DEC_HIDDEN_DIM, enc_hidden_dim=ENC_HIDDEN_DIM, 
                             num_layers=NUM_LAYERS, targ_vocab_size=TARG_VOCAB_SIZE, 
                             src_max_sentence_len=SRC_MAX_SENTENCE_LEN, targ_max_sentence_len=TARG_MAX_SENTENCE_LEN, 
                             dec_dropout=DEC_DROPOUT, attention_type=ATTENTION_TYPE,
                             pretrained_word2vec=get_pretrained_emb(vocab[TARG_LANG]['word2vec'], 
                                                                    vocab[TARG_LANG]['token2id']))
    model = EncoderDecoderAttn(encoder, decoder, vocab[TARG_LANG]['token2id']).to(device)

# %%
model, results = train_and_eval(
    model=model, loaders_full=loaders_full, loaders_minibatch=loaders_minibatch, loaders_minitrain=loaders_minitrain, 
    params=params, vocab=vocab, print_intermediate=500, save_checkpoint=True, save_to_log=True, 
    lazy_eval=True, print_attn=False, inspect_samples=3)
# Out:
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.00, Train Loss: 0.00, Val Loss: 10.19, Train BLEU: 0.00, Val BLEU: 0.02, Minutes Elapsed: 0.12
# Sampling from val predictions...
# Source: 我 生活 在 洛杉矶 <UNK> <EOS> <PAD> <PAD> <PAD> <PAD>
# Reference: i live in south central . <EOS> <PAD> <PAD>
# Model: <SOS> videodisc . . . . . . . .
#
# Source: 那双 被 <UNK> 了 的 手 属于 这家 的 父亲
# Reference: the dyed black hands are the father , while
# Model: <SOS> adversities the the the the the the the the
#
# Source: 一个 奄奄 奄奄一息 一息 的 女人 正 躺 在 地上
# Reference: a lifeless woman was lying on the ground ,
# Model: <SOS> the the the the the the the the the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.15, Train Loss: 0.00, Val Loss: 6.09, Train BLEU: 0.00, Val BLEU: 2.97, Minutes Elapsed: 11.63
# Sampling from val predictions...
# Source: 我 11 岁 那年 记得 得有 一天 早晨 醒来 听见
# Reference: when i was 11 , i remember waking up
# Model: <SOS> and &apos;s , , , , , , ,
#
# Source: 碰巧 一年 年后 我们 又 回到 了 纽约 纽约市 所以
# Reference: we happened to be back in new york exactly
# Model: <SOS> and , , , , , , , ,
#
# Source: 举 个例 例子 我 所 住 的 街区 的 肥胖
# Reference: for instance , the obesity rate in my neighborhood
# Model: <SOS> and &apos;s , , , , , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.30, Train Loss: 0.00, Val Loss: 6.00, Train BLEU: 0.00, Val BLEU: 4.09, Minutes Elapsed: 23.37
# Sampling from val predictions...
# Source: 这 就是 这个 项目 目的 全部 为了 恢复 人性 中
# Reference: that &apos;s all this project was about , about
# Model: <SOS> it &apos;s a to the . . . .
#
# Source: 用 <UNK> 冷藏 食物 也 非 长久 <UNK> 久之 计
# Reference: <UNK> way of maintaining things is not sustainable .
# Model: <SOS> it &apos;s <UNK> <UNK> <UNK> <UNK> the . the
#
# Source: 我 想 通过 一个 叫做 <UNK> 的 作品 来看 看看
# Reference: i want to look into corruption in afghanistan through
# Model: <SOS> it &apos;s a to <UNK> the . . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.45, Train Loss: 0.00, Val Loss: 5.85, Train BLEU: 0.00, Val BLEU: 2.98, Minutes Elapsed: 35.23
# Sampling from val predictions...
# Source: 我 要 回答 下人 人们 常常 问 我 的 那些
# Reference: and i &apos;m going to answer the questions that
# Model: <SOS> and &apos;s &apos;s to to to the the of
#
# Source: 一些 朝鲜 <UNK> 在 中国 到 外国 国大 大使 大使馆
# Reference: some north koreans in china seek asylum in foreign
# Model: <SOS> and , the the the , the the the
#
# Source: 每年 无数 的 朝鲜 <UNK> 在 中国 被捕 并 被
# Reference: every year , countless north koreans are caught in
# Model: <SOS> and , , the the the the the the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.60, Train Loss: 0.00, Val Loss: 5.74, Train BLEU: 0.00, Val BLEU: 2.02, Minutes Elapsed: 47.05
# Sampling from val predictions...
# Source: 那么 结果 呢 40 年 之后 1900 年 美利 美利坚
# Reference: so what happens ? in 40 years &apos; time
# Model: <SOS> so , i i the i , , ,
#
# Source: 它们 是 那么 的 优雅 查尔斯 尔斯 达尔 达尔文 曾
# Reference: they are very graceful . charles darwin said he
# Model: <SOS> so i a a , , , , ,
#
# Source: 我们 <UNK> 了 奴隶 奴隶制 奴隶制度 制度 而 此时 我
# Reference: we started talking about slavery , and really ,
# Model: <SOS> and <UNK> a to , , , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.75, Train Loss: 0.00, Val Loss: 5.66, Train BLEU: 0.00, Val BLEU: 4.62, Minutes Elapsed: 58.44
# Sampling from val predictions...
# Source: 这些 井 有 差不多 不多 有 90 多米 深 他们
# Reference: the shafts are up to 300 feet deep ,
# Model: <SOS> and , , the , the , the <EOS>
#
# Source: 27 岁 时 我 做出 一个 决定 只 基于 人们
# Reference: i decided when i was 27 years old to
# Model: <SOS> it , , to , , , , ,
#
# Source: 现在 就 像 爱 <UNK> 顿 博士 一个 科学 科学家
# Reference: now , like doc <UNK> , a scientist himself
# Model: <SOS> and , the &apos;s , the , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 0.90, Train Loss: 0.00, Val Loss: 5.53, Train BLEU: 0.00, Val BLEU: 3.17, Minutes Elapsed: 69.92
# Sampling from val predictions...
# Source: 而且 它 的 意思 是 一个 <UNK> 的 政客 <EOS>
# Reference: and what <UNK> means is &quot; a dishonest politician
# Model: <SOS> they , , the is the . &quot; .
#
# Source: 如果 听完 这些 她们 还是 说 不 不 cameron 我
# Reference: if , after this amazing list , they still
# Model: <SOS> and , have you , , , the ,
#
# Source: 这 就是 为什么 什么 在 <UNK> <UNK> 10 年后 我
# Reference: that &apos;s why , after 10 years of hiding
# Model: <SOS> this &apos;s the , &apos;s &apos;s , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.00, Train Loss: 0.00, Val Loss: 5.47, Train BLEU: 0.00, Val BLEU: 5.19, Minutes Elapsed: 77.73
# Sampling from val predictions...
# Source: 事实 事实上 这项 实验 得到 的 结论 是 如果 我们
# Reference: so actually , the conclusion from this research is
# Model: <SOS> and , , the &apos;s of that , ,
#
# Source: 我 养 了 一只 黑色 <UNK> 拉布 <UNK> 布拉 拉多
# Reference: i have that black lab , and i have
# Model: <SOS> i i a to a , , , ,
#
# Source: 据估计 估计 有 超过 4000 名儿 儿童 在 沃尔特 尔特
# Reference: it &apos;s estimated that more than 4,000 children are
# Model: <SOS> why : a a the &apos;s , , &apos;s
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.15, Train Loss: 0.00, Val Loss: 5.44, Train BLEU: 0.00, Val BLEU: 4.64, Minutes Elapsed: 89.98
# Sampling from val predictions...
# Source: 但 我 并 没有 因此 放弃 我 坚持 坚持不懈 不懈
# Reference: so i didn &apos;t give up . i continued
# Model: <SOS> but i i &apos;t know that , i i
#
# Source: 康 纳 并 不是 回到 家 向 我 宣布 嘿
# Reference: now , <UNK> did not come home one day
# Model: <SOS> and , the &apos;s , , , the ,
#
# Source: 另外 当 你们 描述 科学 原理 时 要 注意 术语
# Reference: and when you &apos;re describing your science , beware
# Model: <SOS> and , you &apos;re that to , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.30, Train Loss: 0.00, Val Loss: 5.40, Train BLEU: 0.00, Val BLEU: 4.97, Minutes Elapsed: 102.03
# Sampling from val predictions...
# Source: 你 想 过为 为什么 什么 点 <UNK> 符号 <UNK> 子弹
# Reference: have you ever wondered why they &apos;re called bullet
# Model: <SOS> you you you to <UNK> &quot; &apos;s to to
#
# Source: 从 声音 里 我们 可以 追寻 <UNK> 声 <UNK> 颤动
# Reference: from the sound , we can actually track the
# Model: <SOS> and , , , we we to to the
#
# Source: 的 一些 人 实际 实际上 在 说 这 是 她
# Reference: is code for some people for , &quot; it
# Model: <SOS> and &apos;s a the , , the , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.45, Train Loss: 0.00, Val Loss: 5.33, Train BLEU: 0.00, Val BLEU: 5.30, Minutes Elapsed: 113.46
# Sampling from val predictions...
# Source: 这 是 南 洛杉矶 笑 <EOS> <PAD> <PAD> <PAD> <PAD>
# Reference: this is south los angeles . <EOS> <PAD> <PAD>
# Model: <SOS> that &apos;s a . . <EOS> <EOS> <EOS> <EOS>
#
# Source: 我们 总是 没有 <UNK> 勇气 谈论 死亡 甚至 没有 <UNK>
# Reference: death is something that we &apos;re often discouraged to
# Model: <SOS> we we we we we &apos;re to to .
#
# Source: 人们 把 收集 到 的 照片 送到 那个 <UNK> <UNK>
# Reference: this is where people were handing them in ,
# Model: <SOS> and , the of of the . . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.60, Train Loss: 0.00, Val Loss: 5.30, Train BLEU: 0.00, Val BLEU: 3.99, Minutes Elapsed: 125.05
# Sampling from val predictions...
# Source: 我们 需要 你们 每 一个 个人 人理 理解 家庭 家庭暴力
# Reference: we need every one of you to understand the
# Model: <SOS> we we to to of of , , ,
#
# Source: 所以 我 必须 找到 一个 解决 解决问题 问题 的 方法
# Reference: so i had to find a way of solving
# Model: <SOS> so i i to to a , , i
#
# Source: 回到 我 的 问题 为什么 什么 我 要 留下 留下来
# Reference: back to my question : why did i stay
# Model: <SOS> and i i , , i i i i
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.75, Train Loss: 0.00, Val Loss: 5.27, Train BLEU: 0.00, Val BLEU: 5.56, Minutes Elapsed: 136.60
# Sampling from val predictions...
# Source: 议员 甚至 前来 拜访 表达 了 他 有 多么 赞赏
# Reference: my <UNK> even called in and said how they
# Model: <SOS> and of , , , , , , &quot;
#
# Source: 尽管 这 只是 一个 19 世纪 的 报纸 编辑 给出
# Reference: although there was a 19th-century newspaper editor who defined
# Model: <SOS> and , the a of of the , a
#
# Source: 我 将 为 大家 展示 我 模特 从业 十年 的
# Reference: i will demonstrate for you now 10 years of
# Model: <SOS> i i a to a , , i ago
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 1.90, Train Loss: 0.00, Val Loss: 5.22, Train BLEU: 0.00, Val BLEU: 5.24, Minutes Elapsed: 148.72
# Sampling from val predictions...
# Source: 我们 在 这段 路上 取 了 很多 多样 样品 在
# Reference: so we took a lot of samples from this
# Model: <SOS> we we we to of of of , the
#
# Source: 帮助 幸存 幸存者 重新 找回 美好 可爱 的 自己 重新
# Reference: recast survivors as wonderful , lovable people with full
# Model: <SOS> the , the the , , , , <EOS>
#
# Source: 非法 <UNK> 性交 性交易 交易 是 我们 在 听到 奴役
# Reference: sex trafficking is what we often think of when
# Model: <SOS> and , , us , &apos;re to to we
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.00, Train Loss: 0.00, Val Loss: 5.21, Train BLEU: 0.00, Val BLEU: 5.65, Minutes Elapsed: 156.61
# Sampling from val predictions...
# Source: 让 我们 对 邻居 有 了 全新 的 启发 心智
# Reference: it &apos;s about understanding our neighbors in new and
# Model: <SOS> let &apos;s be to to we . the .
#
# Source: 我们 正在 尽力 让 他们 了解 到 <UNK> 的 益处
# Reference: we &apos;re talking to them about appreciating <UNK> ,
# Model: <SOS> we we to to they , , , ,
#
# Source: 我 原本 以为 世界 上 只有 我 一个 个人 会
# Reference: i would have told you myself that i was
# Model: <SOS> i i &apos;t to to &quot; , i i
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.15, Train Loss: 0.00, Val Loss: 5.23, Train BLEU: 0.00, Val BLEU: 5.39, Minutes Elapsed: 168.55
# Sampling from val predictions...
# Source: <UNK> 我 的 下 一项 项发明 发明 是 我 想
# Reference: my next invention is , i want to make
# Model: <SOS> &quot; : , , , , i , talk
#
# Source: 此时 此时此刻 此刻 你 可能 在 想 哇 这 才
# Reference: right now , maybe you &apos;re thinking , &quot;
# Model: <SOS> and fact you you you you that to you
#
# Source: 可是 如果 我们 的 科学 科学家 学家 和 工程 工程师
# Reference: but these great conversations can &apos;t occur if our
# Model: <SOS> and if we us that we us that the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.30, Train Loss: 0.00, Val Loss: 5.21, Train BLEU: 0.00, Val BLEU: 6.43, Minutes Elapsed: 180.15
# Sampling from val predictions...
# Source: 找到 一种 新科 科技 取而代之 才 是 发展 的 <UNK>
# Reference: the idea of finding a different technology had absolutely
# Model: <SOS> and &apos;s is is is is is . <EOS>
#
# Source: 几千 几千人 成为 <UNK> 餐馆 <UNK> 家庭 <UNK> 还 不止
# Reference: tens of hundreds of people are enslaved in agriculture
# Model: <SOS> the , , , , , the , the
#
# Source: 她 向 我 形容 5 岁 的 时候 她 站
# Reference: and she describes to me the feeling she felt
# Model: <SOS> and , , , , , the , the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.45, Train Loss: 0.00, Val Loss: 5.15, Train BLEU: 0.00, Val BLEU: 5.89, Minutes Elapsed: 192.25
# Sampling from val predictions...
# Source: 那么 这些 以 语音 为 基础 的 测试 他们 会
# Reference: so these <UNK> tests , how do they stack
# Model: <SOS> and , &apos;s are , the , the do
#
# Source: 但 我 并 没有 因此 放弃 我 坚持 坚持不懈 不懈
# Reference: so i didn &apos;t give up . i continued
# Model: <SOS> but i &apos;m &apos;t know to , because i
#
# Source: 噪音 也 会 消失 在 这些 毛孔 里 <EOS> <PAD>
# Reference: also the noise will disappear in these pores .
# Model: <SOS> and , , is that do . . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.60, Train Loss: 0.00, Val Loss: 5.12, Train BLEU: 0.00, Val BLEU: 4.76, Minutes Elapsed: 204.55
# Sampling from val predictions...
# Source: 尽管 适应 韩国 的 生活 并 不是 易事 但是 我
# Reference: even though adjusting to life in south korea was
# Model: <SOS> and the the the , , , , but
#
# Source: 这 可不 可不是 不是 科幻 <UNK> 我们 真正 的 做出
# Reference: and it &apos;s not science fiction . we have
# Model: <SOS> and &apos;s &apos;s a a , but but &apos;s
#
# Source: 于是 有 了 第二 第二个 二个 办法 利用 稻草 <UNK>
# Reference: and a second idea i got was to use
# Model: <SOS> so it &apos;s of , the to to a
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.75, Train Loss: 0.00, Val Loss: 5.11, Train BLEU: 0.00, Val BLEU: 6.41, Minutes Elapsed: 216.61
# Sampling from val predictions...
# Source: 虐待 只能 活 在 沉默 中 <EOS> <PAD> <PAD> <PAD>
# Reference: abuse thrives only in silence . <EOS> <PAD> <PAD>
# Model: <SOS> the , : . <EOS> . <EOS> <EOS> <EOS>
#
# Source: 我 可以 感觉 到来 来来 <UNK> 来往 往往 <UNK> <UNK>
# Reference: i can feel the brush of sweaty bodies passing
# Model: <SOS> i can to a <UNK> of the . .
#
# Source: 我 的 祖父 在 他 的 年代 是 位非 非凡
# Reference: my grandfather was an extraordinary man for his time
# Model: <SOS> my my was , , , , he ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 2.90, Train Loss: 0.00, Val Loss: 5.08, Train BLEU: 0.00, Val BLEU: 5.77, Minutes Elapsed: 228.29
# Sampling from val predictions...
# Source: 这些 人 完全 无法 逃跑 当 我们 面对 如此 艰难
# Reference: these people have no escape at all , and
# Model: <SOS> these are are &apos;t , , and , ,
#
# Source: 这 是 南 洛杉矶 笑 <EOS> <PAD> <PAD> <PAD> <PAD>
# Reference: this is south los angeles . <EOS> <PAD> <PAD>
# Model: <SOS> this &apos;s a . . . <EOS> <EOS> <EOS>
#
# Source: 我们 时常 拍照 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: we take photos constantly . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> we we to . <EOS> . <EOS> <EOS> .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.00, Train Loss: 0.00, Val Loss: 5.09, Train BLEU: 0.00, Val BLEU: 6.28, Minutes Elapsed: 236.41
# Sampling from val predictions...
# Source: 我们 的 <UNK> 号码 能 接通 地球 上 7 亿
# Reference: we have local numbers accessible to three quarters of
# Model: <SOS> we we a <UNK> , the , , ,
#
# Source: 在 初次 交往 中 康 纳 做 的 最 聪明
# Reference: one of the smartest things <UNK> did , from
# Model: <SOS> in the the things that in the the the
#
# Source: 我 确实 实有 太多 从没 机会 穿 的 8 英寸
# Reference: i do have too many <UNK> heels which i
# Model: <SOS> i i &apos;t to to to people , the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.15, Train Loss: 0.00, Val Loss: 5.13, Train BLEU: 0.00, Val BLEU: 6.02, Minutes Elapsed: 248.29
# Sampling from val predictions...
# Source: 我 养 了 一只 黑色 <UNK> 拉布 <UNK> 布拉 拉多
# Reference: i have that black lab , and i have
# Model: <SOS> i i to to to , , , ,
#
# Source: 奇怪 奇怪的是 那些 地方 我 都 去过 <EOS> <PAD> <PAD>
# Reference: oddly , i had been to many of these
# Model: <SOS> i , , , to . . . .
#
# Source: 你 又 想 从 这些 采样 中 得出 什么 呢
# Reference: what are you going to get out of those
# Model: <SOS> you you you going to do about to the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.30, Train Loss: 0.00, Val Loss: 5.10, Train BLEU: 0.00, Val BLEU: 6.99, Minutes Elapsed: 260.23
# Sampling from val predictions...
# Source: 有 一天 我 最糟 糟糕 的 <UNK> 成真 了 我
# Reference: one day , my worst nightmare came true ,
# Model: <SOS> and , the i i , , i ,
#
# Source: <UNK> 身上 上体 体现 了 一种 可能 可能性 <EOS> <PAD>
# Reference: kofi is the embodiment of possibility . <EOS> <PAD>
# Model: <SOS> <UNK> <UNK> : . of the . <EOS> &apos;s
#
# Source: 我 在 加纳 地下 50 米 深 的 一个 非法
# Reference: i &apos;m 150 feet down an illegal mine shaft
# Model: <SOS> i i a to , the the . in
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.45, Train Loss: 0.00, Val Loss: 5.05, Train BLEU: 0.00, Val BLEU: 6.65, Minutes Elapsed: 271.98
# Sampling from val predictions...
# Source: 我 这个 年龄 的 女性 中 高中 高中毕业 毕业 的
# Reference: fewer than six percent of women my age have
# Model: <SOS> and i of i i i i i is
#
# Source: 其中 一个 孩子 的 学校 被 海啸 冲击 到 了
# Reference: one of them got caught up in the water
# Model: <SOS> and the the things the the the the and
#
# Source: 我 当时 非常 害怕 感觉 我 的 心 都 快
# Reference: i was so scared , i thought my heart
# Model: <SOS> i i to , , i i , i
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.60, Train Loss: 0.00, Val Loss: 5.04, Train BLEU: 0.00, Val BLEU: 6.05, Minutes Elapsed: 283.69
# Sampling from val predictions...
# Source: 当个 拿 <UNK> 的 流氓 怎么 怎么样 <EOS> <PAD> <PAD>
# Reference: get gangsta with your shovel , okay ? <EOS>
# Model: <SOS> and , , the . . <EOS> ? <EOS>
#
# Source: 音乐 我们 将要 发射 这些 光子 子弹 它们 将要 撞击
# Reference: we &apos;re going to fire those bullets of light
# Model: <SOS> and we to to do this , , and
#
# Source: 让 <UNK> 成为 你 选择 的 武器 吧 <EOS> <PAD>
# Reference: and let that be your weapon of choice .
# Model: <SOS> and you you go you to ? <EOS> ?
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.75, Train Loss: 0.00, Val Loss: 5.03, Train BLEU: 0.00, Val BLEU: 6.97, Minutes Elapsed: 295.80
# Sampling from val predictions...
# Source: 其中 一个 孩子 的 学校 被 海啸 冲击 到 了
# Reference: one of them got caught up in the water
# Model: <SOS> the of the things the , the the ,
#
# Source: 我 所 成长 的 国家 被 几十 几十年 十年 的
# Reference: i was raised in a country that has been
# Model: <SOS> i i a to the , of a was
#
# Source: 整个 过程 非常 费时 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: it was very time-consuming . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> the &apos;s &apos;t . . <EOS> <EOS> <EOS> <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 3.90, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 6.80, Minutes Elapsed: 307.36
# Sampling from val predictions...
# Source: 这个 是 健康 状态 下 的 某人 在 发声 我们
# Reference: now , this is healthy and this is somebody
# Model: <SOS> this is is is a a , , ,
#
# Source: 每 一个 病例 的 情况 都 是 特殊 的 所以
# Reference: it manifests in each individual differently , hence why
# Model: <SOS> every &apos;s a a , of , , ,
#
# Source: 你 能 做 什么 你 能 生产 产出 出来 吗
# Reference: what can you do ? can you make it
# Model: <SOS> you you you do ? ? ? do ?
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.00, Train Loss: 0.00, Val Loss: 5.02, Train BLEU: 0.00, Val BLEU: 6.83, Minutes Elapsed: 315.21
# Sampling from val predictions...
# Source: 我 11 岁 那年 记得 得有 一天 早晨 醒来 听见
# Reference: when i was 11 , i remember waking up
# Model: <SOS> i i was in , the was a the
#
# Source: 我们 在 巴士 上 的 旅途 有 一周 之久 好几
# Reference: the journey by bus took one week , and
# Model: <SOS> we we of we we a in the the
#
# Source: 当然 当地 当地人 对此 表示 毫无 无兴趣 兴趣 所以 我们
# Reference: and of course the local people had absolutely no
# Model: <SOS> and course course , the is is &apos;t ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.15, Train Loss: 0.00, Val Loss: 5.07, Train BLEU: 0.00, Val BLEU: 6.30, Minutes Elapsed: 327.03
# Sampling from val predictions...
# Source: 今天 我 做到 了 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: and here i am today . <EOS> <PAD> <PAD>
# Model: <SOS> i i i i . . <EOS> . <EOS>
#
# Source: 绿地 组织 又 开始 安置 也许 是 20 个 花园
# Reference: so green grounds has gone on to plant maybe
# Model: <SOS> the , &apos;s is the be , , ,
#
# Source: 他们 都 是 <UNK> 暴力 的 受害 受害者 <EOS> <PAD>
# Reference: all of them are victim to injury , illness
# Model: <SOS> they are them are the . . . <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.30, Train Loss: 0.00, Val Loss: 5.04, Train BLEU: 0.00, Val BLEU: 7.42, Minutes Elapsed: 338.70
# Sampling from val predictions...
# Source: 这个 秘密 就是 我 曾经 被 我 认为 是 我
# Reference: my secret was that i had this gun loaded
# Model: <SOS> and the is me me me to , ,
#
# Source: 尽管 他用 <UNK> 的 枪 指着 我 的 头 把
# Reference: even though he held those loaded guns to my
# Model: <SOS> and was the <UNK> a , , the i
#
# Source: 我们 会 因 芭蕾 芭蕾舞 大师 和 <UNK> <UNK> 舞蹈
# Reference: we delight at ballet virtuosos and tap dancers you
# Model: <SOS> we we to , , , the <UNK> ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.45, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 7.15, Minutes Elapsed: 350.09
# Sampling from val predictions...
# Source: 不过 做 这些 事儿 你 可能 会 进 监狱 它们
# Reference: but doing these things , they can get you
# Model: <SOS> but , can this , you you you ,
#
# Source: 我 觉得 人们 太 容易 被 日复一日 一日 的 琐碎
# Reference: i feel like it &apos;s easy to get caught
# Model: <SOS> i think that of have a to be that
#
# Source: 你 可以 看到 这个 电灯 电灯泡 灯泡 是 <UNK> 的
# Reference: as you can see , the bulbs face outside
# Model: <SOS> you you can see , this &apos;s is the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.60, Train Loss: 0.00, Val Loss: 4.99, Train BLEU: 0.00, Val BLEU: 6.34, Minutes Elapsed: 361.59
# Sampling from val predictions...
# Source: 那些 大石 <UNK> 石板 比 搬运 石板 的 孩子 还要
# Reference: the big sheets of slate were heavier than the
# Model: <SOS> it , of of the , the , and
#
# Source: 我们 不一 一定 定能 常常 碰到 我们 的 邻居 所以
# Reference: we don &apos;t bump into every neighbor , so
# Model: <SOS> we we &apos;t have to , , , our
#
# Source: <UNK> 身上 上体 体现 了 一种 可能 可能性 <EOS> <PAD>
# Reference: kofi is the embodiment of possibility . <EOS> <PAD>
# Model: <SOS> <UNK> : : , of <EOS> . <EOS> &apos;s
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.75, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 7.25, Minutes Elapsed: 373.06
# Sampling from val predictions...
# Source: 像 我 一样 她们 也 有 很大 的 梦想 <EOS>
# Reference: like me , they are dreaming big . <EOS>
# Model: <SOS> and me i i &apos;s a to <EOS> .
#
# Source: 掌声 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> thank , . much you <EOS> . <EOS> <EOS>
#
# Source: 我 想 通过 一个 叫做 <UNK> 的 作品 来看 看看
# Reference: i want to look into corruption in afghanistan through
# Model: <SOS> i think to show a a <UNK> a ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 4.90, Train Loss: 0.00, Val Loss: 4.97, Train BLEU: 0.00, Val BLEU: 7.09, Minutes Elapsed: 384.72
# Sampling from val predictions...
# Source: 照片 是 一个 提醒 和 <UNK> 提醒 我们 一些 人
# Reference: a photo is a reminder of someone or something
# Model: <SOS> so is is a , , a , ,
#
# Source: 不过 随着 对话 的 展开 我 的 经历 就 如
# Reference: but as these conversations unfolded , i experienced what
# Model: <SOS> but the , , , i i i to
#
# Source: 谢谢 各位 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> it &apos;s . much you <EOS> . <EOS> <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.00, Train Loss: 0.00, Val Loss: 4.99, Train BLEU: 0.00, Val BLEU: 7.22, Minutes Elapsed: 392.47
# Sampling from val predictions...
# Source: 上面 写道 当 你 读到 这 封信 时 我家 的
# Reference: it read , &quot; when you read this ,
# Model: <SOS> and , &apos;t you you you you the the
#
# Source: 尽管 他用 <UNK> 的 枪 指着 我 的 头 把
# Reference: even though he held those loaded guns to my
# Model: <SOS> and a the <UNK> to and and the and
#
# Source: 五年 年前 我 曾 有 过 一个 有如 漫游 爱丽丝
# Reference: five years ago , i experienced a bit of
# Model: <SOS> and years ago , i was a a to
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.15, Train Loss: 0.00, Val Loss: 5.04, Train BLEU: 0.00, Val BLEU: 6.85, Minutes Elapsed: 404.27
# Sampling from val predictions...
# Source: 这个 我 曾经 最爱 的 人 用 枪 指着 我
# Reference: the man who i loved more than anybody on
# Model: <SOS> and i i me me to -- , ,
#
# Source: 第一 第一个 一个 问题 是 你 是 怎么 成为 模特
# Reference: so the first question is , how do you
# Model: <SOS> the first first question is , you you you
#
# Source: 虽然 我 也 时常 憧憬 外面 的 世界 我 以为
# Reference: although i often wondered about the outside world ,
# Model: <SOS> i i i going to i , of i
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.30, Train Loss: 0.00, Val Loss: 5.01, Train BLEU: 0.00, Val BLEU: 7.84, Minutes Elapsed: 416.45
# Sampling from val predictions...
# Source: 我 为了 让 我 的 家人 获得 自由 <UNK> 所能
# Reference: i did everything to get my family to freedom
# Model: <SOS> i i to make my my my to my
#
# Source: 你 必须 得到 诊所 去 而且 花费 相当 相当 大
# Reference: you have to go to the clinic to do
# Model: <SOS> you you to get the to the , the
#
# Source: 所以 当 那个 中国 警官 快 检查 查到 我家 家人
# Reference: as the chinese officer approached my family , i
# Model: <SOS> so when as , , the , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.45, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.11, Minutes Elapsed: 428.05
# Sampling from val predictions...
# Source: 你 会 好奇 是否 会 有效 <EOS> <PAD> <PAD> <PAD>
# Reference: and now you &apos;re of course curious if it
# Model: <SOS> you you you you to to , you <EOS>
#
# Source: 停电 也 变得 越来 越来越 频繁 到 了 晚上 我
# Reference: power <UNK> also became more and more frequent ,
# Model: <SOS> and i the the , to years and me
#
# Source: 那个 善良 的 陌生 陌生人 生人 象征 着 我 以及
# Reference: the kind stranger symbolized new hope for me and
# Model: <SOS> and the of the me , , i ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.60, Train Loss: 0.00, Val Loss: 4.97, Train BLEU: 0.00, Val BLEU: 6.33, Minutes Elapsed: 439.97
# Sampling from val predictions...
# Source: 我 也 想 告诉 各位 我 有幸 能够 在 10
# Reference: i &apos;d also note that i &apos;m quite privileged
# Model: <SOS> i i to to to i i going to
#
# Source: 他 只是 压力 太大 了 婚礼 的 筹备 和 我家
# Reference: he had just been really stressed out by the
# Model: <SOS> he was a a a to to the the
#
# Source: 它们 是 我们 <UNK> 时间 的 方式 记住 10 月
# Reference: they &apos;re also ways for us to freeze time
# Model: <SOS> they are the , , we , the the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.75, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.26, Minutes Elapsed: 451.14
# Sampling from val predictions...
# Source: 你 不必 非得 改变 你 的 观点 才能 清楚 地
# Reference: you can clearly communicate your science without compromising the
# Model: <SOS> you you &apos;t your your your , and to
#
# Source: 这些 光会 反射 射进 进入 房间 一些 会 返回 回到
# Reference: it &apos;s going to bounce , go inside the
# Model: <SOS> and , be to be a , , ,
#
# Source: <UNK> 期间 我 又 被 打 了 两次 <EOS> <PAD>
# Reference: it happened twice more on the <UNK> . <EOS>
# Model: <SOS> &quot; : my i i i . . <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 5.90, Train Loss: 0.00, Val Loss: 4.97, Train BLEU: 0.00, Val BLEU: 6.89, Minutes Elapsed: 462.45
# Sampling from val predictions...
# Source: 对于 阿富汗 我 意识 到 这 是 西方 方国 国家
# Reference: what i &apos;ve come to realize about afghanistan ,
# Model: <SOS> and , &apos;m to is is is is is
#
# Source: 所以 如果 摄影 摄影师 就 在 这里 灯光 就 在
# Reference: so if the photographer is right there and the
# Model: <SOS> so if , look is to in the and
#
# Source: 对 我 来说 这 是 人们 问 过 的 最
# Reference: to me , this is the saddest and most
# Model: <SOS> and , , this is a a of of
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.00, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.23, Minutes Elapsed: 469.99
# Sampling from val predictions...
# Source: 但是 这 一次 我 要 去 挖掘 那些 见 不得
# Reference: but this time , i would see the skeletons
# Model: <SOS> but that , i i i , to the
#
# Source: 如今 我 22 岁 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: today i am 22 . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> i : i . . . <EOS> <EOS> <EOS>
#
# Source: 有 足够 的 空间 去 种植 <UNK> <UNK> 两千 两千五百
# Reference: that &apos;s enough space to plant <UNK> million tomato
# Model: <SOS> and &apos;s a to to the , , <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.15, Train Loss: 0.00, Val Loss: 5.03, Train BLEU: 0.00, Val BLEU: 6.68, Minutes Elapsed: 481.89
# Sampling from val predictions...
# Source: 有时 有时候 时候 一些 年长 的 女士 从未 从未见过 扫描
# Reference: the older ladies sometimes hadn &apos;t seen a scanner
# Model: <SOS> sometimes sometimes of , the , , , the
#
# Source: 话 说 我 是 学 应用 数学 的 对于 每
# Reference: so , well , i do applied math ,
# Model: <SOS> and , i i i &apos;m , to the
#
# Source: 他 很 害怕 会 掉 到 水里 <EOS> <PAD> <PAD>
# Reference: he was petrified he would be knocked in the
# Model: <SOS> he he , to &quot; the the . <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.30, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 7.79, Minutes Elapsed: 490.26
# Sampling from val predictions...
# Source: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> it you . much . <EOS> . <EOS> <EOS>
#
# Source: 这 是 一个 意外 而 他 以后 不会 再 伤害
# Reference: it was an isolated incident , and he was
# Model: <SOS> this is a a , , he he was
#
# Source: <UNK> 我 的 下 一项 项发明 发明 是 我 想
# Reference: my next invention is , i want to make
# Model: <SOS> and , is is i i i a be
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.45, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.11, Minutes Elapsed: 498.45
# Sampling from val predictions...
# Source: 种 一棵 一棵树 能够 收到 一千 甚至 一万 <UNK> 种子
# Reference: growing one plant will give you 1,000 , 10,000
# Model: <SOS> it &apos;s , , , , a and to
#
# Source: 我 搬到 了 纽约 开始 了 自己 第一 第一份 一份
# Reference: i had moved to new york city for my
# Model: <SOS> i i a first the first , , ,
#
# Source: 在 我 交 了 罚金 金和 贿赂 用 的 钱
# Reference: after i paid the fine and bribe , my
# Model: <SOS> i i , a a , , , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.60, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 6.27, Minutes Elapsed: 506.71
# Sampling from val predictions...
# Source: 它 有 很 好 的 时间 分辨 分辨率 辨率 并且
# Reference: it has very good time resolution , and it
# Model: <SOS> it &apos;s a , , , and , ,
#
# Source: 每当 你 看到 <UNK> 就 像 这 只 首先 浮现
# Reference: when you see a <UNK> like this , the
# Model: <SOS> and you go at , , , , ,
#
# Source: 第一 你 要 给予 他们 保密 的 承诺 <EOS> <PAD>
# Reference: first , you have to offer them <UNK> .
# Model: <SOS> you you you can to to them . <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.75, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.74, Minutes Elapsed: 515.08
# Sampling from val predictions...
# Source: 在 我们 家族 凡是 六 到 九岁 的 男孩 都
# Reference: so a boy , from six to nine years
# Model: <SOS> in the we of us <UNK> , we ,
#
# Source: 同时 沥青 <UNK> 会 产生 很大 噪音 <EOS> <PAD> <PAD>
# Reference: also , asphalt can create a lot of noise
# Model: <SOS> and the the the the . . . .
#
# Source: 众议 众议院 议院 不想 让 华盛 华盛顿 沉醉 <UNK> 权力
# Reference: the house of representatives didn &apos;t want washington to
# Model: <SOS> the : academy not , the take to be
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 6.90, Train Loss: 0.00, Val Loss: 4.96, Train BLEU: 0.00, Val BLEU: 6.94, Minutes Elapsed: 523.47
# Sampling from val predictions...
# Source: 但是 当 我 回到 阿富汗 看见 我 的 学生 以及
# Reference: but when i am back in afghanistan , when
# Model: <SOS> but when i was my , the , i
#
# Source: 现在 我 的 方法 已经 被 肯尼 肯尼亚 尼亚 的
# Reference: and my idea is also being used now all
# Model: <SOS> now , i , to to to to the
#
# Source: <UNK> 今年 22 岁 又 高 又 帅 <EOS> <PAD>
# Reference: <UNK> is 22 , tall and very handsome .
# Model: <SOS> <UNK> , : years old , <EOS> . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.00, Train Loss: 0.00, Val Loss: 4.99, Train BLEU: 0.00, Val BLEU: 7.44, Minutes Elapsed: 529.08
# Sampling from val predictions...
# Source: 那个 善良 的 陌生 陌生人 生人 象征 着 我 以及
# Reference: the kind stranger symbolized new hope for me and
# Model: <SOS> and the of the , , , i ,
#
# Source: 内燃 内燃机 燃机 的 燃料 总 有 耗尽 的 一天
# Reference: the internal combustion engine is not sustainable . <EOS>
# Model: <SOS> the <UNK> of of the the . . .
#
# Source: 不仅 因为 它 听起 起来 很 不错 <EOS> <PAD> <PAD>
# Reference: just because it sounds so good . <EOS> <PAD>
# Model: <SOS> it it it &apos;s &apos;t . . <EOS> &apos;s
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.15, Train Loss: 0.00, Val Loss: 5.04, Train BLEU: 0.00, Val BLEU: 6.90, Minutes Elapsed: 537.43
# Sampling from val predictions...
# Source: 来 让 他 自己 保持 安全 安全感 <EOS> <PAD> <PAD>
# Reference: he needed them to feel protected . <EOS> <PAD>
# Model: <SOS> and , , be be the . <EOS> &apos;s
#
# Source: 这个 我 曾经 最爱 的 人 用 枪 指着 我
# Reference: the man who i loved more than anybody on
# Model: <SOS> and i i me me to and , ,
#
# Source: 他们 会 把 尸体 上 的 肉 吃 的 <UNK>
# Reference: they clean up carcasses right to the bone .
# Model: <SOS> they they to the the the to , of
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.45, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 7.37, Minutes Elapsed: 554.18
# Sampling from val predictions...
# Source: 没有 任何 比较 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: they have nothing to compare it to . <EOS>
# Model: <SOS> no &apos;s &apos;t . . . . <EOS> .
#
# Source: 谢谢 大家 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you very much . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> thank you . <EOS> . <EOS> <EOS> <EOS> .
#
# Source: 话 说 我 是 学 应用 数学 的 对于 每
# Reference: so , well , i do applied math ,
# Model: <SOS> i , i &apos;m i &apos;m , , the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.60, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 6.48, Minutes Elapsed: 562.57
# Sampling from val predictions...
# Source: 我们 西方 西方人 方人 是 帝国 帝国主义 <UNK> 国主 主义
# Reference: we western people are <UNK> , <UNK> missionaries ,
# Model: <SOS> we we a a the a <EOS> , <EOS>
#
# Source: 这个 小男孩 男孩 8 岁 大 <EOS> <PAD> <PAD> <PAD>
# Reference: this young child is eight years old . <EOS>
# Model: <SOS> and &apos;s a . . years . . <EOS>
#
# Source: 我们 种 的 西红柿 漂亮 极了 在意 意大利 大利 一个
# Reference: we had these magnificent tomatoes . in italy ,
# Model: <SOS> we we a of , , and , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.75, Train Loss: 0.00, Val Loss: 5.01, Train BLEU: 0.00, Val BLEU: 7.84, Minutes Elapsed: 570.94
# Sampling from val predictions...
# Source: 谢谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> thank you . <EOS> you <EOS> <EOS> <EOS> <EOS>
#
# Source: 而 如今 我 已经 是 一名 自豪 的 <UNK> 学院
# Reference: instead , i stand here a proud graduate of
# Model: <SOS> and the i i to a a of a
#
# Source: 我 没想 想着 免费 因为 免费 是 不能 持续 的
# Reference: i &apos;m not talking about no free shit ,
# Model: <SOS> i &apos;m &apos;t sure because because because because because
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 7.90, Train Loss: 0.00, Val Loss: 4.98, Train BLEU: 0.00, Val BLEU: 7.33, Minutes Elapsed: 579.32
# Sampling from val predictions...
# Source: 我 要 介绍 你们 认识 <UNK> <EOS> <PAD> <PAD> <PAD>
# Reference: i want to introduce you to kofi . <EOS>
# Model: <SOS> i &apos;m going to you . examples . <EOS>
#
# Source: 所以 不管 是 看到 拐角 还是 为 下一代 一代 制造
# Reference: so whether it &apos;s for photography around corners ,
# Model: <SOS> so the is is is , , the and
#
# Source: 而且 它 的 意思 是 一个 <UNK> 的 政客 <EOS>
# Reference: and what <UNK> means is &quot; a dishonest politician
# Model: <SOS> and &apos;s &apos;s of was is a &quot; of
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.00, Train Loss: 0.00, Val Loss: 5.02, Train BLEU: 0.00, Val BLEU: 7.59, Minutes Elapsed: 584.93
# Sampling from val predictions...
# Source: 我 在 为 这次 演讲 做 调查 时 发现 现在
# Reference: when i was researching this talk , i found
# Model: <SOS> i i was this this this , , the
#
# Source: 这里 的 窍门 就是 使用 简单 <UNK> 的 句子 让
# Reference: and the trick here is to use a single
# Model: <SOS> the the &apos;s of to that you that <UNK>
#
# Source: 但 这些 波纹 应该 向 我们 移动 <EOS> <PAD> <PAD>
# Reference: the ripples should be moving towards us . <EOS>
# Model: <SOS> but there is not us us us . <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.15, Train Loss: 0.00, Val Loss: 5.05, Train BLEU: 0.00, Val BLEU: 6.85, Minutes Elapsed: 593.29
# Sampling from val predictions...
# Source: 我们 用 的 就是 清洁 <UNK> 用 的 钢丝 <UNK>
# Reference: so what we can do is use steel wool
# Model: <SOS> we we we &apos;re is is is we the
#
# Source: 我 没想 想着 免费 因为 免费 是 不能 持续 的
# Reference: i &apos;m not talking about no free shit ,
# Model: <SOS> i i &apos;t to to because because because because
#
# Source: 我 觉得 人们 太 容易 被 日复一日 一日 的 琐碎
# Reference: i feel like it &apos;s easy to get caught
# Model: <SOS> i i that to have a to be that
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.30, Train Loss: 0.00, Val Loss: 5.05, Train BLEU: 0.00, Val BLEU: 7.66, Minutes Elapsed: 601.65
# Sampling from val predictions...
# Source: 我 三岁 的 时候 弟弟 出生 了 我 非常 常兴
# Reference: i was just three years old when my brother
# Model: <SOS> i i my years years old and i was
#
# Source: <UNK> <UNK> 之下 砸 石场 的 男人 个个 健壮 但
# Reference: at first glance , the pounding site seems full
# Model: <SOS> <UNK> <UNK> <UNK> , the &apos;s of in the
#
# Source: 然后 你 要为 他们 提供 专注 而 热情 的 服务
# Reference: then you have to offer them absolute , dedicated
# Model: <SOS> and you &apos;re them , the a to and
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.45, Train Loss: 0.00, Val Loss: 5.02, Train BLEU: 0.00, Val BLEU: 7.47, Minutes Elapsed: 610.02
# Sampling from val predictions...
# Source: 这些 事 就 发生 生在 我们 身边 我们 只是 不知
# Reference: it &apos;s all around us . we just don
# Model: <SOS> and are a . . . and &apos;s going
#
# Source: 今天 我 只要 要求 一件 事 <EOS> <PAD> <PAD> <PAD>
# Reference: today i have just one request . <EOS> <PAD>
# Model: <SOS> and i i going go to to <EOS> <EOS>
#
# Source: 现在 如果 你 把 这个 个子 子弹 这些 光子 打入
# Reference: now , if you take that bullet and take
# Model: <SOS> now , if you look at look , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.60, Train Loss: 0.00, Val Loss: 5.03, Train BLEU: 0.00, Val BLEU: 6.89, Minutes Elapsed: 618.37
# Sampling from val predictions...
# Source: 因为 国会 国会议员 会议 会议员 议员 们 不能 保持 自然
# Reference: because mps do not keep the environment clean .
# Model: <SOS> because not &apos;s &apos;t really to , , they
#
# Source: 我 想 跟 一名 圣战 分子 生活 一天 他 穿着
# Reference: i want to spend a day in the life
# Model: <SOS> i i to start you few of i ,
#
# Source: 这 是 我们 俩 人 唯一 的 受教 教育 方式
# Reference: it was the only way we both could be
# Model: <SOS> and is the of of we we in the
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.75, Train Loss: 0.00, Val Loss: 5.03, Train BLEU: 0.00, Val BLEU: 7.69, Minutes Elapsed: 626.76
# Sampling from val predictions...
# Source: 这个 项目 也 为 我们 这些 修 图 师 带来
# Reference: the project &apos;s also made a big difference in
# Model: <SOS> this this is us to us us to us
#
# Source: 培养 出下 一个 乔治 <UNK> 华盛 华盛顿 呢 <EOS> <PAD>
# Reference: we might produce the next george washington <UNK> .
# Model: <SOS> there &apos;s to have , , . . <EOS>
#
# Source: <UNK> 会议 主持 总统 他们 没有 创造 这个 个头 头衔
# Reference: president . they didn &apos;t invent the title .
# Model: <SOS> the , that , &apos;t have to . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 8.90, Train Loss: 0.00, Val Loss: 5.00, Train BLEU: 0.00, Val BLEU: 7.54, Minutes Elapsed: 635.17
# Sampling from val predictions...
# Source: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> <EOS> . . <EOS> . <EOS> <EOS> <EOS> <EOS>
#
# Source: 我 在 一个 <UNK> 遇见 了 康 纳 那时 是
# Reference: i met <UNK> on a cold , rainy january
# Model: <SOS> i was a in the , of , i
#
# Source: 你 能 做 什么 你 能 生产 产出 出来 吗
# Reference: what can you do ? can you make it
# Model: <SOS> can you you do to ? do do to
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.00, Train Loss: 0.00, Val Loss: 5.05, Train BLEU: 0.00, Val BLEU: 7.52, Minutes Elapsed: 640.80
# Sampling from val predictions...
# Source: 其中 特别 是 一张 照 了 各个 年龄 <UNK> 阶段
# Reference: one in particular , a photo of women of
# Model: <SOS> the the them , that is is is is
#
# Source: 我 的 父亲 在 用 他 的 灰色 小 收音
# Reference: my father was listening to bbc news on his
# Model: <SOS> my my was in in his his his he
#
# Source: 政府 吗 别 想 了 <EOS> <PAD> <PAD> <PAD> <PAD>
# Reference: government ? forget about it ! <EOS> <PAD> <PAD>
# Model: <SOS> the : all &quot; ! <EOS> <EOS> <EOS> <EOS>
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.15, Train Loss: 0.00, Val Loss: 5.09, Train BLEU: 0.00, Val BLEU: 6.81, Minutes Elapsed: 649.15
# Sampling from val predictions...
# Source: 正常 忽视 了 差异 带来 的 美 人 与 人
# Reference: normality <UNK> the beauty that differences give us ,
# Model: <SOS> and , that the of the to that to
#
# Source: 这 当然 会 很 无聊 一个 慢 的 普通 的
# Reference: it &apos;ll be a very boring movie — —
# Model: <SOS> and this a you a of thing of a
#
# Source: 回到 我 的 问题 为什么 什么 我 要 留下 留下来
# Reference: back to my question : why did i stay
# Model: <SOS> and , my question question , i i know
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.30, Train Loss: 0.00, Val Loss: 5.10, Train BLEU: 0.00, Val BLEU: 7.53, Minutes Elapsed: 657.50
# Sampling from val predictions...
# Source: 每年 无数 的 朝鲜 <UNK> 在 中国 被捕 并 被
# Reference: every year , countless north koreans are caught in
# Model: <SOS> the &apos;s of the <UNK> were , the the
#
# Source: 所以 现在 的 沥青 有 一些 些小 钢丝 <UNK> 在
# Reference: so then you have asphalt with very small pieces
# Model: <SOS> so the &apos;s &apos;s the <UNK> the , ,
#
# Source: 你 可以 看到 到底 底部 的 颤动 轨迹 是 一种
# Reference: so on the bottom trace , you can see
# Model: <SOS> you you can you of you you see see
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.45, Train Loss: 0.00, Val Loss: 5.06, Train BLEU: 0.00, Val BLEU: 7.18, Minutes Elapsed: 665.89
# Sampling from val predictions...
# Source: 而 这 也 是 为什么 什么 它 在 街上 的
# Reference: that &apos;s why it &apos;s on the street .
# Model: <SOS> and that why it &apos;s like . the of
#
# Source: 我 开始 意识 到 狮子 们 会 害怕 移动 的
# Reference: and i discovered that lions are afraid of a
# Model: <SOS> and i began to that in and in ,
#
# Source: 世界 上 所有 有成 成功 的 企业 只有 一个 共同
# Reference: there &apos;s only one thing that all the successful
# Model: <SOS> the &apos;s a way of of the can of
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.60, Train Loss: 0.00, Val Loss: 5.06, Train BLEU: 0.00, Val BLEU: 7.21, Minutes Elapsed: 674.26
# Sampling from val predictions...
# Source: 在 沥青 <UNK> 路上 上会 溅 起 很多 水 <EOS>
# Reference: then you can have a lot of splash water
# Model: <SOS> in you the &apos;t it them of time ,
#
# Source: 发生 了 什么 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: what &apos;s going on here ? <EOS> <PAD> <PAD>
# Model: <SOS> what what <EOS> ? ? ? <EOS> <EOS> <EOS>
#
# Source: <UNK> 酒店 快餐 快餐店 闲置 的 土地 <EOS> <PAD> <PAD>
# Reference: liquor stores , fast food , vacant lots .
# Model: <SOS> franco : , . . . . . .
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.75, Train Loss: 0.00, Val Loss: 5.07, Train BLEU: 0.00, Val BLEU: 7.66, Minutes Elapsed: 682.63
# Sampling from val predictions...
# Source: 我 现时 住 在 新奥尔良 奥尔良 并 深深 深深地 爱
# Reference: now , i live in new orleans , and
# Model: <SOS> i &apos;ve &apos;ve was been in , , ,
#
# Source: 这 是 我 第一 第一次 一次 到 阿富汗 <EOS> <PAD>
# Reference: and this was my first time in afghanistan .
# Model: <SOS> this is is the first for . <EOS> .
#
# Source: 这 是 那 张 照片 几个 月前 我 跟 祖母
# Reference: this is what i looked like with my grandma
# Model: <SOS> this &apos;s a of came . the , ,
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 9.90, Train Loss: 0.00, Val Loss: 5.04, Train BLEU: 0.00, Val BLEU: 7.60, Minutes Elapsed: 691.02
# Sampling from val predictions...
# Source: 我 之所以 所以 决定 离开 是因为 因为 最后 一次 残暴
# Reference: i was able to leave , because of one
# Model: <SOS> i i to to see the the of was
#
# Source: 这 并 不是 说 母亲 们 对于 我们 的 成功
# Reference: it &apos;s not to say that our mothers aren
# Model: <SOS> it &apos;s not the the the it are are
#
# Source: 在 死 之前 我 想 跨过 国际 <UNK> 日期 变更
# Reference: &quot; before i die , i want to straddle
# Model: <SOS> i i , i , i i to to
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Epoch: 10.00, Train Loss: 0.00, Val Loss: 5.09, Train BLEU: 0.00, Val BLEU: 7.50, Minutes Elapsed: 696.61
# Sampling from val predictions...
# Source: 谢谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> thank you . <EOS> you <EOS> <EOS> <EOS> <EOS>
#
# Source: 我们 有志 志愿 志愿者 愿者 团队 帮助 创业 辅助 商
# Reference: we have groups of volunteers supporting the enterprise facilitator
# Model: <SOS> we we a cameras and that are and to
#
# Source: 我们 会 因 芭蕾 芭蕾舞 大师 和 <UNK> <UNK> 舞蹈
# Reference: we delight at ballet virtuosos and tap dancers you
# Model: <SOS> we we going , and and , and ,
#
# Model training completed in 696 minutes with 4.96 best validation loss and 7.84 best validation BLEU.

# %%
experiment_results = load_experiment_log(experiment_name=EXPERIMENT_NAME)

# %%
plot_single_learning_curve(experiment_results[0]['results'])

# %%
summarize_results(experiment_results)[['model_name', 'best_val_loss', 'best_val_bleu', 'runtime', 
                                          'total_params', 'trainable_params', 'dt_created']].head(1)
# Out:
#                                 model_name  best_val_loss  best_val_bleu  \
# 0  zh-rnn-without-attn-2018-12-13 05:27:47       4.963824       7.839494
#
#       runtime  total_params  trainable_params           dt_created
# 0  696.610684      69492144          51492144  2018-12-13 17:04:28

# %%
# reload model 
MODEL_NAME_TO_RELOAD = 'zh-rnn-without-attn-2018-12-13 05:27:47'
checkpoint = torch.load('model_checkpoints/{}.pth.tar'.format(MODEL_NAME_TO_RELOAD), map_location=device)
model.load_state_dict(checkpoint)

# %%
# check performance on validation set 
val_loss, val_bleu, val_hyp_idxs, val_ref_idxs, val_source_idxs, val_hyp_tokens, val_ref_tokens, val_source_tokens,\
val_attn = evaluate(model=model, loader=loaders_full['dev'], 
                    src_id2token=vocab[SRC_LANG]['id2token'], targ_id2token=vocab[TARG_LANG]['id2token'])
print("Validation BLEU: {:.2f} | Validation Loss: {:.2f}".format(val_bleu, val_loss))
# Out:
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Validation BLEU: 7.84 | Validation Loss: 5.01

# %%
# print predictions on val data 
for source, ref, hyp in zip(val_source_tokens, val_ref_tokens, val_hyp_tokens): 
    print("SOURCE: {}".format(' '.join(source)))
    print("REFERENCE: {}".format(' '.join(ref)))
    print("HYPOTHESIS: {}".format(' '.join(hyp)))
    print()
# Out:
# SOURCE: 我 11 岁 那年 记得 得有 一天 早晨 醒来 听见
# REFERENCE: when i was 11 , i remember waking up
# HYPOTHESIS: <SOS> i i was in , the was a to
#
# SOURCE: 我 的 父亲 在 用 他 的 灰色 小 收音
# REFERENCE: my father was listening to bbc news on his
# HYPOTHESIS: <SOS> my my is in in his his he he
#
# SOURCE: 他 面带 <UNK> <UNK> 笑容 这 很少 少见 因为 大部
# REFERENCE: there was a big smile on his face which
# HYPOTHESIS: <SOS> he &apos;s a , , , he , ,
#
# SOURCE: 塔利 塔利班 走 了 父亲 大声 叫 着 <EOS> <PAD>
# REFERENCE: &quot; the taliban are gone ! &quot; my father
# HYPOTHESIS: <SOS> the &apos;s , , is . . &quot; .
#
# SOURCE: 我 不知 知道 那 意味 意味着 什么 但是 我 能
# REFERENCE: i didn &apos;t know what it meant , but
# HYPOTHESIS: <SOS> i don &apos;t know what i but . but
#
# SOURCE: 你 现在 可以 去 个 真正 的 学校 念书 了
# REFERENCE: &quot; you can go to a real school now
# HYPOTHESIS: <SOS> you you you , the the the , ,
#
# SOURCE: 我 永远 不会 忘记 那个 早晨 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: a morning that i will never forget . <EOS>
# HYPOTHESIS: <SOS> i don , i &apos;t to to . .
#
# SOURCE: 一个 真正 的 学校 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: a real school . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> the &apos;s of . <EOS> . <EOS> <EOS> <EOS>
#
# SOURCE: 我 6 岁 那年 塔利 塔利班 占领 阿富汗 并 规定
# REFERENCE: you see , i was six when the taliban
# HYPOTHESIS: <SOS> i i , in , a to old half
#
# SOURCE: 所以 在 那 之后 5 年 我 <UNK> <UNK> 陪
# REFERENCE: so for the next five years , i dressed
# HYPOTHESIS: <SOS> so , in , of years , , was
#
# SOURCE: 这 是 我们 俩 人 唯一 的 受教 教育 方式
# REFERENCE: it was the only way we both could be
# HYPOTHESIS: <SOS> this is the we of we we to the
#
# SOURCE: 我们 每天 要 走 不同 的 路线 这样 才 没有
# REFERENCE: each day , we took a different route so
# HYPOTHESIS: <SOS> we we that we &apos;re to of of of
#
# SOURCE: 我们 把 书 放在 食品 杂货 袋中 这样 别人 就
# REFERENCE: we would cover our books in grocery bags so
# HYPOTHESIS: <SOS> we we going to , , the , ,
#
# SOURCE: 学校 在 一个 房屋 房屋里 屋里 我们 100 多 人
# REFERENCE: the school was in a house , more than
# HYPOTHESIS: <SOS> now , is in in , , we we
#
# SOURCE: 冬天 很 舒服 但 夏天 却 <UNK> <EOS> <PAD> <PAD>
# REFERENCE: it was cozy in winter but extremely hot in
# HYPOTHESIS: <SOS> and &apos;s not , but . <EOS> . .
#
# SOURCE: 我们 都 知道 自己 正 冒 着 生命 的 危险
# REFERENCE: we all knew we were risking our lives --
# HYPOTHESIS: <SOS> we all know that know know to the ,
#
# SOURCE: 有时 学校 <UNK> 突然 <UNK> 一周 因为 被 塔利 塔利班
# REFERENCE: from time to time , the school would suddenly
# HYPOTHESIS: <SOS> and , , the , , , of &apos;t
#
# SOURCE: 我们 总是 担心 会 被 塔利 塔利班 发现 <EOS> <PAD>
# REFERENCE: we always wondered what they knew about us .
# HYPOTHESIS: <SOS> we &apos;re to to &quot; was . <EOS> .
#
# SOURCE: 我们 在 被 跟踪 吗 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: were we being followed ? <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> we we going to ? <EOS> <EOS> <EOS> <EOS>
#
# SOURCE: 他们 知道 我们 的 住处 吗 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: do they know where we live ? <EOS> <PAD>
# HYPOTHESIS: <SOS> they know know what we are ? <EOS> <EOS>
#
# SOURCE: 我们 很 害怕 但是 我们 仍然 渴望 望去 学校 <EOS>
# REFERENCE: we were scared , but still , school was
# HYPOTHESIS: <SOS> we &apos;re &apos;t , we we don we don
#
# SOURCE: 我 很 幸运 幸运地 成长 在 一个 珍视 教育 也
# REFERENCE: i was very lucky to grow up in a
# HYPOTHESIS: <SOS> i &apos;m to in in a a in a
#
# SOURCE: 我 的 祖父 在 他 的 年代 是 位非 非凡
# REFERENCE: my grandfather was an extraordinary man for his time
# HYPOTHESIS: <SOS> my my is to in , , his ,
#
# SOURCE: 他 出身 阿富汗 边远 <UNK> 地区 有着 与 他人 不同
# REFERENCE: a total maverick from a remote province of afghanistan
# HYPOTHESIS: <SOS> he &apos;s of the , , , , the
#
# SOURCE: 但是 我 那 受过 教育 的 母亲 成为 为了 一名
# REFERENCE: but my educated mother became a teacher . <EOS>
# HYPOTHESIS: <SOS> but i &apos;m is to the , , and
#
# SOURCE: 那 就是 她 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: there she is . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> that &apos;s no . . <EOS> <EOS> . <EOS>
#
# SOURCE: 她 两年 年前 退休 了 结果 却 把 我家 变成
# REFERENCE: she retired two years ago , only to turn
# HYPOTHESIS: <SOS> she &apos;s to , , , she she the
#
# SOURCE: 我 的 父亲 那 就是 他 他 是 他家 家族
# REFERENCE: and my father -- that &apos;s him -- he
# HYPOTHESIS: <SOS> my my was is , &apos;s the , ,
#
# SOURCE: 因此 毫无 毫无疑问 无疑 疑问 他 的 孩子 应当 受到
# REFERENCE: there was no question that his children would receive
# HYPOTHESIS: <SOS> so , no lot of he was was the
#
# SOURCE: 对 他 来说 孩子 不 接受 受教 教育 <UNK> 是
# REFERENCE: to him , there was greater risk in not
# HYPOTHESIS: <SOS> and , , , &apos;s no , , but
#
# SOURCE: 在 塔利 塔利班 控制 阿富汗 的 那些 年 我 记得
# REFERENCE: during taliban years , i remember there were times
# HYPOTHESIS: <SOS> in the <UNK> in , was to to a
#
# SOURCE: 我 想 过 要 放弃 但 我 的 父亲 这时
# REFERENCE: i would want to quit , but my father
# HYPOTHESIS: <SOS> i i to to say about , i &apos;s
#
# SOURCE: 你 的 钱 可能 被 偷 你 可能 因 战争
# REFERENCE: your money can be stolen . you can be
# HYPOTHESIS: <SOS> your can is &apos;t be , and &apos;re &apos;t
#
# SOURCE: 而 你 唯一 能够 守护 <UNK> 的 东西 就是 这里
# REFERENCE: but the one thing that will always remain with
# HYPOTHESIS: <SOS> and you you you you you &apos;re you you
#
# SOURCE: 即便 即便如此 如此 你 还是 不想 继续 吗 <EOS> <PAD>
# REFERENCE: so do you still not want to continue ?
# HYPOTHESIS: <SOS> and , you want it ? ? do ?
#
# SOURCE: 如今 我 22 岁 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: today i am 22 . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> i , i . . . <EOS> <EOS> .
#
# SOURCE: 我 所 成长 的 国家 被 几十 几十年 十年 的
# REFERENCE: i was raised in a country that has been
# HYPOTHESIS: <SOS> i i a by the of of the the
#
# SOURCE: 我 这个 年龄 的 女性 中 高中 高中毕业 毕业 的
# REFERENCE: fewer than six percent of women my age have
# HYPOTHESIS: <SOS> and the the , , the , the .
#
# SOURCE: 而 如今 我 已经 是 一名 自豪 的 <UNK> 学院
# REFERENCE: instead , i stand here a proud graduate of
# HYPOTHESIS: <SOS> and i i &apos;m a a the of about
#
# SOURCE: 掌声 <UNK> 学院 是 全美 美国 的 顶级 文理 <UNK>
# REFERENCE: when i returned to afghanistan , my grandfather ,
# HYPOTHESIS: <SOS> the &apos;s is the , , , was ,
#
# SOURCE: 他 骄傲 的 不仅 不仅仅 仅仅 是因为 因为 我 的
# REFERENCE: he not only <UNK> about my college degree ,
# HYPOTHESIS: <SOS> he was &apos;t . , , , , because
#
# SOURCE: 掌声 我 的 家人 很 信任 我 <EOS> <PAD> <PAD>
# REFERENCE: my family believes in me . <EOS> <PAD> <PAD>
# HYPOTHESIS: <SOS> and , is . &quot; . <EOS> . <EOS>
#
# SOURCE: 我 的 梦想 很大 但 他们 对 我 的 期待
# REFERENCE: i dream big , but my family dreams even
# HYPOTHESIS: <SOS> my my &apos;t , but i &apos;m is ,
#
# SOURCE: 这 就是 我 成为 <UNK> 的 全球 大使 的 原因
# REFERENCE: that &apos;s why i am a global ambassador for
# HYPOTHESIS: <SOS> this &apos;s what i &apos;m a the of .
#
# SOURCE: 那 也 是 我 参与 创立 <UNK> 的 原因 这
# REFERENCE: that &apos;s why i cofounded <UNK> , the first
# HYPOTHESIS: <SOS> and , the i &apos;m my <UNK> the i
#
# SOURCE: 让 我 兴奋 的 是 我 看见 我 学校 中
# REFERENCE: the exciting thing is that i see students at
# HYPOTHESIS: <SOS> and me thing i me i me to i
#
# SOURCE: 我 看见 她们 的 双亲 尤其 是 她们 的 父亲
# REFERENCE: and i see their parents and their fathers who
# HYPOTHESIS: <SOS> i i i that the , the are ,
#
# SOURCE: 比如 艾哈迈 艾哈迈德 哈迈德 迈德 这 不是 真名 我 也
# REFERENCE: like ahmed . that &apos;s not his real name
# HYPOTHESIS: <SOS> now , , , is not . . .
#
# SOURCE: 不到 一个 一个月 月前 他 和 他 女儿 在 从
# REFERENCE: less than a month ago , he and his
# HYPOTHESIS: <SOS> and , , , , he he he a
#
# SOURCE: 他 到 家 时 电话 <UNK> 了 一个 声音 警告
# REFERENCE: as he arrived home , the phone rang ,
# HYPOTHESIS: <SOS> he &apos;s said , the the he , a
#
# SOURCE: 如果 你 想 现在 就 可以 杀 了 我 他
# REFERENCE: &quot; kill me now , if you wish ,
# HYPOTHESIS: <SOS> and you you &quot; &quot; you you want to
#
# SOURCE: 对于 阿富汗 我 意识 到 这 是 西方 方国 国家
# REFERENCE: what i &apos;ve come to realize about afghanistan ,
# HYPOTHESIS: <SOS> and , &apos;m going to here is is is
#
# SOURCE: 这 并 不是 说 母亲 们 对于 我们 的 成功
# REFERENCE: it &apos;s not to say that our mothers aren
# HYPOTHESIS: <SOS> it &apos;s not a , , , &apos;re are
#
# SOURCE: 事实 事实上 为了 女儿 的 美好 美好未来 未来 她们 通常
# REFERENCE: in fact , they &apos;re often the initial and
# HYPOTHESIS: <SOS> in fact , the of the to to of
#
# SOURCE: 在 塔利 塔利班 控制 下 去 上学 的 女孩 曾经
# REFERENCE: under the taliban , girls who went to school
# HYPOTHESIS: <SOS> in the the of , &apos;s the to the
#
# SOURCE: 但是 今天 阿富汗 接受 受教 教育 的 女孩 已经 超过
# REFERENCE: but today , more than three million girls are
# HYPOTHESIS: <SOS> but the &apos;s the the , , of the
#
# SOURCE: 掌声 阿富汗 与 美国 国有 很大 不同 <EOS> <PAD> <PAD>
# REFERENCE: afghanistan looks so different from here in america .
# HYPOTHESIS: <SOS> and , to . . . . <EOS> .
#
# SOURCE: 我 发现 美国 国人 能 看出 我们 变化 中 的
# REFERENCE: i find that americans see the fragility in changes
# HYPOTHESIS: <SOS> i i a a , we we of the
#
# SOURCE: 我 担心 这些 变化 在 美军 <UNK> 之后 能够 维持
# REFERENCE: i fear that these changes will not last much
# HYPOTHESIS: <SOS> i think that this are are the in in
#
# SOURCE: 但是 当 我 回到 阿富汗 看见 我 的 学生 以及
# REFERENCE: but when i am back in afghanistan , when
# HYPOTHESIS: <SOS> but when i was my my my , i
#
# SOURCE: 对 我 来说 阿富汗 充满 了 希望 和 无限 的
# REFERENCE: to me , afghanistan is a country of hope
# HYPOTHESIS: <SOS> and , , a &apos;s a . bit for
#
# SOURCE: 像 我 一样 她们 也 有 很大 的 梦想 <EOS>
# REFERENCE: like me , they are dreaming big . <EOS>
# HYPOTHESIS: <SOS> and , , they &apos;s a to . .
#
# SOURCE: 谢谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . <EOS> . <EOS> . <EOS> <EOS>
#
# SOURCE: 我 所 做 的 一切 不论 不论是 生活 上 还是
# REFERENCE: everything i do , and everything i do professionally
# HYPOTHESIS: <SOS> i i i to i &apos;m &apos;m i going
#
# SOURCE: 从 1971 年 到 1977 年 我 看起 看起来 起来
# REFERENCE: from 1971 to 1977 -- i look young ,
# HYPOTHESIS: <SOS> in , , i , i i &apos;t the
#
# SOURCE: 当时 我 在 一家 意大利 大利 非政府 政府 组织 织工
# REFERENCE: i worked for an italian ngo , and every
# HYPOTHESIS: <SOS> and i a a in in in the in
#
# SOURCE: 我 都 快 抓狂 了 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: and i was distraught . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> i i said , . <EOS> was <EOS> .
#
# SOURCE: 那时 21 岁 的 我 觉得 我们 意大利 意大利人 大利
# REFERENCE: i thought , age 21 , that we italians
# HYPOTHESIS: <SOS> in , &apos;t &quot; i , , i what
#
# SOURCE: 然而 我们 干什么 什么 <UNK> 什么 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: instead , everything we touched we killed . <EOS>
# HYPOTHESIS: <SOS> and , we don we . . <EOS> <EOS>
#
# SOURCE: 我们 第一 第一个 一个 项目 给 了 我 写 第一
# REFERENCE: our first project , the one that has inspired
# HYPOTHESIS: <SOS> we first is , the , , , was
#
# SOURCE: 所以 我们 带 着意 意大利 大利 的 种子 来到 了
# REFERENCE: so we arrived there with italian seeds in southern
# HYPOTHESIS: <SOS> so we we to a a <UNK> , the
#
# SOURCE: 当然 当地 当地人 对此 表示 毫无 无兴趣 兴趣 所以 我们
# REFERENCE: and of course the local people had absolutely no
# HYPOTHESIS: <SOS> and course course , the is is &apos;t ,
#
# SOURCE: 有着 如此 肥沃 的 山谷 当地 当地人 人居 居然 不
# REFERENCE: and we were amazed that the local people ,
# HYPOTHESIS: <SOS> the &apos;s &apos;s the in the was of of
#
# SOURCE: 但 我们 并 没有 问 他们 原因 而 仅仅 是
# REFERENCE: but instead of asking them how come they were
# HYPOTHESIS: <SOS> but we don don , , &apos;t &apos;re ,
#
# SOURCE: 在 饥饿 的 赞比亚 比亚 人民 <UNK> 悬 一线 时
# REFERENCE: &quot; just in the nick of time to save
# HYPOTHESIS: <SOS> in the the in , , , , &quot;
#
# SOURCE: 当然 在 非洲 种 的 东西 西都 长 得 很
# REFERENCE: and of course , everything in africa grew beautifully
# HYPOTHESIS: <SOS> of of course , there &apos;s the , the
#
# SOURCE: 我们 种 的 西红柿 漂亮 极了 在意 意大利 大利 一个
# REFERENCE: we had these magnificent tomatoes . in italy ,
# HYPOTHESIS: <SOS> we have a a , , the , ,
#
# SOURCE: 这 真是 难以 难以置信 置信 我们 跟 赞比亚 比亚 人
# REFERENCE: and we could not believe , and we were
# HYPOTHESIS: <SOS> it &apos;s &apos;s &apos;t to to the , &apos;re
#
# SOURCE: 当 西红柿 成熟 了 <UNK> 的 好看 极了 一夜 一夜之间
# REFERENCE: when the tomatoes were nice and ripe and red
# HYPOTHESIS: <SOS> when the was came in , , , ,
#
# SOURCE: 我们 跟 赞比亚 比亚 人 说 天 呐 这些 该死
# REFERENCE: and we said to the <UNK> , &quot; my
# HYPOTHESIS: <SOS> we we we going &quot; , , who we
#
# SOURCE: 赞比亚 比亚 人 说 没错 这 就是 我们 不在 这里
# REFERENCE: and the <UNK> said , &quot; yes , that
# HYPOTHESIS: <SOS> and , &apos;s news is &quot; we is it
#
# SOURCE: 你们 为什么 什么 <UNK> 说 你 又 没 问 过
# REFERENCE: &quot; why didn &apos;t you tell us ? &quot;
# HYPOTHESIS: <SOS> you you you you you you ? ? &quot;
#
# SOURCE: 我 本 以为 只有 我们 意大利 意大利人 大利 利人 在
# REFERENCE: i thought it was only us italians <UNK> around
# HYPOTHESIS: <SOS> i &apos;m , &quot; us that that the we
#
# SOURCE: 因为 我们 至少 喂饱 了 河马 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: because , you see , at least we fed
# HYPOTHESIS: <SOS> because we we we to . are . .
#
# SOURCE: 你们 应该 看看 这些 垃圾 掌声 你们 应该 看看 我们
# REFERENCE: you should see the rubbish — -- you should
# HYPOTHESIS: <SOS> you you &apos;t the these , the you you
#
# SOURCE: 你们 可以 读读 这本 本书 叫 致命 援助 作者 是
# REFERENCE: you want to read the book , read &quot;
# HYPOTHESIS: <SOS> you you see see the the of the the
#
# SOURCE: 这本 本书 出版 于 2009 年 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: the book was published in 2009 . <EOS> <PAD>
# HYPOTHESIS: <SOS> this &apos;s is is . <EOS> . <EOS> .
#
# SOURCE: 我们 这些 西方 援助 <UNK> 在 过去 50 年 里
# REFERENCE: we western donor countries have given the african continent
# HYPOTHESIS: <SOS> we we to in in the in percent of
#
# SOURCE: 我 不 打算 跟 你们 细说 这笔 钱 所 造成
# REFERENCE: i &apos;m not going to tell you the damage
# HYPOTHESIS: <SOS> i don &apos;t to to show you about story
#
# SOURCE: 你们 自己 去 读读 看 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: just go and read her book . <EOS> <PAD>
# HYPOTHESIS: <SOS> you you you to . <EOS> . <EOS> <EOS>
#
# SOURCE: 看看 以 一位 位非 非洲 女性 的 眼光 我们 所
# REFERENCE: read it from an african woman , the damage
# HYPOTHESIS: <SOS> and , the the the of , we we
#
# SOURCE: 我们 西方 西方人 方人 是 帝国 帝国主义 <UNK> 国主 主义
# REFERENCE: we western people are <UNK> , <UNK> missionaries ,
# HYPOTHESIS: <SOS> we we the in the in the , <UNK>
#
# SOURCE: 这 两个 词 来自 于 拉丁 词根 <UNK> 意 即
# REFERENCE: the two words come from the latin root &quot;
# HYPOTHESIS: <SOS> it &apos;s of of <UNK> the <UNK> , ,
#
# SOURCE: 但 两个 词 的 意思 不同 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: but they mean two different things . <EOS> <PAD>
# HYPOTHESIS: <SOS> but it &apos;s &apos;t it . . <EOS> .
#
# SOURCE: 家长 <UNK> 意味 意味着 我 把 不同 文化 文化背景 背景
# REFERENCE: <UNK> , i treat anybody from a different culture
# HYPOTHESIS: <SOS> i , i i going . i . .
#
# SOURCE: <UNK> 意味 意味着 我 把 另 一文 文化 文化背景 背景
# REFERENCE: patronizing , i treat everybody from another culture as
# HYPOTHESIS: <SOS> and , i &apos;m going . i . .
#
# SOURCE: 这 也 就是 为什么 什么 在 非洲 白人 被称作 称作
# REFERENCE: that &apos;s why the white people in africa are
# HYPOTHESIS: <SOS> and &apos;s why the &apos;s of in in room
#
# SOURCE: 我 在读 一本 本书 时 如 遭 当头 <UNK> <UNK>
# REFERENCE: i was given a slap in the face reading
# HYPOTHESIS: <SOS> i i to to a , the , ,
#
# SOURCE: 这 应该 该是 援助 的 首要 原则 <EOS> <PAD> <PAD>
# REFERENCE: this should be the first principle of aid .
# HYPOTHESIS: <SOS> it &apos;s a a the of of <EOS> .
#
# SOURCE: 援助 的 首要 原则 就是 尊重 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: the first principle of aid is respect . <EOS>
# HYPOTHESIS: <SOS> the &apos;s is is not is not . .
#
# SOURCE: 今天 早上 给 这次 大会 <UNK> 开幕 <UNK> 的 先生
# REFERENCE: this morning , the gentleman who opened this conference
# HYPOTHESIS: <SOS> and , is the <UNK> of <UNK> to the
#
# SOURCE: 27 岁 时 我 做出 一个 决定 只 基于 人们
# REFERENCE: i decided when i was 27 years old to
# HYPOTHESIS: <SOS> in , a to was a a old ,
#
# SOURCE: 所以 我们 要 做 的 就是 闭嘴 <EOS> <PAD> <PAD>
# REFERENCE: so what you do -- you shut up .
# HYPOTHESIS: <SOS> so we what we going we &apos;s the .
#
# SOURCE: 我们 走进 一个 社区 时 不会 将 任何 想法 强加
# REFERENCE: you never arrive in a community with any ideas
# HYPOTHESIS: <SOS> we we a a a , , and ,
#
# SOURCE: 我们 的 工作 地点 不在 办公 办公室 公室 <EOS> <PAD>
# REFERENCE: we don &apos;t work from offices . <EOS> <PAD>
# HYPOTHESIS: <SOS> we have &apos;t have to . . <EOS> .
#
# SOURCE: 我们 与 客户 在 餐馆 和 酒吧 见面 <EOS> <PAD>
# REFERENCE: we meet at the cafe . we meet at
# HYPOTHESIS: <SOS> we &apos;re &apos;t in in of the &apos;re to
#
# SOURCE: 我们 没有 任何 基础 基础设施 设施 的 建设 <EOS> <PAD>
# REFERENCE: we have zero infrastructure . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> we &apos;re no look . . . <EOS> .
#
# SOURCE: 我们 所 做 的 是 跟 他们 交朋友 朋友 并发
# REFERENCE: and what we do , we become friends ,
# HYPOTHESIS: <SOS> what what we &apos;re doing we , to ,
#
# SOURCE: 最重 重要 的 是 热情 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: the most important thing is passion . <EOS> <PAD>
# HYPOTHESIS: <SOS> the , is is is . . <EOS> <EOS>
#
# SOURCE: 你 可以 向 客户 提出 你 的 点子 <EOS> <PAD>
# REFERENCE: you can give somebody an idea . <EOS> <PAD>
# HYPOTHESIS: <SOS> you can be your a . . <EOS> <EOS>
#
# SOURCE: 但 如果 对方 不感兴趣 感兴 感兴趣 兴趣 你 又 有
# REFERENCE: if that person doesn &apos;t want to do it
# HYPOTHESIS: <SOS> but if look &apos;t &apos;t have to be you
#
# SOURCE: 客户 热衷 热衷于 自我 提升 的 这份 热情 才 是
# REFERENCE: the passion that the person has for her own
# HYPOTHESIS: <SOS> and , of the the are the this to
#
# SOURCE: 对方 的 热情 是 建立 在 自我 提升 的 基础
# REFERENCE: the passion that that man has for his own
# HYPOTHESIS: <SOS> the the is is the the the be to
#
# SOURCE: 然后 我们 帮助 他们 搜集 相关 知识 和 信息 因为
# REFERENCE: and then we help them to go and find
# HYPOTHESIS: <SOS> and we we we them , and them ,
#
# SOURCE: 有点 点子 的 人 未必 懂得 相关 知识 但 我们
# REFERENCE: the person with the idea may not have the
# HYPOTHESIS: <SOS> there of of the is , not , ,
#
# SOURCE: 所以 很多 很多年 多年 年前 我 有 个 想法 我们
# REFERENCE: so years and years ago , i had this
# HYPOTHESIS: <SOS> so , most , , , i i a
#
# SOURCE: 我 告诉 你们 一个 秘密 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: let me tell you a secret . <EOS> <PAD>
# HYPOTHESIS: <SOS> i i tell you a . . <EOS> <EOS>
#
# SOURCE: 社区 会议 存在 一个 问题 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: there is a problem with community meetings . <EOS>
# HYPOTHESIS: <SOS> there , a lot of <EOS> . <EOS> <EOS>
#
# SOURCE: 企业 企业家 们 从不 不出 出席 他们 绝不 绝不会 不会
# REFERENCE: entrepreneurs never come , and they never tell you
# HYPOTHESIS: <SOS> and , gentlemen &apos;t to they they &apos;t &apos;t
#
# SOURCE: 所以 做 计划 有 一个 <UNK> <EOS> <PAD> <PAD> <PAD>
# REFERENCE: so planning has this blind spot . <EOS> <PAD>
# HYPOTHESIS: <SOS> so , &apos;s a . . <EOS> <EOS> .
#
# SOURCE: 你 甚至 都 无从 结识 社区 区里 最 聪明 的
# REFERENCE: the smartest people in your community you don &apos;t
# HYPOTHESIS: <SOS> you you you you you room is &apos;t &apos;t
#
# SOURCE: 我们 的 做法 是 与 客户 一对 一对一 为了 能
# REFERENCE: what we do , we work one-on-one , and
# HYPOTHESIS: <SOS> our our &apos;re is we &apos;re to , ,
#
# SOURCE: 我们 必须 创造 一个 全新 的 职业 <EOS> <PAD> <PAD>
# REFERENCE: you have to create a new profession . <EOS>
# HYPOTHESIS: <SOS> we we to to a a of . <EOS>
#
# SOURCE: 这种 职业 相当 相当于 当于 企业 的 家庭 <UNK> 医生
# REFERENCE: the profession is the family doctor of enterprise ,
# HYPOTHESIS: <SOS> it &apos;s is that the of the the ,
#
# SOURCE: 我 在 <UNK> <UNK> 澳大利 澳大利亚 大利 利亚 <UNK> 的
# REFERENCE: i started this as a <UNK> in <UNK> ,
# HYPOTHESIS: <SOS> i was in <UNK> in <UNK> in in <UNK>
#
# SOURCE: 那时 我 在读 博士 努力 摒弃 那种 <UNK> 的 <UNK>
# REFERENCE: i was a doing a ph.d. at the time
# HYPOTHESIS: <SOS> and i to to of <UNK> of . .
#
# SOURCE: 我 在 埃斯 <UNK> 兰斯 的 第一 第一年 一年 只是
# REFERENCE: and so what i did in <UNK> that first
# HYPOTHESIS: <SOS> i was &apos;m &apos;m &apos;m in in , ,
#
# SOURCE: 我 让 这 五个 渔民 合伙 运作 不是 把 美味
# REFERENCE: and i helped these five fishermen to work together
# HYPOTHESIS: <SOS> and i i this do , , i ,
#
# SOURCE: 一年 之内 我 做 了 27 个 项目 政府 的
# REFERENCE: in a year , i had 27 projects going
# HYPOTHESIS: <SOS> i , , , i i a to to
#
# SOURCE: 你 怎么 能 我 答道 我 做 了 一件 很困
# REFERENCE: how can you do — ? &quot; and i
# HYPOTHESIS: <SOS> you you you say me i i i &apos;m
#
# SOURCE: 那 就是 <UNK> 听 他们 说 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: i shut up , and listen to them .
# HYPOTHESIS: <SOS> it &apos;s it <UNK> them them . <EOS> .
#
# SOURCE: 所以 掌声 所以 政府 的 人 说 那 接着 做
# REFERENCE: so — — so the government says , &quot;
# HYPOTHESIS: <SOS> so , people of , people of the &quot;
#
# SOURCE: 我们 在世 在世界上 世界 上 300 个 社区 开展 了
# REFERENCE: we &apos;ve done it in 300 communities around the
# HYPOTHESIS: <SOS> we we to a in the , , the
#
# SOURCE: 我们 已 帮助 建立 了 40 000 家 企业 <EOS>
# REFERENCE: we have helped to start 40,000 businesses . <EOS>
# HYPOTHESIS: <SOS> we have a percent do a the to <EOS>
#
# SOURCE: 新一代 一代 的 创业 创业者 业者 们 皆 因 <UNK>
# REFERENCE: there is a new generation of entrepreneurs who are
# HYPOTHESIS: <SOS> the &apos;s a a of of <EOS> . <EOS>
#
# SOURCE: 彼得 德鲁 <UNK> 史 上 最 伟大 的 管理 咨询
# REFERENCE: peter <UNK> , one of the greatest management consultants
# HYPOTHESIS: <SOS> the &apos;s : how <UNK> the <UNK> of of
#
# SOURCE: 彼得 德鲁 <UNK> 在 涉足 商界 之前 是 一位 哲学
# REFERENCE: peter <UNK> was a professor of philosophy before becoming
# HYPOTHESIS: <SOS> the &apos;s : a in , the , <EOS>
#
# SOURCE: 计划 是 给 创业 帮 了 <UNK> <EOS> <PAD> <PAD>
# REFERENCE: planning is the kiss of death of entrepreneurship .
# HYPOTHESIS: <SOS> the &apos;s the <UNK> . . . <EOS> .
#
# SOURCE: 现在 我们 重建 建基 基督 <UNK> 新西兰 西兰 却 不知
# REFERENCE: so now you &apos;re rebuilding christchurch without knowing what
# HYPOTHESIS: <SOS> now we &apos;re &apos;re see to the , ,
#
# SOURCE: 我们 必须 学会 如何 让 这些 人 给出 他们 的
# REFERENCE: you have to learn how to get these people
# HYPOTHESIS: <SOS> we we to people them people people them to
#
# SOURCE: 我们 必须 给予 他们 保密 的 承诺 并 尊重 他们
# REFERENCE: you have to offer them <UNK> , privacy ,
# HYPOTHESIS: <SOS> we we to have them the to they they
#
# SOURCE: 在 一个 10 000 人 的 社区 区里 我们 有
# REFERENCE: in a community of 10,000 people , we get
# HYPOTHESIS: <SOS> in the , , , , , , percent
#
# SOURCE: 你 能 想象 一个 400 000 人 的 社区 凝聚
# REFERENCE: can you imagine a community of 400,000 people ,
# HYPOTHESIS: <SOS> you you imagine a a of a , ,
#
# SOURCE: 今天 <UNK> 天上 上午 你们 鼓掌 最多 的 演讲 <UNK>
# REFERENCE: which presentation have you applauded the most this morning
# HYPOTHESIS: <SOS> and &apos;s the the . to <EOS> . .
#
# SOURCE: 是 充满 创业 热情 的 当地 当地人 你们 为 他们
# REFERENCE: local , passionate people . that &apos;s who you
# HYPOTHESIS: <SOS> it &apos;s are , , , , a ,
#
# SOURCE: 所以 我 想 说 的 是 创业 创业精神 精神 是
# REFERENCE: so what i &apos;m saying is that entrepreneurship is
# HYPOTHESIS: <SOS> so i i want like to is is is
#
# SOURCE: 当 我们 处于 第一 第一次 一次 工业 工业革命 革命 的
# REFERENCE: we are at the end of the first industrial
# HYPOTHESIS: <SOS> when we the the first of the first ,
#
# SOURCE: 内燃 内燃机 燃机 的 燃料 总 有 耗尽 的 一天
# REFERENCE: the internal combustion engine is not sustainable . <EOS>
# HYPOTHESIS: <SOS> the &apos;s of of the the by by <EOS>
#
# SOURCE: 用 <UNK> 冷藏 食物 也 非 长久 <UNK> 久之 计
# REFERENCE: <UNK> way of maintaining things is not sustainable .
# HYPOTHESIS: <SOS> it <UNK> : the , , the , ,
#
# SOURCE: 我们 现在 要 关心 的 是 我们 如何 以 一种
# REFERENCE: what we have to look at is at how
# HYPOTHESIS: <SOS> what what &apos;re is is is is is we
#
# SOURCE: 现有 的 科技 水平 尚 做 不到 这 一点 <EOS>
# REFERENCE: the technologies do not exist to do that .
# HYPOTHESIS: <SOS> the &apos;s is the think the <EOS> . .
#
# SOURCE: 谁 能 发明 这种 科技 来 实现 绿色 绿色革命 革命
# REFERENCE: who is going to invent the technology for the
# HYPOTHESIS: <SOS> and &apos;s this to be this this , the
#
# SOURCE: 政府 吗 别 想 了 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: government ? forget about it ! <EOS> <PAD> <PAD>
# HYPOTHESIS: <SOS> the , . . . . <EOS> <EOS> <EOS>
#
# SOURCE: 是 创业 创业者 业者 们 是 他们 正在 为 之
# REFERENCE: it will be entrepreneurs , and they &apos;re doing
# HYPOTHESIS: <SOS> it &apos;s a be to they they &apos;re them
#
# SOURCE: 许多 许多年 多年 年前 我 在 一本 未来 <UNK> 主义
# REFERENCE: there &apos;s a lovely story that i read in
# HYPOTHESIS: <SOS> and i no lot that . i &apos;m in
#
# SOURCE: <UNK> 年 有 一批 专家 受到 邀请 去 讨论 纽约
# REFERENCE: there was a group of experts who were invited
# HYPOTHESIS: <SOS> and &apos;s a , of a , the to
#
# SOURCE: 那 是 <UNK> 年 这 批 人 聚 到 一起
# REFERENCE: and in <UNK> , this group of people came
# HYPOTHESIS: <SOS> this &apos;s &apos;s , , is the <UNK> ,
#
# SOURCE: 为什么 什么 因为 他们 看着 图表 上 的 曲线 说
# REFERENCE: why ? because they looked at the curve and
# HYPOTHESIS: <SOS> why ? because they &apos;re &apos;t the , of
#
# SOURCE: 到 时人 人们 将 会 被 <UNK> 淹没 <EOS> <PAD>
# REFERENCE: they were already drowning in manure . <EOS> <PAD>
# HYPOTHESIS: <SOS> it people &apos;t people to . . . <EOS>
#
# SOURCE: 所以 <UNK> 年 他们 认为 这种 肮脏 的 科技 将
# REFERENCE: so <UNK> , they are seeing this dirty technology
# HYPOTHESIS: <SOS> so they they they , the , the they
#
# SOURCE: 那么 结果 呢 40 年 之后 1900 年 美利 美利坚
# REFERENCE: so what happens ? in 40 years &apos; time
# HYPOTHESIS: <SOS> so , you happened the , , , ,
#
# SOURCE: 找到 一种 新科 科技 取而代之 才 是 发展 的 <UNK>
# REFERENCE: the idea of finding a different technology had absolutely
# HYPOTHESIS: <SOS> and &apos;s is the is is is . <EOS>
#
# SOURCE: 例如 密歇根 密歇根州 迪 尔 伯恩 市 的 福特 福特汽车公司
# REFERENCE: <UNK> , michigan . henry ford . <EOS> <PAD>
# HYPOTHESIS: <SOS> and , , , , , , the &apos;s
#
# SOURCE: 然而 与 创业 创业者 业者 打交道 交道 有 个 秘诀
# REFERENCE: however , there is a secret to work with
# HYPOTHESIS: <SOS> and , the &apos;s a a of for the
#
# SOURCE: 第一 你 要 给予 他们 保密 的 承诺 <EOS> <PAD>
# REFERENCE: first , you have to offer them <UNK> .
# HYPOTHESIS: <SOS> and , you &apos;re to to them . .
#
# SOURCE: 不然 他们 不会 会来 找 你 谈 的 <EOS> <PAD>
# REFERENCE: otherwise they don &apos;t come and talk to you
# HYPOTHESIS: <SOS> don , they &apos;t want to . . <EOS>
#
# SOURCE: 然后 你 要为 他们 提供 专注 而 热情 的 服务
# REFERENCE: then you have to offer them absolute , dedicated
# HYPOTHESIS: <SOS> and you &apos;re them , the the the they
#
# SOURCE: 你 要 告诉 他们 创业 创业精神 精神 的 真谛 <EOS>
# REFERENCE: and then you have to tell them the truth
# HYPOTHESIS: <SOS> you you you tell them tell them what <EOS>
#
# SOURCE: 不论 不论是 大公 公司 还是 小企业 企业 都 能 把
# REFERENCE: the smallest company , the biggest company , has
# HYPOTHESIS: <SOS> the , of is the , of of the
#
# SOURCE: 问题 是 什么 呢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: guess what ? <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> what what what <EOS> <EOS> <EOS> ? <EOS> <EOS>
#
# SOURCE: 这 世上 从来 从来没 没有 一个 个人 能 同时 做好
# REFERENCE: we have never met a single human being in
# HYPOTHESIS: <SOS> it &apos;s &apos;t do to a of of ,
#
# SOURCE: 这种 人 不存 存在 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: it doesn &apos;t exist . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> it &apos;s &apos;t matter . . . <EOS> .
#
# SOURCE: 这样 的 能人 尚未 未出 出生 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: this person has never been born . <EOS> <PAD>
# HYPOTHESIS: <SOS> it &apos;s not &apos;t . . . . .
#
# SOURCE: 我们 做 过 调查 对 世界 上 100 家 标杆
# REFERENCE: we &apos;ve done the research , and we have
# HYPOTHESIS: <SOS> we &apos;re a a in of the the &apos;s
#
# SOURCE: 世界 上 所有 有成 成功 的 企业 只有 一个 共同
# REFERENCE: there &apos;s only one thing that all the successful
# HYPOTHESIS: <SOS> and , no a of the the the the
#
# SOURCE: 现在 我们 在 <UNK> 郡 英国 教授 16 岁 青年
# REFERENCE: now we teach entrepreneurship to <UNK> in <UNK> ,
# HYPOTHESIS: <SOS> now we we a <UNK> the the <UNK> ,
#
# SOURCE: 我 一次 都 没有 我们 用 了 32 次 <EOS>
# REFERENCE: never the word &quot; i , &quot; and the
# HYPOTHESIS: <SOS> i i , , &quot; , . . ,
#
# SOURCE: 他 刚 起步 时 并非 单枪 单枪匹马 <EOS> <PAD> <PAD>
# REFERENCE: he wasn &apos;t alone when he started . <EOS>
# HYPOTHESIS: <SOS> he &apos;s &apos;t a to . was &apos;t .
#
# SOURCE: 没人 能 独自 自创 创立 一个 企业 没人 <EOS> <PAD>
# REFERENCE: nobody started a company alone . no one .
# HYPOTHESIS: <SOS> and , the to of the the was .
#
# SOURCE: 所以 我们 可以 建立 一个 社区 在 这个 社区 区里
# REFERENCE: so we can create the community where we have
# HYPOTHESIS: <SOS> so we can see that in of the the
#
# SOURCE: 你 能 做 什么 你 能 生产 产出 出来 吗
# REFERENCE: what can you do ? can you make it
# HYPOTHESIS: <SOS> you you you do ? ? you be ?
#
# SOURCE: 你 能 销售 售出 出去 吗 你 能 打理 资金
# REFERENCE: okay , can you sell it ? can you
# HYPOTHESIS: <SOS> you you you you imagine a ? a you
#
# SOURCE: 啊 这个 我 办不到 不到 那 要 我 替 你
# REFERENCE: &quot; oh , no , i cannot do this
# HYPOTHESIS: <SOS> and , , i , i &apos;m &apos;t say
#
# SOURCE: 我们 鼓舞 各个 社区 进行 创业 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: we activate communities . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> we we to <UNK> . are <EOS> . <EOS>
#
# SOURCE: 我们 有志 志愿 志愿者 愿者 团队 帮助 创业 辅助 商
# REFERENCE: we have groups of volunteers supporting the enterprise facilitator
# HYPOTHESIS: <SOS> we &apos;re to <UNK> the , the , ,
#
# SOURCE: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . much . <EOS> . <EOS> <EOS>
#
# SOURCE: 五年 年前 我 曾 有 过 一个 有如 漫游 爱丽丝
# REFERENCE: five years ago , i experienced a bit of
# HYPOTHESIS: <SOS> i , ago , i was a a of
#
# SOURCE: 宾夕法尼 宾夕法尼亚 宾夕法尼亚州 尼亚 州立 州立大学 大学 让 我 这个
# REFERENCE: penn state asked me , a communications teacher ,
# HYPOTHESIS: <SOS> and , : and to this is of is
#
# SOURCE: 我 被 吓到 了 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: and i was scared . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> i i i it . <EOS> <EOS> <EOS> .
#
# SOURCE: 我 真的 被 吓坏 了 这些 学生 生发 发达 的
# REFERENCE: really scared . scared of these students with their
# HYPOTHESIS: <SOS> i i i i was i , , i
#
# SOURCE: 不过 随着 对话 的 展开 我 的 经历 就 如
# REFERENCE: but as these conversations unfolded , i experienced what
# HYPOTHESIS: <SOS> but , the as , my my i to
#
# SOURCE: 这 就是 我 和 那些 学生 们 对话 时 的
# REFERENCE: that &apos;s just how i felt as i had
# HYPOTHESIS: <SOS> and &apos;s not i i &apos;m to . as
#
# SOURCE: 我 相信 打开 那 扇门 的 关键 就是 要 有
# REFERENCE: and i believe the key to opening that door
# HYPOTHESIS: <SOS> i i i that &apos;s is the the and
#
# SOURCE: 为了 改变 世界 我们 迫切 迫切需要 需要 从 我们 的
# REFERENCE: we desperately need great communication from our scientists and
# HYPOTHESIS: <SOS> and , to to the and we world ,
#
# SOURCE: 我们 的 科学 科学家 学家 和 工程 工程师 们 解决
# REFERENCE: our scientists and engineers are the ones that are
# HYPOTHESIS: <SOS> our have are the scientists , to of the
#
# SOURCE: 可是 如果 我们 的 科学 科学家 学家 和 工程 工程师
# REFERENCE: but these great conversations can &apos;t occur if our
# HYPOTHESIS: <SOS> it if if our , our , , we
#
# SOURCE: 所以 科学 科学家 学家 和 工程 工程师 们 请 跟
# REFERENCE: so scientists and engineers , please , talk nerdy
# HYPOTHESIS: <SOS> so , scientists to are &apos;t , , ,
#
# SOURCE: 我 想来 分享 几个 有用 的 方法 告诉 你们 如何
# REFERENCE: i want to share a few keys on how
# HYPOTHESIS: <SOS> i i to tell you you of of you
#
# SOURCE: 第一 第一个 一个 要 回答 我们 的 问题 高科技 科技
# REFERENCE: first question to answer for us : so what
# HYPOTHESIS: <SOS> the first the , , , , because we
#
# SOURCE: 告诉 我们 为什么 什么 你们 的 科学 与 我们 有关
# REFERENCE: tell us why your science is relevant to us
# HYPOTHESIS: <SOS> and we we we we is us . we
#
# SOURCE: 别 光 告诉 我 你们 研究 骨 小 <UNK> 要
# REFERENCE: don &apos;t just tell me that you study <UNK>
# HYPOTHESIS: <SOS> &quot; , tell me you , i you &apos;t
#
# SOURCE: 另外 当 你们 描述 科学 原理 时 要 注意 术语
# REFERENCE: and when you &apos;re describing your science , beware
# HYPOTHESIS: <SOS> and , you &apos;re to , , , ,
#
# SOURCE: 术语 是 我们 理解 你们 想法 的 一个 障碍 <EOS>
# REFERENCE: jargon is a barrier to our understanding of your
# HYPOTHESIS: <SOS> and is the . of we . . <EOS>
#
# SOURCE: 当然 了 你们 可以 说 空间 <UNK> 与 <UNK> <UNK>
# REFERENCE: sure , you can say &quot; spatial and temporal
# HYPOTHESIS: <SOS> and course you you be the &quot; , &quot;
#
# SOURCE: 让 你们 的 想法 简单 单易 易懂 <UNK> 不等 等于
# REFERENCE: and making your ideas accessible is not the same
# HYPOTHESIS: <SOS> and &apos;s you , , you you , ,
#
# SOURCE: 相反 正如 爱因斯坦 因斯 坦 所说 让 一切 尽可 尽可能
# REFERENCE: instead , as einstein said , make everything as
# HYPOTHESIS: <SOS> and , the &apos;s einstein , &quot; , ,
#
# SOURCE: 你 不必 非得 改变 你 的 观点 才能 清楚 地
# REFERENCE: you can clearly communicate your science without compromising the
# HYPOTHESIS: <SOS> you don &apos;t your your your , and ,
#
# SOURCE: 可以 考虑 用 一些 例子 故事 还有 类比 这些 都
# REFERENCE: a few things to consider are having examples ,
# HYPOTHESIS: <SOS> they are of , the , , , and
#
# SOURCE: 还有 在 用 幻灯 幻灯片 演示 你们 的 研究 研究成果
# REFERENCE: and when presenting your work , drop the bullet
# HYPOTHESIS: <SOS> and , the &apos;re the , the , the
#
# SOURCE: 你 想 过为 为什么 什么 点 <UNK> 符号 <UNK> 子弹
# REFERENCE: have you ever wondered why they &apos;re called bullet
# HYPOTHESIS: <SOS> you you ever to to &quot; &apos;s &apos;t to
#
# SOURCE: 子弹 是 干什么 什么 的 子弹 能 杀人 也 能
# REFERENCE: what do bullets do ? bullets kill , and
# HYPOTHESIS: <SOS> it &apos;s the mean ? ? ? not ,
#
# SOURCE: 像 这样 的 幻灯 幻灯片 不仅 不仅仅 仅仅 乏味 无聊
# REFERENCE: a slide like this is not only boring ,
# HYPOTHESIS: <SOS> and &apos;s of the , , . . .
#
# SOURCE: 而 这 张 由 <UNK> brown 制作 的 示例 幻灯
# REFERENCE: instead , this example slide by <UNK> brown is
# HYPOTHESIS: <SOS> and this this &apos;s the <UNK> the <UNK> ,
#
# SOURCE: 这里 的 窍门 就是 使用 简单 <UNK> 的 句子 让
# REFERENCE: and the trick here is to use a single
# HYPOTHESIS: <SOS> the &apos;s &apos;s is is that <UNK> the <UNK>
#
# SOURCE: 以上 这些 就是 我 觉得 能够 帮助 我们 大家 打开
# REFERENCE: so i think these are just a few keys
# HYPOTHESIS: <SOS> and , &apos;s that &apos;s the that of of
#
# SOURCE: 那么 因为 与 我 共事 过 的 工程 工程师 们
# REFERENCE: and because the engineers that i &apos;ve worked with
# HYPOTHESIS: <SOS> and , , , of i me to to
#
# SOURCE: 用 你们 研究 的 科学 减去 你们 的 点 <UNK>
# REFERENCE: take your science , subtract your bullet points and
# HYPOTHESIS: <SOS> you , your , , see . . <EOS>
#
# SOURCE: 因此 科学 科学家 学家 和 工程 工程师 们 当 你们
# REFERENCE: and so , scientists and engineers , when you
# HYPOTHESIS: <SOS> so the the the the the , you you
#
# SOURCE: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . much . <EOS> . <EOS> <EOS>
#
# SOURCE: 我 很 喜欢 的 词 之一 在 整个 牛津 英语
# REFERENCE: one of my favorite words in the whole of
# HYPOTHESIS: <SOS> i &apos;m my favorite is in <UNK> , of
#
# SOURCE: 不仅 因为 它 听起 起来 很 不错 <EOS> <PAD> <PAD>
# REFERENCE: just because it sounds so good . <EOS> <PAD>
# HYPOTHESIS: <SOS> it , it &apos;s &apos;t . . <EOS> &apos;s
#
# SOURCE: 而且 它 的 意思 是 一个 <UNK> 的 政客 <EOS>
# REFERENCE: and what <UNK> means is &quot; a dishonest politician
# HYPOTHESIS: <SOS> and it it it is is the &quot; of
#
# SOURCE: 尽管 这 只是 一个 19 世纪 的 报纸 编辑 给出
# REFERENCE: although there was a 19th-century newspaper editor who defined
# HYPOTHESIS: <SOS> and , is a a of the the a
#
# SOURCE: 我 一点 一点儿 点儿 也 不明 明白 <UNK> 是 什么
# REFERENCE: now i have no idea what &quot; <UNK> &quot;
# HYPOTHESIS: <SOS> i i i &apos;t say , , &apos;m ,
#
# SOURCE: 大概 是 和 言语 语词 词汇 相关 的 词汇 我
# REFERENCE: something to do with words , i assume .
# HYPOTHESIS: <SOS> the , the , , , i i to
#
# SOURCE: 但是 言语 语词 词汇 对于 政治 中心 之 作用 是非
# REFERENCE: but it &apos;s very important that words are at
# HYPOTHESIS: <SOS> but it , not , to it &apos;s it
#
# SOURCE: 举例 举例来说 来说 一直 直到 <UNK> 年 英国 <UNK> <UNK>
# REFERENCE: it wasn &apos;t until , for example , <UNK>
# HYPOTHESIS: <SOS> the &apos;s like a , , was , the
#
# SOURCE: 而且 实际 实际上 这 全 是因为 因为 一个 勇敢 勇敢的人
# REFERENCE: and this was actually all down to the bravery
# HYPOTHESIS: <SOS> and it fact actually because because because because because
#
# SOURCE: 他 被 丢到 了 伦敦 塔里 遭到 囚禁 但是 他
# REFERENCE: and he was thrown into the tower of london
# HYPOTHESIS: <SOS> he he he a , the , , and
#
# SOURCE: 而且 仅仅 几年 年后 我们 有 了 第一 第一次 一次
# REFERENCE: and it was only a few years later that
# HYPOTHESIS: <SOS> and , , out , , , years we
#
# SOURCE: 很多 人 认为 这个 短语 出自 出自于 金属 什么 的
# REFERENCE: most people think that &apos;s down to the metal
# HYPOTHESIS: <SOS> people people people this &apos;s is , this .
#
# SOURCE: 不是 的 它 是 出自 出自于 一个 新闻 新闻自由 自由
# REFERENCE: it &apos;s not . it &apos;s down to a
# HYPOTHESIS: <SOS> but it not . it &apos;s a a the
#
# SOURCE: 不过 过为 为了 真实 的 表明 词汇 和 政治 怎样
# REFERENCE: but to really show you how words and politics
# HYPOTHESIS: <SOS> but the &apos;s the , the to do the
#
# SOURCE: 那时 他们 有 一个 问题 要 面对 就是 怎样 称号
# REFERENCE: and they had to face the question of what
# HYPOTHESIS: <SOS> and they they a a a a , they
#
# SOURCE: 他们 不知 知道 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: they didn &apos;t know . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> they don &apos;t want . . <EOS> <EOS> .
#
# SOURCE: 应该 <UNK> 一个 共和 共和国 的 领袖 为什么 什么 <EOS>
# REFERENCE: what do you call the leader of a republican
# HYPOTHESIS: <SOS> the &apos;s the do the the ? the ?
#
# SOURCE: 就 这个 问题 在 国会 会上 争论 了 很久 很久很久
# REFERENCE: and this was debated in congress for ages and
# HYPOTHESIS: <SOS> and this this is in the , and ,
#
# SOURCE: 并且 产生 了 很多 建议 这些 建议 貌似 <UNK> 可行
# REFERENCE: and there were all sorts of suggestions on the
# HYPOTHESIS: <SOS> and , there many lot many things , the
#
# SOURCE: 我 的 意思 是 一些 人 想 叫 他 为
# REFERENCE: i mean , some people wanted him to be
# HYPOTHESIS: <SOS> i mean , i &apos;s the it be to
#
# SOURCE: 没有 一个 <UNK> <UNK> 上口 的 名字 <EOS> <PAD> <PAD>
# REFERENCE: not that catchy . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> it &apos;s a the . <UNK> <EOS> . <EOS>
#
# SOURCE: 一些 人 只是 想 叫 他国 国王 <EOS> <PAD> <PAD>
# REFERENCE: some people just wanted to call him king .
# HYPOTHESIS: <SOS> and is people the the be the . .
#
# SOURCE: 他们 认为 是 个 称号 是 过去 用 过 <UNK>
# REFERENCE: they thought it was tried and tested . <EOS>
# HYPOTHESIS: <SOS> they they , &quot; a . be . <EOS>
#
# SOURCE: 他们 甚至 并 没有 延续 君主 君主制 他们 的 主意
# REFERENCE: and they weren &apos;t even being <UNK> there ,
# HYPOTHESIS: <SOS> they don don &apos;t the to to to they
#
# SOURCE: 你 知道 的 这样 大概 会 可行 <EOS> <PAD> <PAD>
# REFERENCE: and , you know , it could have worked
# HYPOTHESIS: <SOS> you know know know the this &apos;s a be
#
# SOURCE: 而且 每 一个 个人 都 感到 神经 <UNK> 错乱 似地
# REFERENCE: and everybody got insanely bored , actually , because
# HYPOTHESIS: <SOS> and every &apos;s a a , the it a
#
# SOURCE: 我 读 过 一个 当时 可怜 议员 的 日记 里面
# REFERENCE: i read a diary of this poor senator ,
# HYPOTHESIS: <SOS> i i a a of a , , ,
#
# SOURCE: 而 致使 <UNK> 和 厌倦 的 原因 是 众议 众议院
# REFERENCE: and the reason for the delay and the boredom
# HYPOTHESIS: <SOS> and the &apos;s is the is is the is
#
# SOURCE: 众议 众议院 议院 不想 让 华盛 华盛顿 沉醉 <UNK> 权力
# REFERENCE: the house of representatives didn &apos;t want washington to
# HYPOTHESIS: <SOS> the the of the , the want to be
#
# SOURCE: 他们 不想 称 他 为 国王 以防 以防万一 万一 他
# REFERENCE: they didn &apos;t want to call him king in
# HYPOTHESIS: <SOS> they didn &apos;t have to to to , &quot;
#
# SOURCE: 所以 他们 给 他 一个 他们 能够 想到 的 最低
# REFERENCE: so they wanted to give him the <UNK> ,
# HYPOTHESIS: <SOS> so they they him to them a to to
#
# SOURCE: 而 这个 个头 头衔 叫 <UNK> <EOS> <PAD> <PAD> <PAD>
# REFERENCE: and that title was &quot; president . &quot; <EOS>
# HYPOTHESIS: <SOS> and this is the . . . &quot; <EOS>
#
# SOURCE: <UNK> 会议 主持 总统 他们 没有 创造 这个 个头 头衔
# REFERENCE: president . they didn &apos;t invent the title .
# HYPOTHESIS: <SOS> the , <UNK> , &apos;t want it . .
#
# SOURCE: 同 陪审 陪审团 主席 的 意思 相似 <EOS> <PAD> <PAD>
# REFERENCE: it was like the foreman of the jury .
# HYPOTHESIS: <SOS> it &apos;s a a . of . . .
#
# SOURCE: 并且 它 一点 也 不显 显得 非常 极其 地位 <UNK>
# REFERENCE: and it didn &apos;t have much more grandeur than
# HYPOTHESIS: <SOS> and it it not be to be to to
#
# SOURCE: 虽然 偶尔 会 有 一些 些小 小型 殖民 殖民地 的
# REFERENCE: there were occasional presidents of little colonial councils and
# HYPOTHESIS: <SOS> and , a of , the who , ,
#
# SOURCE: 而且 这 也 是 为什么 什么 参议 参议院 议院 反对
# REFERENCE: and that &apos;s why the senate objected to it
# HYPOTHESIS: <SOS> and , &apos;s why the &apos;s of the the
#
# SOURCE: 他们 说 这个 真的 很 荒谬 你们 不能 叫 他
# REFERENCE: they said , that &apos;s ridiculous , you can
# HYPOTHESIS: <SOS> they said this &quot; well a . . i
#
# SOURCE: 这个 个人 还 得 去 <UNK> 条约 和 接见 <UNK>
# REFERENCE: this guy has to go and sign treaties and
# HYPOTHESIS: <SOS> the &apos;s is to <UNK> with to to the
#
# SOURCE: 谁 还 会 认真 认真对待 真对 对待 他 如果 他
# REFERENCE: and who &apos;s going to take him seriously if
# HYPOTHESIS: <SOS> who &apos;s &apos;s , , say , , ,
#
# SOURCE: 之后 经过 三周 的 辩论 最后 参议 参议院 议院 也
# REFERENCE: and after three weeks of debate , in the
# HYPOTHESIS: <SOS> and , , , , the , the the
#
# SOURCE: 作为 替代 他们 同意 先用 着 头衔 <UNK> 但 他们
# REFERENCE: instead , they agreed to use the title &quot;
# HYPOTHESIS: <SOS> they , they &apos;re &apos;t to , , ,
#
# SOURCE: 现在 从 这个 故事 里 你 能够 了解 到 三件
# REFERENCE: now you can learn three interesting things from this
# HYPOTHESIS: <SOS> now , this see this this , , you
#
# SOURCE: 首先 也 是 我 最 喜欢 的 地方 到 目前
# REFERENCE: first of all -- and this is my favorite
# HYPOTHESIS: <SOS> and , the , i i was the favorite
#
# SOURCE: 巴拉 巴拉克 拉克 奥巴 奥巴马 巴马 总统 奥巴 奥巴马 巴马
# REFERENCE: barack obama , president obama , is there on
# HYPOTHESIS: <SOS> the , : the , <UNK> the the the
#
# SOURCE: 第二 第二件 二件 事 你 可以 了解 到 当 美国
# REFERENCE: second thing you can learn is that when a
# HYPOTHESIS: <SOS> the the , you going you you you you
#
# SOURCE: 但 第三 第三件 三件 事 你 能 了解 到 的
# REFERENCE: but the third thing you can learn , and
# HYPOTHESIS: <SOS> but the , thing you you to is is
#
# SOURCE: 大概 是 有着 超过 5000 多 的 核弹 核弹头 弹头
# REFERENCE: something to do with the slightly over 5,000 nuclear
# HYPOTHESIS: <SOS> the is the about , percent of percent percent
#
# SOURCE: 现实 和 历史 赋予 了 这个 个头 头衔 高贵 的
# REFERENCE: reality and history have endowed that title with grandeur
# HYPOTHESIS: <SOS> and , the , this this , , <EOS>
#
# SOURCE: 所以 最后 参议 参议院 议院 赢 了 <EOS> <PAD> <PAD>
# REFERENCE: and so the senate won in the end .
# HYPOTHESIS: <SOS> so , , &apos;s is . <EOS> . .
#
# SOURCE: 他们 得到 了 他们 要 的 体面 头衔 <EOS> <PAD>
# REFERENCE: they got their title of respectability . <EOS> <PAD>
# HYPOTHESIS: <SOS> they they them their . . . <EOS> <EOS>
#
# SOURCE: 而且 参议 参议院 议院 担心 的 另 一件 事 这个
# REFERENCE: and also , the senate &apos;s other worry ,
# HYPOTHESIS: <SOS> and , &apos;s the &apos;s of the , ,
#
# SOURCE: 但是 现在 你 知道 现在 有 多少 个 国家 有
# REFERENCE: but now , do you know how many nations
# HYPOTHESIS: <SOS> but now you know know know that &apos;s is
#
# SOURCE: <UNK> 个 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: a hundred and forty-seven . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> &quot; . . . . <EOS> . <EOS> <EOS>
#
# SOURCE: 这 都 是因为 因为 他们 想 让 自己 的 头衔
# REFERENCE: all because they want to sound like the guy
# HYPOTHESIS: <SOS> and &apos;s the &apos;s &apos;t be the because they
#
# SOURCE: 所以 到 最后 参议 参议院 议院 胜利 了 众议 众议院
# REFERENCE: and so , in the end , the senate
# HYPOTHESIS: <SOS> so , the &apos;s &apos;s , of the &apos;s
#
# SOURCE: 而且 这 是 很重 重要 的 一 课 我 认为
# REFERENCE: and that &apos;s the important lesson i think you
# HYPOTHESIS: <SOS> and , &apos;s the of news , i to
#
# SOURCE: 政客 们 小心 小心翼翼 翼翼 地 选择 用词 并 利用
# REFERENCE: politicians try to pick words and use words to
# HYPOTHESIS: <SOS> and , to get the the , , .
#
# SOURCE: 非常 非常感谢 感谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you very much . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you very much . <EOS> <EOS> <EOS> .
#
# SOURCE: 我 是 跟着 50 个 去往 <UNK> 拉拉 拉巴 巴德
# REFERENCE: so i arrived by truck with about 50 rebels
# HYPOTHESIS: <SOS> i &apos;m &apos;m a the , the , years
#
# SOURCE: 我 用 我 的 黑色 <UNK> 威 的 低 邦
# REFERENCE: i traded my converse black <UNK> for a pair
# HYPOTHESIS: <SOS> i i my my , my and and ,
#
# SOURCE: 这 是 我 第一 第一次 一次 到 阿富汗 <EOS> <PAD>
# REFERENCE: and this was my first time in afghanistan .
# HYPOTHESIS: <SOS> this is is the first . . <EOS> .
#
# SOURCE: 早先 我 在 战争 中长 长大 周末 在 朋友 朋友家
# REFERENCE: long before that i had grown up with the
# HYPOTHESIS: <SOS> and , i was i in in in the
#
# SOURCE: 但 这 就是 自我 的 形成 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: but this is the geography of self . <EOS>
# HYPOTHESIS: <SOS> but that &apos;s the the of . . <EOS>
#
# SOURCE: 因此 我 今天 站 在 这里 流 着 阿富汗 的
# REFERENCE: and so i stand here today , afghan by
# HYPOTHESIS: <SOS> so i i i to , this i &apos;s
#
# SOURCE: 在 阿富汗 你 可以 通过 艺术 艺术作品 作品 创造 展示
# REFERENCE: now there are a lot of wonderful things that
# HYPOTHESIS: <SOS> in in you be you of you in in
#
# SOURCE: 我 想 跟 一名 圣战 分子 生活 一天 他 穿着
# REFERENCE: i want to spend a day in the life
# HYPOTHESIS: <SOS> i i to talk a a of a ,
#
# SOURCE: 这些 圣战 分子 除了 去 议会 参加 公众 的 选举
# REFERENCE: and where else can the <UNK> <UNK> go ,
# HYPOTHESIS: <SOS> these are these these the the of the the
#
# SOURCE: 我 尝试 试用 选举 来 解密 黑手 黑手党 的 成员
# REFERENCE: and try and use this campaign to expose these
# HYPOTHESIS: <SOS> i i i say , to of the the
#
# SOURCE: 我 想 通过 一个 叫做 <UNK> 的 作品 来看 看看
# REFERENCE: i want to look into corruption in afghanistan through
# HYPOTHESIS: <SOS> i i to talk a a <UNK> the <UNK>
#
# SOURCE: 我 想要 知道 并用 我 的 观点 来 阐释 阿富汗
# REFERENCE: i want to look at how , in my
# HYPOTHESIS: <SOS> i i to tell my my point &apos;m my
#
# SOURCE: 战争 和 被 驱逐 的 生活 怎样 制造 了 这个
# REFERENCE: the war and the <UNK> life that comes with
# HYPOTHESIS: <SOS> and , of the , of the the the
#
# SOURCE: 而且 我 还 想 把 一辆 简单 喀布尔 布尔 手推
# REFERENCE: and i &apos;d like to look at how taking
# HYPOTHESIS: <SOS> and i &apos;m going to talk you a a
#
# SOURCE: 不过 做 这些 事儿 你 可能 会 进 监狱 它们
# REFERENCE: but doing these things , they can get you
# HYPOTHESIS: <SOS> but the the this , you you be you
#
# SOURCE: 不过 我 做 我 必须 做 的 事 因为 我
# REFERENCE: but i do them because i have to ,
# HYPOTHESIS: <SOS> but i i &apos;t i i i &apos;t i
#
# SOURCE: 这 就是 我 的 负担 你 的 呢 <EOS> <PAD>
# REFERENCE: that is my burden . what &apos;s yours ?
# HYPOTHESIS: <SOS> so &apos;s what i . <EOS> <EOS> <EOS> ?
#
# SOURCE: 谢谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . <EOS> . <EOS> . <EOS> <EOS>
#
# SOURCE: 嗨 我 是 cameron russell 过去 的 一段 一段时间 段时间
# REFERENCE: hi . my name is cameron russell , and
# HYPOTHESIS: <SOS> i , i &apos;m is ted . . and
#
# SOURCE: 其实 我 干 了 10 年 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: actually , for 10 years . <EOS> <PAD> <PAD>
# HYPOTHESIS: <SOS> and i i . . . <EOS> <EOS> <EOS>
#
# SOURCE: 现在 我 在 这个 房间 房间内 感到 一种 令人 不适
# REFERENCE: and i feel like there &apos;s an uncomfortable tension
# HYPOTHESIS: <SOS> now , i going this this a little of
#
# SOURCE: <UNK> 我 带 了 另外 一套 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: so luckily i brought an outfit change . <EOS>
# HYPOTHESIS: <SOS> and : i i a a . <EOS> <EOS>
#
# SOURCE: 这 是 ted 讲台 台上 第一 第一次 一次 现场 <UNK>
# REFERENCE: this is the first outfit change on the ted
# HYPOTHESIS: <SOS> this is the first of of the the .
#
# SOURCE: 如果 有些 女士 对 的 我 出现 感到 惊恐 不必
# REFERENCE: if some of the women were really horrified when
# HYPOTHESIS: <SOS> and if &apos;s me sudden , me , ,
#
# SOURCE: 我 也 想 告诉 各位 我 有幸 能够 在 10
# REFERENCE: i &apos;d also note that i &apos;m quite privileged
# HYPOTHESIS: <SOS> i i going to to i i &apos;t to
#
# SOURCE: 这 不是 所有 所有人 有人 都 能 做 得到 的
# REFERENCE: not everybody gets to do that . <EOS> <PAD>
# HYPOTHESIS: <SOS> this &apos;s not &apos;t , , , &apos;s &apos;s
#
# SOURCE: 这双 <UNK> 高跟鞋 很 不 舒服 而 好消息 消息 是
# REFERENCE: these heels are very uncomfortable , so good thing
# HYPOTHESIS: <SOS> this &apos;s are &apos;t , , but they &apos;re
#
# SOURCE: 最 坏 的 消息 是 我 要 把 这件 毛衣
# REFERENCE: the worst part is putting this sweater over my
# HYPOTHESIS: <SOS> the , thing is that i to i i
#
# SOURCE: 可以 了 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: all right . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> it &apos;s . <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# SOURCE: 那么 我 为什么 什么 做 这个 呢 现场 <UNK> <EOS>
# REFERENCE: so why did i do that ? <EOS> <PAD>
# HYPOTHESIS: <SOS> and i i i do this this <EOS> <EOS>
#
# SOURCE: 这 很 怪 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: that was awkward . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> it is a . <EOS> <EOS> <EOS> <EOS> <EOS>
#
# SOURCE: 呃 希望 不会 像 图片 上 这样 怪 <EOS> <PAD>
# REFERENCE: well , hopefully not as awkward as that picture
# HYPOTHESIS: <SOS> it , it &apos;s it . . . .
#
# SOURCE: 图象 象是 强大 的 但 同时 又 是 表面 <UNK>
# REFERENCE: image is powerful , but also image is superficial
# HYPOTHESIS: <SOS> the &apos;s not , but it &apos;s but <EOS>
#
# SOURCE: 我 只是 在 6 秒 内 就 彻底 彻底改变 改变
# REFERENCE: i just totally transformed what you thought of me
# HYPOTHESIS: <SOS> i &apos;m just to in the in in in
#
# SOURCE: 在 这 张 照片 里 我 事实 事实上 在 现实
# REFERENCE: and in this picture , i had actually never
# HYPOTHESIS: <SOS> in in this , , i &apos;m &apos;t idea
#
# SOURCE: 当 摄影 摄影师 要 我 <UNK> 背 摸 那个 男士
# REFERENCE: i was totally uncomfortable , and the photographer was
# HYPOTHESIS: <SOS> when the to to by the i was said
#
# SOURCE: 确定 的 是 除了 手术 或 像 两天 前 我
# REFERENCE: and of course , barring surgery , or the
# HYPOTHESIS: <SOS> the , &apos;s , it &apos;s , , ,
#
# SOURCE: 所以 今天 对 我 来说 变 的 <UNK> 就 意味
# REFERENCE: so today , for me , being fearless means
# HYPOTHESIS: <SOS> so , the the me , the <UNK> <UNK>
#
# SOURCE: 今天 我 站 在 这里 是因为 因为 我 是 个
# REFERENCE: and i am on this stage because i am
# HYPOTHESIS: <SOS> and i &apos;m that , , , i &apos;m
#
# SOURCE: 我 在 这个 舞台 台上 是因为 因为 我 是 个
# REFERENCE: i am on this stage because i am a
# HYPOTHESIS: <SOS> i i this this room , i &apos;m a
#
# SOURCE: 我 要 回答 下人 人们 常常 问 我 的 那些
# REFERENCE: and i &apos;m going to answer the questions that
# HYPOTHESIS: <SOS> i i &apos;m to to show you a of
#
# SOURCE: 第一 第一个 一个 问题 是 你 是 怎么 成为 模特
# REFERENCE: so the first question is , how do you
# HYPOTHESIS: <SOS> the first first question is , you you you
#
# SOURCE: 我 总是 说 我 是 被 发现 的 但 这
# REFERENCE: and i always just say , &quot; oh ,
# HYPOTHESIS: <SOS> i i &apos;m , , i i i ,
#
# SOURCE: 我 成为 模特 的 真正 的 原因 是 我 拥有
# REFERENCE: the real way that i became a model is
# HYPOTHESIS: <SOS> i i i i my &apos;m is , ,
#
# SOURCE: 呃 在 过去 的 几个 世纪 里 我们 定义 里
# REFERENCE: well , for the past few centuries we have
# HYPOTHESIS: <SOS> in in the the , of years , we
#
# SOURCE: 这 就是 我 的 遗产 这 就是 我 一直 在
# REFERENCE: and this is a legacy that was built for
# HYPOTHESIS: <SOS> and &apos;s &apos;s what i i i &apos;m my
#
# SOURCE: 我 知道 你们 中 有些 人 可能 对 这个 观点
# REFERENCE: and i know there are people in the audience
# ...
# REFERENCE: many women had children strapped to their backs while
# HYPOTHESIS: <SOS> and are are &apos;t to the the their ,
#
# SOURCE: 汞 是 用来 提取 金子 的 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: mercury is used in the extraction process . <EOS>
# HYPOTHESIS: <SOS> it &apos;s the . . . . . <EOS>
#
# SOURCE: 这些 人 被 奴役 在 加纳 的 另 一处 矿井
# REFERENCE: these miners are enslaved in a mine shaft in
# HYPOTHESIS: <SOS> these are are were the the , of .
#
# SOURCE: 当 她们 走出 矿井 时 全身 <UNK> <EOS> <PAD> <PAD>
# REFERENCE: when they came out of the shaft , they
# HYPOTHESIS: <SOS> when they go to <UNK> the , , <EOS>
#
# SOURCE: 我 记得 他们 布满 <UNK> <UNK> <UNK> 的 眼睛 里
# REFERENCE: i remember looking into their tired , <UNK> eyes
# HYPOTHESIS: <SOS> i remember remember <UNK> the <UNK> , , <UNK>
#
# SOURCE: 这些 井 有 差不多 不多 有 90 多米 深 他们
# REFERENCE: the shafts are up to 300 feet deep ,
# HYPOTHESIS: <SOS> these are are are in the percent and the
#
# SOURCE: <UNK> <UNK> 之下 砸 石场 的 男人 个个 健壮 但
# REFERENCE: at first glance , the pounding site seems full
# HYPOTHESIS: <SOS> <UNK> <UNK> , , the &apos;s of , the
#
# SOURCE: 他们 都 是 <UNK> 暴力 的 受害 受害者 <EOS> <PAD>
# REFERENCE: all of them are victim to injury , illness
# HYPOTHESIS: <SOS> they are them are <UNK> . . . <EOS>
#
# SOURCE: 事实 事实上 这些 肌肉 强健 的 男人 若干 若干年 年后
# REFERENCE: in fact , it &apos;s very likely that this
# HYPOTHESIS: <SOS> in fact , the of out to to the
#
# SOURCE: 这 是 <UNK> 当 他 父亲 死 的 时候 他
# REFERENCE: this is <UNK> . when his father died ,
# HYPOTHESIS: <SOS> this is the <UNK> , &apos;s was , ,
#
# SOURCE: 在 他 叔叔 死 后 <UNK> 要 继续 背负 他
# REFERENCE: when his uncle died , <UNK> inherited his uncle
# HYPOTHESIS: <SOS> in he was was to he he , <UNK>
#
# SOURCE: 我 见到 他 时 他 已 在 矿场 工作 了
# REFERENCE: when i met him , he had been working
# HYPOTHESIS: <SOS> i i looked him , he he to to
#
# SOURCE: 除了 这个 伤 以外 他 还 患有 肺结核 结核 即使
# REFERENCE: on top of that , <UNK> has tuberculosis ,
# HYPOTHESIS: <SOS> and , , , , , was he ,
#
# SOURCE: 即使 <UNK> 如此 他 也 梦想 想着 能够 够重 重获
# REFERENCE: even still , he has a dream that he
# HYPOTHESIS: <SOS> and , he he he &apos;t , , he
#
# SOURCE: 我 希望 我们 给 这些 被 奴隶 的 人 一道
# REFERENCE: i want to shine a light on slavery .
# HYPOTHESIS: <SOS> i think we to that all of the the
#
# SOURCE: 当 我 在 拍摄 的 途中 我 带 了 很多
# REFERENCE: when i was working in the field , i
# HYPOTHESIS: <SOS> when i was a , i , , i
#
# SOURCE: 他们 知道 这些 影像 会 被 外面 的 人 看见
# REFERENCE: they knew their image would be seen by you
# HYPOTHESIS: <SOS> they know that they , the to to the
#
# SOURCE: 我 想要 让 他们 知道 我们 将 为 他们 作证
# REFERENCE: i wanted them to know that we will be
# HYPOTHESIS: <SOS> i i to tell them them we were to
#
# SOURCE: 我 确实 实相 相信 当 我们 把 他们 当做 同胞
# REFERENCE: i truly believe , if we can see one
# HYPOTHESIS: <SOS> and i to the we we &apos;s to ,
#
# SOURCE: 这些 影像 非 关于 议题 而是 关于 人 真实 的
# REFERENCE: these images are not of issues . they are
# HYPOTHESIS: <SOS> these are are the , , , the are
#
# SOURCE: 我 没有 一天 不想 这些 美丽 但 却 受到 不公
# REFERENCE: there is not a day that goes by that
# HYPOTHESIS: <SOS> i i a lot lot , i &apos;m ,
#
# SOURCE: 我 希望 这些 影像 能够 在 你们 这样 的 观者
# REFERENCE: i hope that these images awaken a force in
# HYPOTHESIS: <SOS> i i that these of are the the of
#
# SOURCE: 谢谢 大家 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you very much . <EOS> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . much . <EOS> <EOS> <EOS> .
#
# SOURCE: 话 说 我 是 学 应用 数学 的 对于 每
# REFERENCE: so , well , i do applied math ,
# HYPOTHESIS: <SOS> and , i &apos;m i &apos;m a to the
#
# SOURCE: 没人 知道 我们 是 干嘛 的 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: no one knows what the hell we do .
# HYPOTHESIS: <SOS> and , we we we &apos;re . <EOS> .
#
# SOURCE: 所以 我 今天 天会 给 你们 一些 实例 来 解释
# REFERENCE: so i am going to give you some --
# HYPOTHESIS: <SOS> so i i going to show you a little
#
# SOURCE: 嗯 跳舞 是 人类 众多 的 活动 之一 <EOS> <PAD>
# REFERENCE: so , dancing is one of the most human
# HYPOTHESIS: <SOS> well , &apos;s &apos;s the . the . of
#
# SOURCE: 我们 会 因 芭蕾 芭蕾舞 大师 和 <UNK> <UNK> 舞蹈
# REFERENCE: we delight at ballet virtuosos and tap dancers you
# HYPOTHESIS: <SOS> we we to , , , the <UNK> <UNK>
#
# SOURCE: 如今 芭蕾 需要 非凡 的 专业 专业知识 知识 和 杰出
# REFERENCE: now , ballet requires an extraordinary level of expertise
# HYPOTHESIS: <SOS> and &apos;s the &apos;s the to of of the
#
# SOURCE: 不过 可悲 的 是 神经 神经系 神经系统 系统 <UNK> 疾病
# REFERENCE: now , sadly , neurological disorders such as parkinson
# HYPOTHESIS: <SOS> but what the &apos;s the &apos;s is been is
#
# SOURCE: 这些 年 他 接受 受过 很多 治疗 也 有 很大
# REFERENCE: so great progress and treatment has been made over
# HYPOTHESIS: <SOS> and he he he he &apos;s his a to
#
# SOURCE: 然而 世上 上有 <UNK> 万 的 人 患有 这种 疾病
# REFERENCE: however , there are 6.3 million people worldwide who
# HYPOTHESIS: <SOS> and , the &apos;s a who people the the
#
# SOURCE: 我们 需要 客观 地 测量 进展 最后 想要 知道 何时
# REFERENCE: we need to be able to measure progression objectively
# HYPOTHESIS: <SOS> we we to make the to go a and
#
# SOURCE: 但 令人 <UNK> 的 是 帕金森 帕金森症 和 其他 运动
# REFERENCE: but <UNK> , with parkinson &apos;s disease and other
# HYPOTHESIS: <SOS> but the &apos;s is , , , , the
#
# SOURCE: 你 必须 得到 诊所 去 而且 花费 相当 相当 大
# REFERENCE: you have to go to the clinic to do
# HYPOTHESIS: <SOS> you you to get the to the , the
#
# SOURCE: 但 如果 病人 能 在家 完成 这个 测试 呢 <EOS>
# REFERENCE: but what if patients could do this test at
# HYPOTHESIS: <SOS> but what people people do to this ? <EOS>
#
# SOURCE: 这 也 能 为 病人 节省 节省下 那段 去 诊所
# REFERENCE: now , that would actually save on a difficult
# HYPOTHESIS: <SOS> it &apos;s it &apos;s a a a lot world
#
# SOURCE: 就 不 需要 花 大量 的 钱 去 雇佣 员工
# REFERENCE: no expensive staff time required . <EOS> <PAD> <PAD>
# HYPOTHESIS: <SOS> not &apos;s no , not to to , ,
#
# SOURCE: 顺便 提下 如果 去 神经 神经科 诊所 做 的话 这个
# REFERENCE: takes about $ 300 , by the way ,
# HYPOTHESIS: <SOS> and , to , , the the way ,
#
# SOURCE: 所以 我 想 向 你们 提出 一个 非常 非常规 常规
# REFERENCE: so what i want to propose to you as
# HYPOTHESIS: <SOS> so i want want going show you you a
#
# SOURCE: 我 这里 有 一个 关于 声 <UNK> 颤动 的 视频
# REFERENCE: so here we have a video of the vibrating
# HYPOTHESIS: <SOS> i &apos;m &apos;m a a <UNK> of <UNK> <UNK>
#
# SOURCE: 这个 是 健康 状态 下 的 某人 在 发声 我们
# REFERENCE: now , this is healthy and this is somebody
# HYPOTHESIS: <SOS> this is is is a example , , ,
#
# SOURCE: 而且 和 芭蕾 一样 这 也 需要 经过 特殊 地
# REFERENCE: and like ballet , it takes an extraordinary level
# HYPOTHESIS: <SOS> and &apos;s &apos;s it this &apos;s like to to
#
# SOURCE: 可以 想一想 小孩 学说 <UNK> 说话 得 花 多长 多长时间
# REFERENCE: i mean , just think how long it takes
# HYPOTHESIS: <SOS> it &apos;s &apos;t it &apos;s , &apos;s is ,
#
# SOURCE: 从 声音 里 我们 可以 追寻 <UNK> 声 <UNK> 颤动
# REFERENCE: from the sound , we can actually track the
# HYPOTHESIS: <SOS> and , , , we can to a to
#
# SOURCE: 你 可以 看到 到底 底部 的 颤动 轨迹 是 一种
# REFERENCE: so on the bottom trace , you can see
# HYPOTHESIS: <SOS> you you can you of you you see see
#
# SOURCE: 我们 看到 了 一样 的 症状 <EOS> <PAD> <PAD> <PAD>
# REFERENCE: we see all the same symptoms . <EOS> <PAD>
# HYPOTHESIS: <SOS> we we the the . . . <EOS> .
#
# SOURCE: 声音 颤动 虚弱 和 僵化 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: we see vocal tremor , weakness and <UNK> .
# HYPOTHESIS: <SOS> and , to the . <EOS> . <EOS> .
#
# SOURCE: 讲话 会 变得 <UNK> 而且 之后 伴随 更多 气息 音
# REFERENCE: the speech actually becomes quieter and more <UNK> after
# HYPOTHESIS: <SOS> the , is the the to and the ,
#
# SOURCE: 事实 事实上 这些 声效 大部 大部分 部分 分时 时候 挺
# REFERENCE: so these vocal effects can actually be quite subtle
# HYPOTHESIS: <SOS> in fact fact these are the the to to
#
# SOURCE: 那么 这些 以 语音 为 基础 的 测试 他们 会
# REFERENCE: so these <UNK> tests , how do they stack
# HYPOTHESIS: <SOS> and , these are , the the they make
#
# SOURCE: 神经 神经学 经学 测试 是 无 创 性 的 而且
# REFERENCE: the neurologist &apos;s test is non-invasive . they both
# HYPOTHESIS: <SOS> the is is a is , . &apos;s ,
#
# SOURCE: 你 无需 去 设计 一系 一系列 系列 新 的 医院
# REFERENCE: you don &apos;t have to design a whole new
# HYPOTHESIS: <SOS> you you &apos;t want to go a . .
#
# SOURCE: 他们 也 都 具有 精确 精确性 虽然 这么 说 但是
# REFERENCE: and they &apos;re both accurate . okay , but
# HYPOTHESIS: <SOS> they &apos;re they &apos;t to to , &apos;re ,
#
# SOURCE: 这 意味 意味着 患者 能 自己 搞定 <EOS> <PAD> <PAD>
# REFERENCE: that means they can be <UNK> . <EOS> <PAD>
# HYPOTHESIS: <SOS> it &apos;s what it be . . <EOS> .
#
# SOURCE: 而且 速度 也 快 最多 多只 只要 30 秒 <EOS>
# REFERENCE: they &apos;re high-speed , take about 30 seconds at
# HYPOTHESIS: <SOS> and &apos;s &apos;t to , , percent percent .
#
# SOURCE: 价格 很 低 我们 也 知道 是 怎么 一回 儿
# REFERENCE: they &apos;re <UNK> cost , and we all know
# HYPOTHESIS: <SOS> and , &apos;t , we we we &apos;re to
#
# SOURCE: 一旦 价格 价格低 价格低廉 低廉 它 也 就 能 被
# REFERENCE: when something becomes <UNK> cost , it becomes massively
# HYPOTHESIS: <SOS> and it it it , it it it like
#
# SOURCE: 我 这儿 有些 现在 能 拿出 出来 来说 的 伟大
# REFERENCE: so here are some amazing goals that i think
# HYPOTHESIS: <SOS> i i &apos;m the i of i i &apos;m
#
# SOURCE: 我们 能 减少 和 病人 有关 的 后勤 问题 <EOS>
# REFERENCE: we can reduce logistical difficulties with patients . <EOS>
# HYPOTHESIS: <SOS> we we going the the . <EOS> . <EOS>
#
# SOURCE: 没 必要 去 诊所 做 例行 的 检查 <EOS> <PAD>
# REFERENCE: no need to go to the clinic for a
# HYPOTHESIS: <SOS> it &apos;s the make the the the of the
#
# SOURCE: 我们 能 进行 高频 高频率 频率 的 监测 以 获取
# REFERENCE: we can do high-frequency monitoring to get objective data
# HYPOTHESIS: <SOS> we we going the the &apos;s , the to
#
# SOURCE: 我们 能 为 临床 临床试验 试验 组织 大量 <UNK> 且
# REFERENCE: we can perform low-cost mass recruitment for clinical trials
# HYPOTHESIS: <SOS> we we a a <UNK> , , , .
#
# SOURCE: 我们 也 有机 机会 开始 寻找 这种 疾病 在 <UNK>
# REFERENCE: we have the opportunity to start to search for
# HYPOTHESIS: <SOS> we we going very of do the this the
#
# SOURCE: 所以 从今 今天 天开 开始 朝 这个 方向 迈出 第一
# REFERENCE: so , taking the first steps towards this today
# HYPOTHESIS: <SOS> so , the , , of , this ,
#
# SOURCE: 和 <UNK> 还有 <UNK> 一起 合作 我们 希望 记录 录下
# REFERENCE: with <UNK> and <UNK> , we &apos;re aiming to
# HYPOTHESIS: <SOS> and <UNK> , , , we &apos;re to to
#
# SOURCE: 我们 的 <UNK> 号码 能 接通 地球 上 7 亿
# REFERENCE: we have local numbers accessible to three quarters of
# HYPOTHESIS: <SOS> our have <UNK> <UNK> , the the percent of
#
# SOURCE: 任何 健康 或者 患有 帕金森 疾病 的 人 都 能
# REFERENCE: anyone healthy or with parkinson &apos;s can call in
# HYPOTHESIS: <SOS> and , the , , , who , be
#
# SOURCE: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . much . <EOS> . <EOS> <EOS>
#
# SOURCE: max 靠着 这些 采样 不妨 说 在 一万 人 中
# REFERENCE: so max , by taking all these samples of
# HYPOTHESIS: <SOS> and : &apos;s , , , , , ,
#
# SOURCE: 你 又 想 从 这些 采样 中 得出 什么 呢
# REFERENCE: what are you going to get out of those
# HYPOTHESIS: <SOS> you you you going to do ? ? these
#
# SOURCE: 对 是 的 所以 以是 这样 的 在 来电 期间
# REFERENCE: yeah . yeah . so what will happen is
# HYPOTHESIS: <SOS> it &apos;s it &apos;s so &apos;s &apos;s &apos;re do
#
# SOURCE: 要 知道 有些 人 可能 不会 打 给 我们 或者
# REFERENCE: you see , some people may not do it
# HYPOTHESIS: <SOS> and , , people &apos;s people &apos;t , to
#
# SOURCE: 但 我们 还是 会 得到 大量 来自 不同 环境 下
# REFERENCE: but we &apos;ll get a very large sample of
# HYPOTHESIS: <SOS> but we &apos;re &apos;t that to of for ,
#
# SOURCE: 所以 你 现在 拥有 86 的 准确 准确率 了 <EOS>
# REFERENCE: so you &apos;re 86 percent accurate right now ?
# HYPOTHESIS: <SOS> so you you to to to the . <EOS>
#
# SOURCE: 已经 远远 远不止 不止 了 <EOS> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: it &apos;s much better than that . <EOS> <PAD>
# HYPOTHESIS: <SOS> it &apos;s very . . . . . .
#
# SOURCE: 事实 事实上 我 的 学生 <UNK> 我 得 提 一下
# REFERENCE: actually , my student <UNK> , i have to
# HYPOTHESIS: <SOS> in fact my my , my who i my
#
# SOURCE: 九十 九十九 十九 好 吧 这 还 挺 了不起 的
# REFERENCE: ninety-nine . well , that &apos;s an improvement .
# HYPOTHESIS: <SOS> and , a , it , a . .
#
# SOURCE: 所以 这 也 意味 意味着 人们 能 笑 人们 能用
# REFERENCE: so what that means is that people will be
# HYPOTHESIS: <SOS> so , &apos;s means is that to is doing
#
# SOURCE: 就是 这样 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: absolutely . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> it &apos;s . . <EOS> . <EOS> <EOS> <EOS>
#
# SOURCE: 非常 非常感谢 感谢 max little 和 所有 所有人 有人 <EOS>
# REFERENCE: thanks so much . max little , everybody .
# HYPOTHESIS: <SOS> thank , . . . . , . ,
#
# SOURCE: 谢谢 你 tom 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thanks , tom . <EOS> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you you you you . <EOS> . <EOS>
#
# SOURCE: 自从 我 足够 大拿 拿起 相机 以来 我 一直 热衷
# REFERENCE: photography has been my passion ever since i was
# HYPOTHESIS: <SOS> i , i a me , i me me
#
# SOURCE: 没有 艺术 指导 没有 造型 <UNK> 没有 <UNK> 的 机会
# REFERENCE: there were no art directors , no <UNK> ,
# HYPOTHESIS: <SOS> the , no of , , <UNK> <UNK> ,
#
# SOURCE: 事实 事实上 它们 大多 大多数 多数 是 随机 找来 的
# REFERENCE: in fact , most of them were taken by
# HYPOTHESIS: <SOS> in fact , they &apos;s the most the .
#
# SOURCE: 我 的 故事 源 起 于 有 一次 我 获
# REFERENCE: my story begins when i was in new york
# HYPOTHESIS: <SOS> my my , <UNK> , and , , ,
#
# SOURCE: 碰巧 一年 年后 我们 又 回到 了 纽约 纽约市 所以
# REFERENCE: we happened to be back in new york exactly
# HYPOTHESIS: <SOS> and , a we about in the , ,
#
# SOURCE: 你 可以 猜到 事情 是 怎么 发展 的 <EOS> <PAD>
# REFERENCE: well you can see where this is going .
# HYPOTHESIS: <SOS> you you you see the it are is .
#
# SOURCE: 接近 女儿 三岁 生日 时 妻子 说 嘿 你 为什么
# REFERENCE: approaching my daughter &apos;s third birthday , my wife
# HYPOTHESIS: <SOS> and , the , , , , , ,
#
# SOURCE: 也 就是 是从 这次 开始 我们 找 路上 的 游客
# REFERENCE: this is when we started asking passing tourists to
# HYPOTHESIS: <SOS> and &apos;s the the &apos;re the the the the
#
# SOURCE: 你们 知道 把 相机 递给 一个 完全 陌生 陌生人 生人
# REFERENCE: you know , it &apos;s remarkable how universal the
# HYPOTHESIS: <SOS> you know , you &apos;s a to that &apos;s
#
# SOURCE: 没有 有人 会 拒绝 幸运 的 是 也 没有 有人
# REFERENCE: no one &apos;s ever refused , and luckily no
# HYPOTHESIS: <SOS> nobody the who the to be be the the
#
# SOURCE: 那时 我们 并不知道 不知 知道 这样 的 旅程 会 深深
# REFERENCE: back then , we had no idea how much
# HYPOTHESIS: <SOS> and , we don we &apos;t idea that this
#
# SOURCE: 对 我们 而言 它 渐渐 渐变 变得 神圣 起来 <EOS>
# REFERENCE: it &apos;s really become sacred to us . <EOS>
# HYPOTHESIS: <SOS> and &apos;s us to to to it it it
#
# SOURCE: 这 张 是 在 911 的 几周 后 拍 的
# REFERENCE: this one was taken just weeks after 9 /
# HYPOTHESIS: <SOS> this is a the in the minutes the ,
#
# SOURCE: 所以 这些 照片 远远 远不止 不止 是 记录 了 一个
# REFERENCE: so these photos are far more than <UNK> for
# HYPOTHESIS: <SOS> so these &apos;s are are , , , ,
#
# SOURCE: 它们 是 我们 <UNK> 时间 的 方式 记住 10 月
# REFERENCE: they &apos;re also ways for us to freeze time
# HYPOTHESIS: <SOS> they are the <UNK> , we , the the
#
# SOURCE: 因为 我 每年 们 拍 同样 的 照片 我们 的
# REFERENCE: because while we take the same photo , our
# HYPOTHESIS: <SOS> because i think i , of of of i
#
# SOURCE: 这 是 我们 亲子 相处 的 时间 是 一年 里面
# REFERENCE: this very focused time we get to spend together
# HYPOTHESIS: <SOS> this is the , the we to in the
#
# SOURCE: 最近 一次 旅程 我们 在 路上 走 着 她 突然
# REFERENCE: recently , on one trip , we were walking
# HYPOTHESIS: <SOS> and , , we time , we &apos;ve a
#
# SOURCE: 她 向 我 形容 5 岁 的 时候 她 站
# REFERENCE: and she describes to me the feeling she felt
# HYPOTHESIS: <SOS> she , said me me , the , the
#
# SOURCE: 她 说 她 记得 第一 第一次 一次 看到 那个 地方
# REFERENCE: she said she remembers her heart bursting out of
# HYPOTHESIS: <SOS> she , , &quot; to she the she the
#
# SOURCE: 现在 她 去 纽约 关注 的 是 大学 大学校园 学校
# REFERENCE: and now what she &apos;s looking at in new
# HYPOTHESIS: <SOS> now , &apos;s &apos;s is was is is is
#
# SOURCE: 我 突然 明白 我们 创造 的 最重 重要 的 事情
# REFERENCE: and it hit me : one of the most
# HYPOTHESIS: <SOS> i i think out that the we the things
#
# SOURCE: 所以 我 希望 分享 这种 主动 且 有意 有意识 意识
# REFERENCE: so i want to share the idea of taking
# HYPOTHESIS: <SOS> so i i &apos;t think you you of this
#
# SOURCE: 我 不知 知道 你们 的 情况 但 我 个人 而言
# REFERENCE: i don &apos;t know about you , but aside
# HYPOTHESIS: <SOS> i don &apos;t know if you , but i
#
# SOURCE: 我 总是 那个 拿 相机 拍照 的 人 <EOS> <PAD>
# REFERENCE: i &apos;m always the one taking the picture .
# HYPOTHESIS: <SOS> i &apos;m not to to person . . .
#
# SOURCE: 我 希望 鼓励 今天 在座 的 各位 争取 取到 照片
# REFERENCE: so i want to encourage everyone today to get
# HYPOTHESIS: <SOS> i i i that to you to to the
#
# SOURCE: 谢谢 掌声 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# REFERENCE: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# HYPOTHESIS: <SOS> thank you . much . <EOS> . <EOS> <EOS>

# %%
# evaluate on test set 
test_loss, test_bleu, test_hyp_idxs, test_ref_idxs, test_source_idxs, test_hyp_tokens, test_ref_tokens, test_source_tokens,\
test_attn = evaluate(model=model, loader=loaders_full['test'], 
                     src_id2token=vocab[SRC_LANG]['id2token'], targ_id2token=vocab[TARG_LANG]['id2token'])
print("Test BLEU: {:.2f} | Test Loss: {:.2f}".format(test_bleu, test_loss))
# Out:
# WARNING:root:That's 100 lines that end in a tokenized period ('.')
# WARNING:root:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:root:If you insist your data is detokenized, or don't care, you can suppress this message with '--force'.
# Test BLEU: 8.55 | Test Loss: 4.89
