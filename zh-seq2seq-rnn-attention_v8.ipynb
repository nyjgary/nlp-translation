# %%
import numpy as np 
import pandas as pd 
from data_processing import generate_vocab, process_data, create_dataloaders, text2tokens
from model import get_pretrained_emb, EncoderDecoder, EncoderRNN, DecoderRNN, EncoderDecoderAttn, DecoderAttnRNN, \
    DecoderDotAttnRNN
from train_eval import count_parameters, summarize_results, plot_single_learning_curve, load_experiment_log
from train_eval import train_and_eval
import importlib
import pickle as pkl 
import torch

# %%
# model identification
MODEL_NAME = 'zh-seq2seq-rnn-dot-attn'
SRC_LANG = 'zh'
TARG_LANG = 'en'

# data processing params  
SRC_MAX_SENTENCE_LEN = 10
TARG_MAX_SENTENCE_LEN = 10
SRC_VOCAB_SIZE = 30000 #30000
TARG_VOCAB_SIZE = 30000 #30000

# model architecture params 
RNN_CELL_TYPE = 'gru'
NUM_LAYERS = 2 #2 
ENC_HIDDEN_DIM = 256 #512
DEC_HIDDEN_DIM = 2 * ENC_HIDDEN_DIM #2 * ENC_HIDDEN_DIM 
TEACHER_FORCING_RATIO = 1
CLIP_GRAD_MAX_NORM = 1
ENC_DROPOUT = 0.2 # to actually implement
DEC_DROPOUT = 0.2 # to actually implement
USE_ATTN = True

# training params  
BATCH_SIZE = 64 #32
NUM_EPOCHS = 200
LR = 0.0003 # 0.0005
OPTIMIZER = 'Adam'
LAZY_TRAIN = False

# %%
# store as dict to save to results later 
params = {'model_name': MODEL_NAME, 'src_lang': SRC_LANG, 'targ_lang': TARG_LANG, 'rnn_cell_type': RNN_CELL_TYPE, 
          'src_max_sentence_len': SRC_MAX_SENTENCE_LEN, 'targ_max_sentence_len': TARG_MAX_SENTENCE_LEN, 
          'src_vocab_size': SRC_VOCAB_SIZE, 'targ_vocab_size': TARG_VOCAB_SIZE, 
          'num_layers': NUM_LAYERS, 'enc_hidden_dim': ENC_HIDDEN_DIM, 'dec_hidden_dim': DEC_HIDDEN_DIM,
          'teacher_forcing_ratio': TEACHER_FORCING_RATIO, 'clip_grad_max_norm': CLIP_GRAD_MAX_NORM,
          'enc_dropout': ENC_DROPOUT, 'dec_dropout': DEC_DROPOUT, 'use_attn': USE_ATTN, 
          'batch_size': BATCH_SIZE, 'num_epochs': NUM_EPOCHS, 'learning_rate': LR, 'optimizer': OPTIMIZER, 
          'lazy_train': LAZY_TRAIN}

# %%
# # takes a long time to process, save to pickle for reimport in future 
# vocab = generate_vocab(SRC_LANG, TARG_LANG, SRC_VOCAB_SIZE, TARG_VOCAB_SIZE)
# vocab_filename = "{}-{}-vocab.p".format(SRC_LANG, TARG_LANG)
# pkl.dump(vocab, open(vocab_filename, "wb"))

# %%
# reload from pickle 
vocab_filename = "{}-{}-vocab.p".format(SRC_LANG, TARG_LANG)
vocab = pkl.load(open(vocab_filename, "rb"))
data = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, filter_long=False)
data_minibatch = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, sample_limit=BATCH_SIZE, filter_long=False) 
data_minitrain = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab, sample_limit=1000, filter_long=False)

# %%
# create dataloaders 
loaders_full = create_dataloaders(data, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)
loaders_minibatch = create_dataloaders(data_minibatch, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)
loaders_minitrain = create_dataloaders(data_minitrain, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)

# %%
# define model 

encoder = EncoderRNN(rnn_cell_type=RNN_CELL_TYPE, enc_hidden_dim=ENC_HIDDEN_DIM, num_layers=NUM_LAYERS, 
                     src_max_sentence_len=SRC_MAX_SENTENCE_LEN, enc_dropout=ENC_DROPOUT, 
                     pretrained_word2vec=get_pretrained_emb(vocab[SRC_LANG]['word2vec'], vocab[SRC_LANG]['token2id']))

# without attention 
decoder = DecoderRNN(dec_hidden_dim=DEC_HIDDEN_DIM, enc_hidden_dim=ENC_HIDDEN_DIM, num_layers=NUM_LAYERS,
                     targ_vocab_size=TARG_VOCAB_SIZE, targ_max_sentence_len=TARG_MAX_SENTENCE_LEN, 
                     pretrained_word2vec=get_pretrained_emb(vocab[TARG_LANG]['word2vec'], vocab[TARG_LANG]['token2id']))
model = EncoderDecoder(encoder, decoder, vocab[TARG_LANG]['token2id'])

# with attention 
# decoder = DecoderAttnRNN(rnn_cell_type=RNN_CELL_TYPE, dec_hidden_dim=DEC_HIDDEN_DIM, enc_hidden_dim=ENC_HIDDEN_DIM, 
#                          num_layers=NUM_LAYERS, targ_vocab_size=TARG_VOCAB_SIZE, src_max_sentence_len=SRC_MAX_SENTENCE_LEN, 
#                          targ_max_sentence_len=TARG_MAX_SENTENCE_LEN, dec_dropout=DEC_DROPOUT, 
#                          pretrained_word2vec=get_pretrained_emb(vocab[TARG_LANG]['word2vec'], vocab[TARG_LANG]['token2id']))
# model = EncoderDecoderAttn(encoder, decoder, vocab[TARG_LANG]['token2id']) 

# with dot attention 
decoder = DecoderDotAttnRNN(rnn_cell_type=RNN_CELL_TYPE, dec_hidden_dim=DEC_HIDDEN_DIM, enc_hidden_dim=ENC_HIDDEN_DIM, 
                         num_layers=NUM_LAYERS, targ_vocab_size=TARG_VOCAB_SIZE, src_max_sentence_len=SRC_MAX_SENTENCE_LEN, 
                         targ_max_sentence_len=TARG_MAX_SENTENCE_LEN, dec_dropout=DEC_DROPOUT, 
                         pretrained_word2vec=get_pretrained_emb(vocab[TARG_LANG]['word2vec'], vocab[TARG_LANG]['token2id']))
model = EncoderDecoderAttn(encoder, decoder, vocab[TARG_LANG]['token2id'])

# %%
model, results = train_and_eval(
    model=model, loaders_full=loaders_full, loaders_minibatch=loaders_minibatch, loaders_minitrain=loaders_minitrain, 
    params=params, vocab=vocab, print_intermediate=100, save_checkpoint=True, save_to_log=True, 
    lazy_eval=True, print_attn=True, inspect_samples=1)
# Out:
# Epoch: 0.00, Train Loss: 0.00, Val Loss: 10.22, Train BLEU: 0.00, Val BLEU: 0.21, Minutes Elapsed: 0.08
# Sampling from val predictions...
# Source: 她 两年 年前 退休 了 结果 却 把 我家 变成
# Reference: she retired two years ago , only to turn
# Model: <SOS> the the the the the the the the the
# Attention Weights: tensor([[0.0000, 0.0001, 0.0017, 0.0191, 0.2104, 0.1899, 0.4758, 0.1011, 0.0019,
#          0.0000],
#         [0.0015, 0.0039, 0.0185, 0.0621, 0.2173, 0.2102, 0.3286, 0.1397, 0.0169,
#          0.0015],
#         [0.0094, 0.0199, 0.0567, 0.1006, 0.1973, 0.1928, 0.2352, 0.1383, 0.0400,
#          0.0098],
#         [0.0248, 0.0425, 0.0912, 0.1195, 0.1787, 0.1703, 0.1828, 0.1198, 0.0500,
#          0.0203],
#         [0.0391, 0.0593, 0.1085, 0.1249, 0.1636, 0.1541, 0.1543, 0.1088, 0.0566,
#          0.0307],
#         [0.0516, 0.0710, 0.1146, 0.1248, 0.1560, 0.1464, 0.1409, 0.1005, 0.0579,
#          0.0362],
#         [0.0595, 0.0740, 0.1114, 0.1225, 0.1506, 0.1446, 0.1348, 0.0982, 0.0618,
#          0.0426],
#         [0.0670, 0.0814, 0.1123, 0.1219, 0.1474, 0.1410, 0.1289, 0.0936, 0.0615,
#          0.0450],
#         [0.0705, 0.0787, 0.1033, 0.1170, 0.1498, 0.1436, 0.1345, 0.0966, 0.0615,
#          0.0446]], grad_fn=<SelectBackward>)
#
# Epoch: 0.03, Train Loss: 0.00, Val Loss: 6.28, Train BLEU: 0.00, Val BLEU: 0.35, Minutes Elapsed: 1.63
# Sampling from val predictions...
# Source: 对 我 来说 这 是 人们 问 过 的 最
# Reference: to me , this is the saddest and most
# Model: <SOS> and the , , , , , , ,
# Attention Weights: tensor([[1.3459e-28, 8.2327e-08, 7.9856e-03, 3.2678e-01, 5.2375e-01, 1.3348e-01,
#          7.9922e-03, 1.2104e-05, 9.1516e-13, 4.5151e-36],
#         [3.1441e-15, 8.2024e-05, 4.5860e-02, 2.7335e-01, 3.7216e-01, 2.4796e-01,
#          5.7371e-02, 3.2195e-03, 1.0162e-06, 6.7545e-19],
#         [2.5628e-12, 3.9690e-04, 6.2571e-02, 2.6964e-01, 3.4224e-01, 2.4325e-01,
#          7.4677e-02, 7.2219e-03, 8.7734e-06, 7.6792e-16],
#         [1.2834e-11, 5.4551e-04, 6.1792e-02, 2.5209e-01, 3.2930e-01, 2.5355e-01,
#          9.1064e-02, 1.1628e-02, 2.6759e-05, 1.8092e-14],
#         [2.5836e-11, 6.2930e-04, 6.0934e-02, 2.4215e-01, 3.2140e-01, 2.5873e-01,
#          1.0116e-01, 1.4954e-02, 4.7060e-05, 7.8330e-14],
#         [4.3342e-11, 7.0103e-04, 6.0573e-02, 2.3595e-01, 3.1578e-01, 2.6127e-01,
#          1.0810e-01, 1.7554e-02, 6.6702e-05, 1.8598e-13],
#         [6.5234e-11, 7.6425e-04, 6.0413e-02, 2.3158e-01, 3.1147e-01, 2.6261e-01,
#          1.1334e-01, 1.9734e-02, 8.5804e-05, 3.4159e-13],
#         [9.0745e-11, 8.2059e-04, 6.0328e-02, 2.2832e-01, 3.0797e-01, 2.6324e-01,
#          1.1756e-01, 2.1648e-02, 1.0448e-04, 5.4125e-13],
#         [1.1981e-10, 8.6993e-04, 6.0210e-02, 2.2549e-01, 3.0489e-01, 2.6369e-01,
#          1.2129e-01, 2.3438e-02, 1.2352e-04, 7.8823e-13]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.06, Train Loss: 0.00, Val Loss: 6.16, Train BLEU: 0.00, Val BLEU: 0.79, Minutes Elapsed: 3.19
# Sampling from val predictions...
# Source: 太 不 简单 了 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: extraordinary . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> and &apos;s &apos;s . . . . . .
# Attention Weights: tensor([[0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0076, 0.9915, 0.0009, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.5089, 0.4910, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0410, 0.9590, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0056, 0.9944, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0013, 0.9987, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0005, 0.9995, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0002, 0.9998, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0002, 0.9998, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.09, Train Loss: 0.00, Val Loss: 6.09, Train BLEU: 0.00, Val BLEU: 1.34, Minutes Elapsed: 4.75
# Sampling from val predictions...
# Source: 有着 如此 肥沃 的 山谷 当地 当地人 人居 居然 不
# Reference: and we were amazed that the local people ,
# Model: <SOS> and , the the the the the the the
# Attention Weights: tensor([[1.7065e-38, 1.3337e-11, 2.3106e-03, 9.8180e-01, 1.5888e-02, 8.4378e-07,
#          1.1288e-19, 9.7769e-16, 3.0177e-13, 3.3581e-37],
#         [9.8259e-15, 7.6390e-03, 4.9577e-01, 4.7940e-01, 1.7172e-02, 2.1072e-05,
#          1.0071e-14, 3.2414e-12, 5.7209e-11, 2.4794e-24],
#         [1.1207e-06, 6.3320e-01, 3.1285e-01, 5.2911e-02, 1.0411e-03, 1.5284e-06,
#          1.2653e-15, 5.4303e-13, 1.8602e-11, 1.1926e-20],
#         [2.4092e-04, 9.4898e-01, 4.7962e-02, 2.7921e-03, 2.5685e-05, 2.0106e-08,
#          5.0264e-17, 9.2287e-14, 8.0431e-13, 2.1741e-21],
#         [3.9306e-04, 9.7121e-01, 2.7208e-02, 1.1777e-03, 7.7384e-06, 5.2662e-09,
#          1.8574e-17, 4.3313e-14, 5.2765e-13, 6.6086e-21],
#         [4.8467e-04, 9.7800e-01, 2.0717e-02, 7.9352e-04, 4.5670e-06, 3.1717e-09,
#          1.5462e-17, 3.4644e-14, 6.5986e-13, 2.1536e-20],
#         [6.2525e-04, 9.8103e-01, 1.7690e-02, 6.5519e-04, 3.5163e-06, 2.5241e-09,
#          1.4798e-17, 3.1463e-14, 9.5199e-13, 6.2727e-20],
#         [8.1372e-04, 9.8249e-01, 1.6097e-02, 5.9652e-04, 3.0151e-06, 2.1745e-09,
#          1.3541e-17, 2.9500e-14, 1.3879e-12, 1.5596e-19],
#         [1.0246e-03, 9.8329e-01, 1.5115e-02, 5.6812e-04, 2.7391e-06, 1.9927e-09,
#          1.3061e-17, 2.8481e-14, 2.0093e-12, 3.5638e-19]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.12, Train Loss: 0.00, Val Loss: 6.05, Train BLEU: 0.00, Val BLEU: 1.60, Minutes Elapsed: 6.30
# Sampling from val predictions...
# Source: 当 你 走出 这个 房间 的 时候 你们 就是 <UNK>
# Reference: when you walk out of this room , you
# Model: <SOS> and , , , , , , , ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0002, 0.0150, 0.9833, 0.0016, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.6789, 0.0008, 0.0011, 0.0071, 0.3045, 0.0077, 0.0000, 0.0000,
#          0.0000],
#         [0.8827, 0.1173, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9997, 0.0003, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9998, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9998, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9998, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9998, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9997, 0.0003, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.15, Train Loss: 0.00, Val Loss: 6.02, Train BLEU: 0.00, Val BLEU: 3.49, Minutes Elapsed: 7.85
# Sampling from val predictions...
# Source: 家长 <UNK> 意味 意味着 我 把 不同 文化 文化背景 背景
# Reference: <UNK> , i treat anybody from a different culture
# Model: <SOS> and &apos;s , , , , , , ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2074, 0.7926, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0104, 0.0192, 0.0000, 0.0000, 0.8546, 0.1156, 0.0001,
#          0.0000],
#         [0.9168, 0.0805, 0.0026, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9991, 0.0002, 0.0003, 0.0003, 0.0001, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.7795, 0.0001, 0.2202, 0.0002, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0033, 0.0000, 0.9966, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.21, Train Loss: 0.00, Val Loss: 5.85, Train BLEU: 0.00, Val BLEU: 3.31, Minutes Elapsed: 10.96
# Sampling from val predictions...
# Source: 每 一个 病例 的 情况 都 是 特殊 的 所以
# Reference: it manifests in each individual differently , hence why
# Model: <SOS> and &apos;s a the , , the and ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0047, 0.3961, 0.5992, 0.0000, 0.0000,
#          0.0000],
#         [0.0006, 0.9220, 0.0244, 0.0466, 0.0064, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.8113, 0.1887, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.1954, 0.8046, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0005, 0.0610, 0.0001, 0.0893, 0.7774, 0.0698, 0.0003, 0.0000, 0.0002,
#          0.0013],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0002, 0.0001, 0.0000, 0.0000, 0.0007,
#          0.9990],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0001,
#          0.9999],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0001,
#          0.9999],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          1.0000]], grad_fn=<SelectBackward>)
# Epoch: 0.24, Train Loss: 0.00, Val Loss: 5.83, Train BLEU: 0.00, Val BLEU: 3.11, Minutes Elapsed: 12.51
# Sampling from val predictions...
# Source: 所以 如果 摄影 摄影师 就 在 这里 灯光 就 在
# Reference: so if the photographer is right there and the
# Model: <SOS> and we we we , we the the the
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0009, 0.9196, 0.0001, 0.0794,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9846, 0.0000, 0.0000, 0.0151, 0.0000, 0.0000, 0.0000, 0.0003,
#          0.0000],
#         [0.0000, 0.0784, 0.0000, 0.0000, 0.9058, 0.0000, 0.0018, 0.0000, 0.0140,
#          0.0000],
#         [0.0000, 0.0031, 0.0000, 0.0000, 0.8984, 0.0000, 0.0007, 0.0000, 0.0977,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.27, Train Loss: 0.00, Val Loss: 5.78, Train BLEU: 0.00, Val BLEU: 2.47, Minutes Elapsed: 14.06
# Sampling from val predictions...
# Source: 所以 我 想 说 的 是 创业 创业精神 精神 是
# Reference: so what i &apos;m saying is that entrepreneurship is
# Model: <SOS> and i i i , to , , ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9999,
#          0.0001],
#         [0.0000, 0.0931, 0.9069, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9952, 0.0048, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9991, 0.0009, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9596, 0.0404, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0864, 0.9134, 0.0003, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0013, 0.9987, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0001, 0.9999, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.30, Train Loss: 0.00, Val Loss: 5.74, Train BLEU: 0.00, Val BLEU: 3.92, Minutes Elapsed: 15.61
# Sampling from val predictions...
# Source: 这 当然 会 很 无聊 一个 慢 的 普通 的
# Reference: it &apos;ll be a very boring movie — —
# Model: <SOS> it &apos;s a it a of the . .
# Attention Weights: tensor([[7.8169e-29, 9.0630e-30, 5.9246e-13, 2.9870e-07, 3.4834e-11, 4.9793e-09,
#          9.3886e-01, 6.1135e-02, 2.0969e-07, 9.5746e-11],
#         [9.9185e-01, 7.6265e-03, 5.1844e-04, 2.4488e-06, 9.0127e-14, 1.6535e-22,
#          1.2779e-20, 2.0109e-24, 4.5510e-31, 8.2293e-30],
#         [9.8849e-01, 1.1511e-02, 1.3200e-09, 4.6893e-13, 4.7352e-18, 6.8042e-29,
#          8.3471e-31, 6.6589e-35, 1.2441e-40, 2.0298e-36],
#         [6.6351e-04, 9.9180e-01, 1.5696e-03, 5.9675e-03, 5.7805e-07, 2.2988e-19,
#          5.4255e-21, 6.7819e-26, 1.1446e-31, 3.8603e-29],
#         [1.2372e-05, 3.3388e-01, 1.1140e-02, 6.5445e-01, 5.2305e-04, 3.4960e-15,
#          2.5724e-16, 1.3846e-20, 4.3509e-26, 1.3407e-22],
#         [2.0206e-12, 1.1986e-06, 1.1116e-04, 9.4485e-01, 5.5034e-02, 7.5192e-11,
#          1.0863e-11, 2.9084e-15, 5.1125e-20, 5.9640e-18],
#         [7.1228e-11, 6.5472e-06, 9.2167e-05, 3.3135e-01, 6.6855e-01, 5.2498e-07,
#          1.4547e-08, 8.5489e-11, 1.7143e-14, 8.5813e-12],
#         [2.2119e-11, 3.5405e-06, 5.4666e-05, 9.6286e-01, 3.7078e-02, 1.7209e-10,
#          4.9171e-10, 4.1050e-13, 1.0600e-17, 6.5895e-15],
#         [3.9365e-10, 5.0110e-06, 7.2758e-05, 9.9531e-01, 4.6164e-03, 9.7297e-11,
#          2.1033e-09, 2.6614e-12, 6.8449e-17, 2.2109e-13]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.33, Train Loss: 0.00, Val Loss: 5.68, Train BLEU: 0.00, Val BLEU: 3.22, Minutes Elapsed: 17.16
# Sampling from val predictions...
# Source: 找到 一种 新科 科技 取而代之 才 是 发展 的 <UNK>
# Reference: the idea of finding a different technology had absolutely
# Model: <SOS> and , , , , , , , the
# Attention Weights: tensor([[8.3886e-39, 1.5124e-31, 2.6731e-25, 1.1036e-16, 7.6774e-10, 5.0955e-04,
#          9.9945e-01, 3.2610e-05, 3.6952e-06, 2.4266e-19],
#         [9.9955e-01, 4.4895e-04, 3.4162e-11, 7.5250e-13, 3.0223e-11, 2.0855e-09,
#          9.5162e-12, 5.1823e-16, 2.2831e-18, 4.5880e-28],
#         [9.9999e-01, 7.0788e-06, 6.1756e-13, 1.9600e-16, 1.3615e-17, 1.5637e-17,
#          3.7652e-22, 2.4769e-26, 3.0725e-28, 7.5137e-33],
#         [9.8390e-01, 1.1797e-02, 1.5010e-03, 1.5636e-03, 1.1419e-03, 9.4029e-05,
#          2.5195e-09, 5.9532e-12, 1.1515e-15, 6.1089e-18],
#         [8.7748e-03, 1.5438e-05, 1.0413e-06, 1.1011e-05, 2.2710e-04, 9.9096e-01,
#          1.0283e-05, 1.0848e-10, 1.9090e-11, 2.2338e-17],
#         [5.4530e-04, 1.5306e-05, 3.2296e-05, 8.8430e-04, 5.0408e-02, 9.4788e-01,
#          2.3173e-04, 3.9644e-06, 1.6848e-07, 2.7469e-09],
#         [7.4703e-04, 1.8972e-08, 3.7772e-10, 4.7912e-09, 1.4660e-06, 9.9924e-01,
#          8.9893e-06, 1.5280e-10, 4.3565e-09, 1.2307e-15],
#         [1.8895e-05, 2.4580e-07, 1.9296e-07, 8.0869e-06, 1.3362e-03, 9.9845e-01,
#          1.8069e-04, 1.4522e-06, 1.4651e-06, 3.4227e-09],
#         [2.8654e-06, 1.3379e-10, 2.7913e-12, 9.3932e-11, 1.0669e-07, 9.9998e-01,
#          1.4895e-05, 1.3838e-10, 4.4884e-08, 2.9730e-15]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.36, Train Loss: 0.00, Val Loss: 5.70, Train BLEU: 0.00, Val BLEU: 3.18, Minutes Elapsed: 18.72
# Sampling from val predictions...
# Source: 我 不知 知道 那 张 是 怎么 怎么回事 回事 回事儿
# Reference: that was , i don &apos;t know what happened
# Model: <SOS> i i i , you &apos;t you to you
# Attention Weights: tensor([[1.6944e-32, 1.2411e-38, 5.3782e-33, 3.2728e-31, 3.1541e-24, 9.0007e-12,
#          1.0000e+00, 6.1322e-19, 8.2731e-25, 1.0329e-33],
#         [1.0000e+00, 1.4017e-13, 9.3372e-13, 5.5016e-26, 9.3267e-34, 3.0105e-30,
#          9.3440e-17, 2.8610e-31, 2.3402e-33, 7.3611e-39],
#         [1.0000e+00, 2.1018e-12, 2.9743e-10, 1.1818e-28, 7.5530e-42, 8.4302e-42,
#          1.8753e-25, 1.2758e-37, 4.7303e-39, 2.3682e-43],
#         [9.5873e-01, 7.4065e-08, 4.1272e-02, 1.5291e-19, 5.9908e-32, 1.9532e-33,
#          1.4260e-18, 1.0501e-29, 2.0006e-31, 1.5906e-36],
#         [3.0333e-09, 1.3590e-09, 1.0000e+00, 4.0737e-12, 1.0868e-21, 1.3390e-22,
#          1.9107e-10, 3.8413e-20, 1.3020e-23, 7.5849e-30],
#         [6.1207e-03, 1.2428e-08, 9.9388e-01, 9.8991e-16, 1.9939e-27, 1.6226e-27,
#          6.1241e-12, 1.4286e-21, 1.7739e-23, 1.5848e-28],
#         [6.6925e-10, 3.5897e-11, 1.0000e+00, 1.3569e-10, 2.9814e-21, 9.6576e-24,
#          8.1428e-12, 1.6351e-21, 1.5369e-24, 6.2588e-31],
#         [2.5034e-09, 1.3298e-11, 9.9999e-01, 1.2184e-06, 5.6042e-17, 6.5843e-18,
#          4.6052e-06, 4.3089e-16, 7.4933e-19, 1.7078e-24],
#         [1.2360e-13, 2.2257e-12, 8.6617e-01, 7.2474e-04, 1.1237e-11, 1.3260e-11,
#          1.3310e-01, 4.8204e-10, 9.1096e-13, 5.3758e-19]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.39, Train Loss: 0.00, Val Loss: 5.57, Train BLEU: 0.00, Val BLEU: 3.12, Minutes Elapsed: 20.28
# Sampling from val predictions...
# Source: 一些 光 流 了 出来 到 了 桌子 上 所以
# Reference: some of the light leaks , goes on the
# Model: <SOS> and the the , , , , &apos;s ,
# Attention Weights: tensor([[4.3014e-33, 1.3774e-31, 1.5180e-22, 7.4091e-16, 9.1111e-13, 2.1781e-03,
#          6.8351e-01, 3.0767e-01, 6.6486e-03, 6.6220e-13],
#         [4.6968e-02, 3.4957e-05, 2.2051e-05, 1.2000e-02, 9.2067e-01, 2.0036e-02,
#          2.6556e-04, 2.7185e-06, 2.6963e-12, 4.0464e-14],
#         [9.9709e-01, 2.5478e-04, 8.3963e-07, 1.1587e-05, 2.6447e-03, 3.2187e-09,
#          1.3436e-13, 5.9742e-16, 3.2770e-23, 1.1893e-20],
#         [1.4612e-05, 1.9505e-07, 2.2597e-09, 1.0789e-04, 9.9988e-01, 1.7706e-06,
#          5.0492e-11, 1.3615e-13, 2.5850e-18, 2.4683e-14],
#         [1.9686e-08, 9.9158e-11, 4.9217e-12, 5.1509e-06, 9.9993e-01, 2.6308e-05,
#          6.6746e-08, 5.9388e-09, 2.8426e-11, 3.5462e-05],
#         [7.6311e-10, 1.4614e-11, 1.5487e-13, 6.4340e-06, 9.8993e-01, 3.7107e-05,
#          1.9776e-07, 4.4696e-09, 2.9814e-09, 1.0031e-02],
#         [4.3751e-08, 8.1213e-10, 1.8330e-13, 1.8039e-04, 9.9555e-01, 2.2201e-04,
#          4.5727e-07, 4.1073e-11, 4.7095e-09, 4.0491e-03],
#         [9.2955e-08, 9.9182e-10, 7.1456e-13, 2.9576e-04, 8.5294e-01, 1.1670e-03,
#          5.0486e-06, 5.5607e-10, 5.5810e-07, 1.4559e-01],
#         [2.6607e-04, 2.8338e-07, 2.3705e-10, 2.2417e-05, 9.8204e-01, 1.8226e-06,
#          2.1441e-09, 4.7600e-11, 1.5024e-10, 1.7668e-02]],
#        grad_fn=<SelectBackward>)
# Epoch: 0.42, Train Loss: 0.00, Val Loss: 5.60, Train BLEU: 0.00, Val BLEU: 2.77, Minutes Elapsed: 21.84
# Sampling from val predictions...
# Source: 在 加德 <UNK> 我 由 一些 从前 是 性 奴
# Reference: in kathmandu , i was escorted by women who
# Model: <SOS> and , , i i to , , ,
# Attention Weights: tensor([[1.2489e-32, 3.7988e-28, 1.3232e-18, 2.2805e-29, 6.5388e-09, 2.1991e-11,
#          2.5004e-12, 9.7186e-01, 2.8144e-02, 1.4819e-07],
#         [9.8947e-02, 7.5292e-01, 5.5424e-05, 2.4275e-07, 1.4753e-01, 5.4556e-04,
#          9.9324e-09, 2.7251e-07, 2.3719e-09, 2.3534e-13],
#         [3.6037e-02, 9.6380e-01, 6.2407e-09, 1.6413e-04, 2.3395e-11, 2.5608e-16,
#          9.1138e-20, 5.6749e-21, 5.1576e-23, 5.4442e-24],
#         [2.8056e-15, 7.6525e-13, 1.1030e-15, 1.0000e+00, 1.0025e-18, 1.2645e-18,
#          3.4176e-18, 1.4931e-22, 2.1754e-24, 1.2485e-24],
#         [3.6802e-21, 2.1580e-20, 5.4749e-22, 1.0000e+00, 4.2186e-22, 1.1960e-22,
#          4.5544e-20, 4.3155e-24, 1.4332e-27, 7.3037e-27],
#         [1.5938e-14, 6.9012e-12, 1.4487e-14, 1.0000e+00, 8.8692e-20, 1.4403e-20,
#          1.4286e-18, 5.5037e-23, 4.1311e-24, 6.4439e-23],
#         [6.4109e-10, 1.5004e-09, 7.8754e-12, 1.0000e+00, 4.6482e-12, 7.4662e-11,
#          1.6410e-10, 1.7252e-15, 2.5246e-19, 7.6156e-21],
#         [6.2339e-16, 4.4281e-13, 1.5786e-10, 1.0000e+00, 2.9946e-10, 6.9226e-07,
#          4.1096e-06, 6.2642e-09, 1.5791e-12, 2.2228e-13],
#         [6.8768e-20, 4.8504e-18, 1.0576e-15, 1.0000e+00, 5.9375e-13, 5.5155e-10,
#          5.9668e-08, 7.3465e-10, 1.6912e-13, 4.8212e-14]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.45, Train Loss: 0.00, Val Loss: 5.52, Train BLEU: 0.00, Val BLEU: 3.58, Minutes Elapsed: 23.39
# Sampling from val predictions...
# Source: 这 是 他们 在内 内罗毕 国家 公园 杀 的 六个
# Reference: it &apos;s one of the six lions which were
# Model: <SOS> this &apos;s a the of of of of and
# Attention Weights: tensor([[6.0475e-20, 1.7724e-27, 2.5834e-28, 2.8499e-22, 3.4299e-19, 4.4937e-11,
#          8.2665e-06, 1.4184e-01, 8.5815e-01, 1.3388e-14],
#         [1.0000e+00, 1.3905e-13, 1.7529e-14, 3.9162e-28, 9.8203e-33, 3.5107e-30,
#          3.2079e-31, 1.0903e-28, 5.5446e-28, 9.0908e-39],
#         [1.0000e+00, 2.6476e-08, 4.2756e-08, 5.5476e-21, 1.5138e-28, 1.4737e-28,
#          7.4279e-32, 2.1789e-31, 9.1502e-31, 6.0378e-36],
#         [6.5974e-03, 3.0194e-05, 9.9337e-01, 3.6496e-07, 8.6332e-14, 7.4503e-15,
#          4.5171e-20, 4.3278e-21, 1.3900e-20, 9.2831e-27],
#         [1.3436e-06, 1.0472e-05, 6.6623e-02, 7.3690e-01, 2.7780e-02, 1.6774e-01,
#          5.6773e-04, 6.7271e-05, 3.0247e-04, 1.0465e-07],
#         [7.7264e-08, 1.2956e-07, 6.4656e-03, 7.4200e-02, 4.6624e-02, 8.1652e-01,
#          6.3945e-03, 7.9140e-03, 4.1877e-02, 5.6649e-06],
#         [8.6709e-10, 2.7018e-10, 5.9496e-05, 1.4753e-03, 7.2182e-03, 8.7825e-01,
#          2.2399e-02, 2.3284e-02, 6.5154e-02, 2.1602e-03],
#         [2.0791e-07, 1.4659e-09, 8.4867e-04, 6.3952e-04, 3.5244e-03, 7.7031e-01,
#          1.5380e-02, 3.7575e-02, 1.6907e-01, 2.6463e-03],
#         [4.3989e-06, 4.6032e-09, 3.1312e-03, 1.7468e-04, 8.9725e-04, 2.7732e-01,
#          9.6834e-03, 1.1697e-01, 5.9109e-01, 7.2962e-04]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.48, Train Loss: 0.00, Val Loss: 5.50, Train BLEU: 0.00, Val BLEU: 2.37, Minutes Elapsed: 24.95
# Sampling from val predictions...
# Source: 但 这 就是 自我 的 形成 <EOS> <PAD> <PAD> <PAD>
# Reference: but this is the geography of self . <EOS>
# Model: <SOS> but it &apos;s a . . . . <EOS>
# Attention Weights: tensor([[0.7248, 0.0000, 0.0000, 0.0000, 0.2752, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.7855, 0.1618, 0.0527, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9948, 0.0052, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.8431, 0.1569, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0058, 0.9941, 0.0001, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.8132, 0.1866, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.4505, 0.5444, 0.0050, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0349, 0.9452, 0.0193, 0.0006, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0001, 0.6429, 0.0611, 0.2959, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.51, Train Loss: 0.00, Val Loss: 5.51, Train BLEU: 0.00, Val BLEU: 2.89, Minutes Elapsed: 26.51
# Sampling from val predictions...
# Source: 这 是 那 张 照片 几个 月前 我 跟 祖母
# Reference: this is what i looked like with my grandma
# Model: <SOS> this is a , i to , , ,
# Attention Weights: tensor([[3.9533e-20, 4.8998e-21, 5.2931e-17, 3.7211e-17, 6.2348e-15, 5.6384e-05,
#          7.6682e-12, 1.2253e-05, 9.9993e-01, 2.2642e-15],
#         [1.0000e+00, 8.8087e-12, 6.6259e-14, 7.8162e-26, 1.0789e-35, 6.8322e-31,
#          1.4471e-41, 7.7484e-27, 2.0457e-31, 1.0229e-43],
#         [1.0000e+00, 2.1087e-09, 3.9822e-11, 3.2764e-23, 2.7039e-34, 1.5938e-34,
#          1.8217e-44, 4.7872e-29, 1.1647e-37, 2.3822e-44],
#         [1.6998e-01, 2.3757e-03, 8.2764e-01, 6.2441e-08, 3.7823e-13, 3.4138e-13,
#          3.6489e-19, 1.2600e-09, 1.8513e-19, 1.3258e-25],
#         [9.4162e-08, 9.6067e-06, 1.1611e-01, 6.9488e-03, 1.8992e-03, 2.7632e-01,
#          4.4166e-03, 5.9430e-01, 6.2533e-10, 1.6837e-12],
#         [1.2157e-12, 4.3739e-13, 6.2300e-08, 3.3793e-11, 1.0205e-12, 2.0198e-09,
#          8.4889e-11, 1.0000e+00, 7.8960e-13, 1.0365e-16],
#         [6.9115e-06, 1.7378e-04, 9.9981e-01, 1.0307e-05, 8.1503e-11, 1.8132e-09,
#          4.2396e-15, 8.3698e-13, 1.0920e-17, 9.8279e-22],
#         [2.0639e-12, 1.0006e-10, 5.5060e-06, 1.8951e-07, 3.6945e-06, 3.5299e-02,
#          3.2155e-04, 9.6437e-01, 1.7441e-07, 1.6081e-12],
#         [8.5853e-18, 2.6460e-16, 6.2063e-11, 1.4029e-12, 1.4869e-11, 1.8456e-06,
#          8.2495e-07, 1.0000e+00, 1.0402e-09, 1.2619e-13]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.54, Train Loss: 0.00, Val Loss: 5.47, Train BLEU: 0.00, Val BLEU: 4.29, Minutes Elapsed: 28.07
# Sampling from val predictions...
# Source: 当时 我 以为 我 只是 和 我 的 家人 分开
# Reference: but i only thought that i would be separated
# Model: <SOS> and i i to , i , to ,
# Attention Weights: tensor([[1.6251e-24, 3.3631e-44, 1.8170e-22, 1.2076e-31, 2.0516e-18, 1.0000e+00,
#          3.0702e-19, 1.4858e-10, 3.9276e-08, 1.2602e-09],
#         [7.6292e-06, 9.9958e-01, 3.7306e-04, 6.3103e-06, 2.5703e-10, 3.7527e-05,
#          5.2239e-11, 2.6996e-16, 1.3053e-15, 2.8284e-17],
#         [5.8274e-16, 9.9939e-01, 2.5905e-10, 6.1223e-04, 1.5786e-16, 2.0104e-19,
#          2.2032e-17, 1.0113e-32, 8.5445e-34, 1.3073e-32],
#         [2.5467e-23, 3.6231e-04, 5.0206e-10, 9.9964e-01, 3.4419e-15, 8.6687e-21,
#          1.0484e-14, 1.7522e-36, 1.1719e-35, 6.4680e-36],
#         [4.7013e-27, 1.1621e-18, 6.2573e-12, 4.5958e-01, 5.4041e-01, 1.1638e-06,
#          1.6099e-06, 1.4187e-19, 3.9469e-25, 9.2226e-25],
#         [7.6341e-27, 5.7413e-18, 2.0040e-12, 1.4733e-04, 3.6426e-04, 6.8865e-05,
#          9.9942e-01, 2.3262e-14, 1.3133e-14, 2.3306e-12],
#         [2.3480e-32, 1.8972e-18, 4.7926e-17, 1.1742e-06, 5.7123e-09, 6.1451e-10,
#          1.0000e+00, 3.2404e-15, 2.7517e-16, 1.4122e-13],
#         [6.7439e-29, 1.8700e-18, 6.0331e-15, 5.1848e-05, 7.8640e-08, 2.9699e-07,
#          9.9995e-01, 1.7399e-15, 2.4545e-16, 2.1492e-13],
#         [1.0164e-27, 3.9588e-24, 3.3454e-15, 2.2828e-05, 6.6228e-01, 4.2470e-02,
#          2.9523e-01, 5.2887e-10, 9.2882e-15, 4.9829e-13]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.57, Train Loss: 0.00, Val Loss: 5.41, Train BLEU: 0.00, Val BLEU: 3.79, Minutes Elapsed: 29.63
# Sampling from val predictions...
# Source: 音乐 而且 因为 我们 有 一个 可以 运行 如此 之
# Reference: and because we have a camera that can run
# Model: <SOS> the &apos;s &apos;s is to to of , .
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0892, 0.0000, 0.0000, 0.9108, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9951, 0.0002, 0.0000, 0.0047, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0146, 0.9854, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0001, 0.9999, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0016, 0.0000, 0.0000, 0.9981, 0.0000, 0.0003,
#          0.0000]], grad_fn=<SelectBackward>)
# Epoch: 0.60, Train Loss: 0.00, Val Loss: 5.39, Train BLEU: 0.00, Val BLEU: 3.01, Minutes Elapsed: 31.20
# Sampling from val predictions...
# Source: 非常 非常感谢 感谢 肯尼 肯尼亚 尼亚 <UNK> <UNK> 在 我
# Reference: <UNK> <UNK> . it means in my language ,
# Model: <SOS> thank you you you you very . . .
# Attention Weights: tensor([[3.9777e-26, 1.3082e-30, 2.6479e-36, 3.7835e-44, 5.8434e-43, 1.3236e-35,
#          1.7014e-25, 1.4655e-19, 9.2228e-12, 1.0000e+00],
#         [9.2496e-02, 9.0657e-01, 1.6101e-05, 1.0486e-18, 5.4863e-23, 2.9517e-22,
#          1.8006e-22, 8.7288e-22, 2.2075e-15, 9.1755e-04],
#         [5.9099e-07, 1.0000e+00, 1.1230e-06, 1.1959e-18, 1.9588e-21, 1.0768e-22,
#          2.5299e-28, 2.5929e-31, 1.8534e-30, 2.0817e-17],
#         [2.8664e-05, 9.9996e-01, 8.5684e-09, 1.8936e-20, 6.9622e-23, 1.0285e-21,
#          1.9205e-23, 8.4594e-24, 1.1567e-17, 7.8809e-06],
#         [7.8457e-05, 9.7864e-01, 4.8869e-08, 6.7727e-20, 1.1110e-22, 4.2182e-21,
#          4.3976e-22, 2.5654e-21, 2.8240e-14, 2.1283e-02],
#         [1.0373e-06, 1.0000e+00, 2.2754e-09, 8.7790e-20, 1.4757e-21, 4.9702e-21,
#          2.5327e-24, 2.3700e-25, 7.0642e-22, 3.2832e-10],
#         [4.1319e-02, 9.5868e-01, 6.1819e-11, 1.8376e-17, 7.7701e-17, 1.6319e-15,
#          1.8246e-15, 1.9507e-15, 1.8278e-12, 2.0961e-07],
#         [7.8312e-03, 1.8272e-04, 5.5712e-13, 4.7575e-19, 2.9922e-18, 1.6086e-15,
#          3.0453e-12, 4.4428e-10, 4.5055e-05, 9.9194e-01],
#         [2.8407e-04, 1.0492e-05, 6.0077e-13, 5.4109e-19, 1.7560e-18, 2.7316e-15,
#          2.2507e-12, 2.0795e-10, 2.9923e-04, 9.9941e-01]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.63, Train Loss: 0.00, Val Loss: 5.35, Train BLEU: 0.00, Val BLEU: 2.85, Minutes Elapsed: 32.76
# Sampling from val predictions...
# Source: 地球 上 总共 共有 一万 <UNK> 万种 种鸟 鸟类 <EOS>
# Reference: there are 10,000 species of birds in the world
# Model: <SOS> the are a in of the . . .
# Attention Weights: tensor([[4.4069e-19, 7.4947e-25, 6.4543e-15, 1.2973e-10, 4.9152e-09, 2.1139e-05,
#          4.9315e-01, 5.0239e-01, 4.4406e-03, 8.8673e-09],
#         [9.9952e-01, 1.3915e-07, 4.6686e-04, 1.5833e-05, 3.9851e-09, 6.8379e-14,
#          2.8081e-12, 4.1164e-17, 5.3678e-21, 1.2095e-30],
#         [9.8343e-01, 2.6015e-05, 1.4619e-02, 1.9277e-03, 6.2481e-08, 3.7044e-14,
#          2.2866e-15, 4.8308e-21, 1.1460e-25, 9.2349e-29],
#         [1.1212e-04, 2.6276e-05, 2.4256e-02, 5.2232e-01, 4.5328e-01, 2.5099e-06,
#          1.7376e-06, 2.3105e-13, 2.9620e-17, 2.1865e-22],
#         [3.4512e-10, 1.4064e-08, 5.8120e-04, 7.4580e-01, 2.5333e-01, 2.4682e-04,
#          4.9875e-05, 9.0536e-10, 8.9623e-15, 8.4857e-18],
#         [1.6338e-06, 1.4490e-06, 4.2287e-03, 8.8874e-01, 1.0647e-01, 4.9081e-06,
#          5.5400e-04, 3.7267e-09, 2.8694e-12, 4.7051e-16],
#         [7.9263e-09, 6.3475e-08, 8.0140e-06, 2.5874e-02, 5.0666e-02, 1.3578e-04,
#          9.2299e-01, 3.1919e-04, 4.5640e-06, 6.1527e-12],
#         [4.9396e-10, 7.5524e-09, 3.6600e-06, 1.9599e-02, 1.6395e-02, 1.2259e-04,
#          9.2844e-01, 3.1027e-02, 4.4077e-03, 4.2655e-06],
#         [5.2885e-07, 5.3982e-06, 3.9855e-05, 2.9128e-02, 3.8327e-02, 3.7902e-06,
#          9.2072e-01, 3.8066e-03, 7.9671e-03, 1.5975e-07]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.66, Train Loss: 0.00, Val Loss: 5.35, Train BLEU: 0.00, Val BLEU: 2.61, Minutes Elapsed: 34.32
# Sampling from val predictions...
# Source: 但 第三 第三件 三件 事 你 能 了解 到 的
# Reference: but the third thing you can learn , and
# Model: <SOS> but , , , , you you you you
# Attention Weights: tensor([[1.5585e-15, 2.7194e-28, 1.0519e-33, 1.1104e-31, 1.8671e-27, 3.8153e-35,
#          3.6176e-23, 3.4682e-17, 8.8308e-01, 1.1692e-01],
#         [1.0000e+00, 6.5213e-09, 1.0832e-17, 1.0734e-21, 4.2218e-19, 4.4849e-18,
#          4.3263e-21, 2.0361e-21, 2.9707e-18, 3.0728e-18],
#         [9.9998e-01, 2.1256e-05, 1.8540e-13, 1.2823e-18, 7.3851e-17, 1.4402e-07,
#          2.1342e-14, 1.0304e-19, 4.1479e-24, 7.3539e-25],
#         [1.0382e-06, 3.1762e-04, 1.1999e-08, 3.8232e-12, 1.9765e-10, 9.9968e-01,
#          4.3979e-09, 2.3491e-11, 8.4413e-19, 5.7497e-21],
#         [3.1133e-18, 5.0339e-15, 5.4221e-17, 6.1704e-18, 1.8944e-13, 1.0000e+00,
#          4.0273e-13, 1.8978e-15, 1.1559e-25, 1.2905e-25],
#         [1.1389e-24, 3.0593e-24, 1.0227e-24, 2.0382e-24, 8.4172e-18, 1.0000e+00,
#          4.3672e-15, 2.8271e-18, 5.9218e-29, 4.7071e-28],
#         [3.3517e-21, 2.0550e-22, 3.3515e-23, 1.6107e-23, 2.5853e-18, 1.0000e+00,
#          9.3892e-11, 4.8319e-13, 1.8886e-23, 5.3863e-23],
#         [2.5933e-15, 6.1917e-15, 1.2668e-15, 1.4151e-15, 1.9990e-14, 2.2519e-04,
#          2.8726e-03, 9.9690e-01, 6.5643e-09, 1.6355e-10],
#         [2.1959e-16, 1.1653e-16, 6.6742e-18, 5.8120e-17, 1.7260e-16, 2.5264e-11,
#          7.2840e-07, 9.9980e-01, 1.9516e-04, 2.9518e-06]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.69, Train Loss: 0.00, Val Loss: 5.33, Train BLEU: 0.00, Val BLEU: 3.98, Minutes Elapsed: 35.88
# Sampling from val predictions...
# Source: 如果 孩子 们 种植 <UNK> 孩子 们 就 会 吃
# Reference: if kids grow <UNK> , kids eat <UNK> .
# Model: <SOS> so if &apos;re the , , , , to
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0001, 0.0002, 0.9996, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9995, 0.0000, 0.0000, 0.0000, 0.0005, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.2478, 0.0000, 0.0000, 0.0000, 0.7521, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9996, 0.0004, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.5940, 0.0000, 0.0000, 0.0000, 0.4058, 0.0002, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9968, 0.0032, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.72, Train Loss: 0.00, Val Loss: 5.34, Train BLEU: 0.00, Val BLEU: 3.36, Minutes Elapsed: 37.44
# Sampling from val predictions...
# Source: 我们 还给 她 复原 照片 的 那天 又 恰好 是
# Reference: the day i gave her the photos also happened
# Model: <SOS> we we we we to to to of and
# Attention Weights: tensor([[0.0001, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0390, 0.0000, 0.0443,
#          0.9165],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9999, 0.0001, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9965, 0.0035, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9905, 0.0021, 0.0000, 0.0003, 0.0071, 0.0000, 0.0000,
#          0.0000],
#         [0.0003, 0.0000, 0.9668, 0.0000, 0.0000, 0.0004, 0.0324, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.75, Train Loss: 0.00, Val Loss: 5.29, Train BLEU: 0.00, Val BLEU: 3.83, Minutes Elapsed: 39.00
# Sampling from val predictions...
# Source: 当 他们 遭受 海啸 袭击 之时 可想 可想而知 必然 四处
# Reference: as they had run from the wave , and
# Model: <SOS> and they , , , , , , the
# Attention Weights: tensor([[7.7482e-24, 1.1061e-33, 1.1978e-31, 2.3863e-29, 2.8464e-21, 2.6840e-19,
#          7.0143e-16, 4.6501e-11, 2.3968e-06, 1.0000e+00],
#         [3.1020e-09, 1.0000e+00, 5.0292e-15, 3.6126e-20, 6.5226e-20, 6.1081e-23,
#          2.8047e-26, 7.7473e-27, 4.6433e-23, 2.3066e-19],
#         [1.8707e-15, 1.0000e+00, 9.0956e-17, 1.2126e-21, 1.1477e-22, 2.7222e-27,
#          5.5520e-33, 3.0638e-37, 2.6111e-36, 3.2047e-31],
#         [5.7790e-13, 1.0000e+00, 1.4405e-09, 7.2105e-13, 1.1841e-12, 1.2954e-16,
#          3.2195e-21, 3.3433e-23, 2.1238e-25, 1.8077e-21],
#         [3.2321e-11, 9.1164e-01, 8.7409e-02, 6.3529e-04, 3.1808e-04, 5.0115e-08,
#          2.1821e-12, 3.4729e-14, 5.9728e-17, 7.4864e-15],
#         [1.3135e-09, 9.0426e-02, 4.5998e-01, 2.9063e-03, 4.3492e-01, 6.9599e-04,
#          2.0529e-06, 1.7049e-03, 3.6455e-04, 9.0003e-03],
#         [1.3063e-11, 8.7237e-05, 6.1927e-05, 3.5982e-07, 4.5859e-04, 7.8468e-06,
#          4.0761e-08, 1.2149e-03, 1.3985e-01, 8.5832e-01],
#         [3.1816e-11, 5.8743e-05, 2.9526e-09, 4.5870e-13, 8.3688e-10, 4.0503e-11,
#          2.0805e-12, 4.1495e-05, 5.4097e-01, 4.5892e-01],
#         [2.0869e-10, 1.5528e-03, 1.0153e-10, 1.0862e-14, 1.0781e-11, 1.3577e-12,
#          2.7463e-14, 1.5465e-06, 6.7019e-01, 3.2825e-01]],
#        grad_fn=<SelectBackward>)
# Epoch: 0.78, Train Loss: 0.00, Val Loss: 5.31, Train BLEU: 0.00, Val BLEU: 3.38, Minutes Elapsed: 40.56
# Sampling from val predictions...
# Source: 谁 还 会 认真 认真对待 真对 对待 他 如果 他
# Reference: and who &apos;s going to take him seriously if
# Model: <SOS> and &apos;s can &apos;t to to to to to
# Attention Weights: tensor([[1.5600e-24, 1.6127e-37, 1.4973e-32, 5.6362e-25, 2.3097e-26, 3.7017e-17,
#          1.3979e-12, 9.9999e-01, 1.7095e-08, 1.0064e-05],
#         [1.0000e+00, 1.2666e-07, 9.6307e-12, 4.7812e-15, 3.2019e-25, 4.0484e-22,
#          1.0508e-25, 1.7482e-14, 4.5859e-25, 1.3770e-16],
#         [9.9883e-01, 1.1721e-03, 6.9983e-08, 2.8615e-10, 1.9603e-21, 5.6884e-19,
#          2.1363e-28, 6.5282e-23, 3.2300e-31, 6.5071e-27],
#         [9.9734e-01, 2.6500e-03, 4.4711e-06, 9.6505e-07, 1.0626e-14, 3.0761e-11,
#          8.4428e-20, 1.6694e-14, 3.6160e-21, 1.1277e-19],
#         [4.6390e-07, 1.6552e-04, 1.8426e-03, 9.9799e-01, 1.9106e-09, 8.8490e-09,
#          2.2130e-15, 3.0598e-09, 5.4921e-13, 1.4139e-12],
#         [1.8731e-10, 1.0345e-07, 3.6038e-05, 9.8626e-01, 9.3545e-06, 1.3635e-03,
#          3.4939e-07, 1.2110e-02, 2.2009e-04, 1.1234e-07],
#         [4.6672e-14, 4.1864e-13, 3.9120e-10, 8.5584e-01, 1.7692e-04, 3.4968e-02,
#          2.1733e-06, 1.0897e-01, 4.2014e-05, 5.2756e-07],
#         [4.9558e-19, 2.8918e-15, 2.4355e-13, 1.1429e-05, 3.7954e-07, 4.1988e-03,
#          2.1852e-04, 3.2546e-01, 6.6922e-01, 8.9157e-04],
#         [1.1918e-19, 4.7118e-20, 5.4356e-19, 5.3780e-09, 1.1991e-10, 9.9417e-06,
#          5.0692e-06, 9.9796e-01, 1.9167e-03, 1.1168e-04]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.81, Train Loss: 0.00, Val Loss: 5.24, Train BLEU: 0.00, Val BLEU: 4.20, Minutes Elapsed: 42.12
# Sampling from val predictions...
# Source: 我 的 第一 第一个 一个 答案 是 我 也 不知
# Reference: and the first answer is , &quot; i don
# Model: <SOS> i i i i i i i i ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.4063, 0.0002, 0.0000, 0.5936, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0001, 0.0000, 0.0000, 0.6659, 0.0014, 0.3002, 0.0000, 0.0325, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0190, 0.0000, 0.9810, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.84, Train Loss: 0.00, Val Loss: 5.24, Train BLEU: 0.00, Val BLEU: 3.30, Minutes Elapsed: 43.68
# Sampling from val predictions...
# Source: 我们 是 一个 自由 的 组织 由来 来自 不同 同行
# Reference: what we do , we &apos;re a <UNK> kind
# Model: <SOS> we we we a a is a to of
# Attention Weights: tensor([[4.0245e-02, 6.3748e-35, 9.0358e-27, 3.4439e-17, 8.8400e-17, 2.9090e-10,
#          7.4441e-05, 5.2744e-03, 1.7524e-02, 9.3688e-01],
#         [1.0000e+00, 2.2248e-27, 2.4301e-27, 4.2655e-28, 3.3487e-33, 4.7426e-34,
#          1.3322e-34, 1.6099e-36, 6.9556e-41, 1.3046e-42],
#         [1.0000e+00, 4.8391e-18, 9.1964e-18, 8.8648e-19, 4.7929e-22, 4.1038e-24,
#          3.3297e-26, 1.0809e-29, 5.8102e-36, 1.0776e-40],
#         [9.9998e-01, 2.0337e-11, 9.4880e-07, 1.3914e-05, 7.0323e-08, 1.5223e-07,
#          1.5651e-09, 5.7696e-13, 2.6864e-19, 3.3729e-24],
#         [9.2353e-19, 1.1305e-13, 7.7038e-06, 1.4253e-02, 2.4277e-01, 5.8531e-01,
#          1.5765e-01, 5.8197e-06, 3.1891e-13, 9.1476e-22],
#         [1.4722e-21, 4.7932e-17, 3.2057e-05, 2.4771e-04, 2.8768e-03, 6.3612e-01,
#          3.6070e-01, 1.8329e-05, 4.6099e-13, 8.0251e-22],
#         [4.4188e-11, 4.4482e-13, 2.1525e-04, 7.9493e-03, 8.0542e-03, 9.6961e-01,
#          1.4106e-02, 6.7259e-05, 2.6893e-10, 3.3089e-18],
#         [9.2535e-21, 3.1313e-16, 7.6887e-07, 4.2991e-03, 2.9772e-01, 6.1195e-01,
#          8.6020e-02, 6.6618e-06, 8.6962e-13, 3.8448e-22],
#         [2.5650e-21, 4.8316e-15, 3.4178e-06, 3.4599e-03, 7.7858e-03, 1.8261e-01,
#          8.0603e-01, 1.0484e-04, 4.6052e-10, 6.7588e-18]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.87, Train Loss: 0.00, Val Loss: 5.21, Train BLEU: 0.00, Val BLEU: 3.45, Minutes Elapsed: 45.25
# Sampling from val predictions...
# Source: 她家 有 一大 一大堆 大堆 的 家禽 被 狮子 捕食
# Reference: she had a lot of her animals being killed
# Model: <SOS> and is a a of , , , the
# Attention Weights: tensor([[5.3018e-05, 3.1167e-11, 1.7446e-07, 1.5662e-09, 6.8330e-05, 1.8415e-01,
#          2.9682e-03, 3.8187e-06, 8.1275e-01, 3.8505e-06],
#         [8.7714e-01, 1.2071e-01, 2.1557e-03, 1.5508e-08, 1.2268e-14, 1.5686e-17,
#          9.2894e-21, 1.3589e-29, 1.0374e-26, 1.8701e-29],
#         [5.4813e-03, 9.8728e-01, 7.2332e-03, 3.3115e-06, 1.0334e-13, 1.5521e-17,
#          2.6113e-22, 1.1340e-32, 1.4055e-32, 5.3130e-33],
#         [1.9683e-09, 9.7933e-05, 6.2302e-01, 3.7688e-01, 5.2572e-06, 1.7501e-06,
#          1.6775e-11, 3.0761e-18, 3.2351e-22, 1.9987e-24],
#         [3.4942e-11, 1.3198e-07, 1.5205e-01, 8.4752e-01, 3.7027e-04, 5.9548e-05,
#          4.6006e-09, 1.3647e-13, 1.9789e-16, 7.6032e-19],
#         [3.5580e-10, 2.8198e-06, 1.9452e-02, 9.8051e-01, 2.5839e-05, 1.1268e-05,
#          7.2087e-09, 3.0978e-12, 4.1456e-15, 2.5058e-14],
#         [4.5528e-11, 2.8310e-07, 5.1160e-04, 4.0388e-02, 2.7176e-04, 9.5812e-01,
#          3.2443e-04, 3.8386e-04, 1.8382e-09, 2.7125e-08],
#         [3.5380e-08, 5.6342e-05, 3.8541e-03, 2.1786e-01, 1.0628e-03, 7.2722e-01,
#          1.5794e-02, 3.2031e-02, 6.3105e-06, 2.1125e-03],
#         [1.8291e-11, 2.0431e-08, 4.0527e-06, 2.0429e-04, 1.4407e-05, 9.1755e-01,
#          6.6446e-03, 7.5570e-02, 1.2171e-06, 9.6481e-06]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.90, Train Loss: 0.00, Val Loss: 5.22, Train BLEU: 0.00, Val BLEU: 4.27, Minutes Elapsed: 46.82
# Sampling from val predictions...
# Source: 我们 开始 交往 他 喜欢 关于 我 的 一切 例如
# Reference: we started dating , and he loved everything about
# Model: <SOS> we we to to , , , to ,
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.4038, 0.0000, 0.5962,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.9989, 0.0011, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0334, 0.9666, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0001, 0.9999, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 0.93, Train Loss: 0.00, Val Loss: 5.14, Train BLEU: 0.00, Val BLEU: 3.67, Minutes Elapsed: 48.37
# Sampling from val predictions...
# Source: 我们 种 的 西红柿 漂亮 极了 在意 意大利 大利 一个
# Reference: we had these magnificent tomatoes . in italy ,
# Model: <SOS> we are a a a , the is ,
# Attention Weights: tensor([[4.7182e-13, 1.8357e-43, 1.5628e-37, 2.9434e-31, 1.1176e-27, 5.7197e-09,
#          1.3883e-11, 2.4099e-11, 1.5407e-07, 1.0000e+00],
#         [1.0000e+00, 6.2136e-26, 6.2691e-24, 5.2794e-27, 1.9043e-34, 6.0788e-26,
#          1.4406e-32, 1.0450e-36, 3.5986e-37, 4.4900e-32],
#         [1.0000e+00, 2.8060e-17, 1.1424e-15, 5.3517e-19, 1.6004e-23, 1.0578e-20,
#          8.8647e-27, 1.4261e-31, 5.2223e-33, 1.1971e-29],
#         [1.6735e-13, 5.9545e-11, 6.5218e-01, 3.4737e-01, 5.3395e-05, 3.9470e-04,
#          2.1878e-09, 2.6293e-14, 5.7666e-18, 1.7265e-17],
#         [2.8490e-15, 2.6607e-14, 5.7198e-07, 2.0365e-01, 5.6931e-01, 2.2490e-01,
#          1.8924e-03, 2.4894e-04, 6.3120e-07, 2.6424e-08],
#         [1.1252e-09, 1.3855e-13, 7.3661e-08, 4.8975e-03, 5.4357e-02, 9.3903e-01,
#          1.6341e-03, 8.1450e-05, 1.6174e-06, 1.7472e-07],
#         [8.7381e-07, 5.1400e-14, 6.8961e-09, 4.0634e-08, 1.2643e-06, 9.9978e-01,
#          2.0294e-04, 3.1103e-07, 2.3638e-07, 1.1538e-05],
#         [1.4819e-09, 1.5244e-16, 1.1953e-11, 5.3121e-11, 8.3942e-09, 9.6783e-01,
#          1.1530e-02, 3.0293e-05, 1.0173e-04, 2.0507e-02],
#         [7.6277e-08, 2.1613e-12, 2.7790e-09, 2.3477e-09, 5.2129e-09, 9.1085e-03,
#          2.9202e-03, 7.3814e-04, 2.7928e-03, 9.8444e-01]],
#        grad_fn=<SelectBackward>)
# Epoch: 0.96, Train Loss: 0.00, Val Loss: 5.14, Train BLEU: 0.00, Val BLEU: 4.08, Minutes Elapsed: 49.92
# Sampling from val predictions...
# Source: 对 是 的 所以 以是 这样 的 在 来电 期间
# Reference: yeah . yeah . so what will happen is
# Model: <SOS> it &apos;s that &apos;s it is &apos;s the the
# Attention Weights: tensor([[3.4658e-15, 2.6777e-17, 8.3892e-19, 2.1691e-21, 5.5301e-15, 1.9912e-03,
#          9.9353e-01, 2.1835e-03, 1.2908e-03, 1.0009e-03],
#         [9.6046e-01, 3.9525e-02, 1.1068e-05, 9.3768e-17, 4.4915e-18, 1.0669e-12,
#          9.6433e-16, 2.4529e-20, 2.6741e-24, 2.4560e-24],
#         [1.8615e-03, 9.7739e-01, 2.0751e-02, 3.0168e-11, 1.4603e-14, 3.5047e-11,
#          1.1090e-16, 9.2423e-22, 4.4300e-28, 1.5000e-29],
#         [1.4773e-09, 1.4152e-03, 7.8086e-01, 2.1683e-01, 2.6315e-06, 8.9002e-04,
#          8.4113e-08, 3.0536e-11, 9.1619e-17, 4.7196e-17],
#         [8.9766e-11, 9.7555e-06, 9.7718e-01, 6.1990e-04, 5.7019e-06, 2.0841e-02,
#          1.3304e-03, 8.5986e-06, 9.7697e-11, 1.8865e-11],
#         [2.2251e-13, 1.7550e-07, 6.1197e-04, 1.0496e-01, 9.4449e-06, 8.0285e-01,
#          9.0262e-02, 1.3059e-03, 1.9531e-08, 3.2068e-08],
#         [1.0885e-14, 5.9525e-10, 2.3768e-04, 1.8240e-05, 5.1288e-07, 2.4860e-01,
#          7.0651e-01, 4.4625e-02, 4.3728e-06, 5.2053e-07],
#         [1.1841e-12, 3.6118e-08, 3.4902e-03, 1.3503e-04, 3.1819e-06, 3.5690e-01,
#          6.0386e-01, 3.5597e-02, 1.3187e-05, 2.1801e-06],
#         [5.1250e-13, 3.3191e-09, 8.3431e-06, 4.6545e-04, 2.1466e-06, 6.6190e-01,
#          3.1930e-01, 1.8322e-02, 1.3255e-06, 1.3370e-06]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 0.99, Train Loss: 0.00, Val Loss: 5.14, Train BLEU: 0.00, Val BLEU: 4.11, Minutes Elapsed: 51.48
# Sampling from val predictions...
# Source: 但是 很多 尝试 <UNK> 的 人 死 了 <EOS> <PAD>
# Reference: but many die . <EOS> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> but the &apos;s are , &apos;s . <EOS> <EOS>
# Attention Weights: tensor([[0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1603, 0.8396, 0.0000,
#          0.0000],
#         [0.3792, 0.6208, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9999, 0.0001, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.9090, 0.0062, 0.0019, 0.0317, 0.0512, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.1663, 0.8337, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0119, 0.9880, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0012, 0.9972, 0.0016, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0006, 0.5042, 0.1766, 0.3186, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 1.00, Train Loss: 0.00, Val Loss: 5.13, Train BLEU: 0.00, Val BLEU: 4.67, Minutes Elapsed: 52.05
# Sampling from val predictions...
# Source: 你 知道 吗 你 可以 选择 任何 的 职业 <EOS>
# Reference: you know ? you can be anything . <EOS>
# Model: <SOS> you you , you you see you you you
# Attention Weights: tensor([[0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0446, 0.0000, 0.0000, 0.9554, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0008, 0.9992, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9350, 0.0575, 0.0074, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0039, 0.6194, 0.3521, 0.0247, 0.0000, 0.0000,
# ...
#         [1.1879e-03, 4.6148e-03, 4.7641e-01, 5.1777e-01, 2.4039e-05, 2.7628e-14,
#          6.1142e-20, 5.1307e-20, 1.1247e-21, 5.4816e-22],
#         [1.3269e-19, 1.8612e-15, 1.9710e-07, 1.1756e-02, 9.8824e-01, 4.1595e-14,
#          1.8203e-15, 3.6218e-16, 2.1380e-16, 1.6036e-19],
#         [1.7124e-19, 3.3209e-19, 5.8319e-11, 5.0942e-04, 9.9949e-01, 2.8051e-11,
#          8.1519e-10, 4.9467e-09, 2.8061e-06, 5.3295e-11],
#         [5.2317e-16, 6.9029e-18, 4.6940e-09, 2.6877e-02, 8.6628e-01, 7.4103e-08,
#          5.1888e-06, 2.4705e-04, 1.0659e-01, 2.9351e-06],
#         [8.7726e-17, 1.1515e-18, 8.1855e-13, 6.5645e-07, 3.5798e-04, 3.2270e-08,
#          5.5614e-06, 1.4372e-03, 9.9695e-01, 1.2492e-03],
#         [8.0891e-16, 3.7144e-17, 1.2313e-13, 1.6046e-08, 4.8893e-05, 2.5725e-07,
#          7.0438e-08, 4.3647e-04, 9.9895e-01, 5.6299e-04],
#         [1.1418e-08, 2.0384e-12, 3.4889e-10, 8.1945e-06, 6.7044e-05, 4.9466e-07,
#          9.6923e-10, 3.0548e-06, 9.8615e-01, 1.3776e-02]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 10.09, Train Loss: 0.00, Val Loss: 4.39, Train BLEU: 0.00, Val BLEU: 6.46, Minutes Elapsed: 652.09
# Sampling from val predictions...
# Source: 我们 看到 了 一样 的 症状 <EOS> <PAD> <PAD> <PAD>
# Reference: we see all the same symptoms . <EOS> <PAD>
# Model: <SOS> we we seen same symptoms . . <EOS> <EOS>
# Attention Weights: tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9999, 0.0001, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.6588, 0.0006, 0.3049, 0.0358, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1023, 0.8977, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9897, 0.0002, 0.0100, 0.0001, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0043, 0.0002, 0.0007, 0.9948, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.12, Train Loss: 0.00, Val Loss: 4.39, Train BLEU: 0.00, Val BLEU: 6.53, Minutes Elapsed: 654.35
# Sampling from val predictions...
# Source: 而且 速度 也 快 最多 多只 只要 30 秒 <EOS>
# Reference: they &apos;re high-speed , take about 30 seconds at
# Model: <SOS> and &apos;s about to for 30 10 . .
# Attention Weights: tensor([[9.9902e-01, 2.3435e-06, 4.5366e-09, 8.5125e-06, 2.3397e-07, 1.1055e-05,
#          7.4603e-06, 1.4832e-08, 5.3485e-04, 4.1350e-04],
#         [5.9895e-03, 3.2934e-06, 9.9399e-01, 1.3871e-05, 2.2505e-09, 9.4088e-12,
#          3.6781e-13, 7.4067e-18, 1.9733e-19, 6.3048e-24],
#         [1.9925e-09, 1.0490e-05, 9.9999e-01, 9.5682e-09, 1.8821e-14, 5.3923e-19,
#          4.0639e-23, 4.4117e-24, 7.8102e-30, 2.8501e-34],
#         [3.9369e-12, 5.1267e-08, 4.2243e-01, 5.4778e-01, 2.9776e-02, 7.6165e-06,
#          9.6179e-11, 7.3666e-10, 5.7609e-13, 7.7350e-22],
#         [1.5632e-12, 2.6032e-08, 7.4162e-03, 6.2335e-02, 9.3008e-01, 1.7294e-04,
#          1.8719e-07, 3.9991e-09, 5.2860e-10, 3.6474e-21],
#         [7.6703e-14, 8.5655e-10, 5.2962e-03, 1.9123e-04, 5.2048e-03, 8.3249e-04,
#          7.4321e-03, 1.8421e-05, 9.8102e-01, 8.9846e-09],
#         [7.1532e-17, 2.8869e-10, 8.8934e-09, 8.6721e-08, 9.8158e-03, 9.9018e-01,
#          1.6251e-06, 5.1443e-06, 8.6745e-09, 1.4524e-13],
#         [1.3981e-20, 5.2830e-18, 9.3231e-13, 1.6642e-10, 5.1149e-07, 8.4404e-06,
#          2.3860e-05, 4.3997e-06, 9.9891e-01, 1.0545e-03],
#         [2.7516e-16, 4.0727e-14, 1.6449e-10, 7.7308e-08, 2.4891e-07, 6.6722e-07,
#          2.1021e-05, 2.4899e-06, 9.9994e-01, 3.5348e-05]],
#        grad_fn=<SelectBackward>)
# Epoch: 10.15, Train Loss: 0.00, Val Loss: 4.40, Train BLEU: 0.00, Val BLEU: 6.78, Minutes Elapsed: 656.58
# Sampling from val predictions...
# Source: 这种 人 不存 存在 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: it doesn &apos;t exist . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> and &apos;s &apos;t exist . <EOS> <EOS> <EOS> <EOS>
# Attention Weights: tensor([[0.9860, 0.0000, 0.0000, 0.0000, 0.0140, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0001, 0.0000, 0.0001, 0.9998, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9986, 0.0014, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.18, Train Loss: 0.00, Val Loss: 4.39, Train BLEU: 0.00, Val BLEU: 6.03, Minutes Elapsed: 658.80
# Sampling from val predictions...
# Source: 如果 我们 能 让 这种 材料 自我 修复 就 有
# Reference: if we can make this material <UNK> , then
# Model: <SOS> if if could do this ideas of , ,
# Attention Weights: tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0331, 0.9669, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.4102, 0.5898, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.9994, 0.0005, 0.0001, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9972, 0.0000, 0.0027,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6403, 0.0000, 0.3597,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.21, Train Loss: 0.00, Val Loss: 4.38, Train BLEU: 0.00, Val BLEU: 6.87, Minutes Elapsed: 661.02
# Sampling from val predictions...
# Source: 我 曾经 <UNK> 以为 只有 我 一个 个人 有 这样
# Reference: i was mistaken in thinking that i was unique
# Model: <SOS> i i had thought i , i had a
# Attention Weights: tensor([[0.0383, 0.0000, 0.0000, 0.0000, 0.0000, 0.9617, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0045, 0.9125, 0.0830, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0043, 0.9957, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0009, 0.9991, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.1762, 0.8238, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0003, 0.9997, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0002, 0.9998, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.24, Train Loss: 0.00, Val Loss: 4.41, Train BLEU: 0.00, Val BLEU: 6.56, Minutes Elapsed: 663.25
# Sampling from val predictions...
# Source: 谢谢 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: thank you . <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Model: <SOS> thank you . <EOS> you <EOS> <EOS> thank thank
# Attention Weights: tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.27, Train Loss: 0.00, Val Loss: 4.37, Train BLEU: 0.00, Val BLEU: 6.78, Minutes Elapsed: 665.48
# Sampling from val predictions...
# Source: 那些 大石 <UNK> 石板 比 搬运 石板 的 孩子 还要
# Reference: the big sheets of slate were heavier than the
# Model: <SOS> the those are are the , , to ,
# Attention Weights: tensor([[1.7831e-03, 4.1766e-23, 1.7049e-22, 1.1428e-18, 5.1637e-09, 9.9754e-01,
#          6.4442e-04, 1.2073e-06, 2.6316e-05, 1.5034e-06],
#         [1.0000e+00, 1.0077e-20, 1.9618e-19, 4.7813e-21, 6.9851e-17, 8.1669e-19,
#          1.3710e-23, 9.6377e-27, 3.5686e-28, 2.3869e-31],
#         [1.0000e+00, 1.0102e-14, 9.8878e-14, 8.9370e-18, 1.4950e-17, 9.4507e-22,
#          1.7651e-26, 2.1246e-30, 1.9382e-32, 8.7117e-34],
#         [9.2764e-07, 3.3885e-09, 5.8824e-05, 3.8119e-05, 9.9990e-01, 1.4004e-11,
#          2.0010e-18, 8.9483e-22, 6.6462e-22, 2.3504e-20],
#         [2.6399e-12, 4.2244e-16, 7.2847e-10, 2.7666e-08, 1.0000e+00, 5.5232e-11,
#          3.6910e-18, 8.6423e-22, 1.2221e-22, 7.7233e-23],
#         [2.7611e-13, 2.6083e-18, 8.8530e-13, 6.4638e-09, 1.0000e+00, 2.0358e-06,
#          3.7630e-11, 2.7141e-15, 3.0257e-15, 9.0613e-18],
#         [2.6793e-18, 1.2090e-18, 5.0201e-12, 1.1972e-07, 9.9995e-01, 5.2436e-05,
#          2.7546e-10, 1.7093e-11, 7.1288e-13, 6.6667e-14],
#         [4.5279e-18, 6.7825e-24, 8.6708e-17, 1.7571e-10, 1.0000e+00, 2.7276e-06,
#          6.6562e-10, 6.6574e-14, 3.8325e-13, 3.1065e-14],
#         [5.4655e-17, 1.4079e-19, 3.3361e-15, 6.9229e-09, 9.9900e-01, 9.9880e-04,
#          4.2175e-07, 6.0946e-12, 2.5788e-13, 7.8676e-13]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 10.30, Train Loss: 0.00, Val Loss: 4.39, Train BLEU: 0.00, Val BLEU: 6.75, Minutes Elapsed: 667.71
# Sampling from val predictions...
# Source: 上面 写道 当 你 读到 这 封信 时 我家 的
# Reference: it read , &quot; when you read this ,
# Model: <SOS> and the like &quot; you you look a the
# Attention Weights: tensor([[1.0000e+00, 2.0797e-15, 3.3742e-28, 4.0691e-33, 1.8732e-29, 4.0844e-12,
#          1.3657e-10, 2.9200e-11, 4.3382e-13, 7.9531e-08],
#         [1.0000e+00, 1.1721e-09, 2.3275e-24, 3.3779e-21, 1.2905e-29, 5.3098e-23,
#          1.7177e-22, 6.4960e-28, 8.3035e-28, 4.8796e-28],
#         [7.3111e-01, 2.6889e-01, 9.3531e-09, 9.9770e-11, 8.2536e-18, 2.1410e-18,
#          2.4021e-22, 1.5671e-27, 2.1295e-25, 2.7133e-30],
#         [1.3764e-11, 6.6243e-08, 8.5260e-01, 1.4740e-01, 3.2433e-11, 5.5651e-17,
#          5.9857e-15, 2.9395e-17, 3.4513e-18, 1.2758e-26],
#         [7.8646e-11, 8.6160e-07, 1.2786e-04, 9.9987e-01, 5.3586e-12, 7.6223e-12,
#          9.6790e-11, 3.0779e-13, 5.4288e-13, 3.0060e-23],
#         [2.8775e-16, 1.9438e-17, 1.5872e-11, 1.0000e+00, 4.7797e-09, 3.5046e-09,
#          5.8343e-14, 1.4673e-14, 1.2894e-13, 1.7334e-25],
#         [2.9103e-14, 2.1997e-14, 9.1188e-10, 1.0000e+00, 1.5026e-08, 3.6370e-08,
#          3.7301e-16, 2.8094e-17, 3.8221e-14, 1.5898e-26],
#         [7.3446e-12, 2.7760e-14, 2.1205e-12, 1.0000e+00, 1.4670e-07, 3.6614e-09,
#          1.4043e-11, 1.9027e-14, 3.2628e-11, 4.4513e-23],
#         [1.4545e-13, 5.5664e-14, 2.6299e-20, 6.5776e-16, 4.7354e-05, 9.9995e-01,
#          3.2034e-07, 1.4032e-14, 8.6699e-14, 1.4922e-19]],
#        grad_fn=<SelectBackward>)
#
# Epoch: 10.33, Train Loss: 0.00, Val Loss: 4.39, Train BLEU: 0.00, Val BLEU: 5.81, Minutes Elapsed: 669.93
# Sampling from val predictions...
# Source: 说 你 长大 后 想 当 模特 就 像 你
# Reference: saying that you want to be a model when
# Model: <SOS> you you you childhood born say , when when
# Attention Weights: tensor([[3.9128e-10, 1.5301e-35, 1.2958e-36, 3.1485e-35, 1.6567e-18, 4.2475e-16,
#          3.8880e-12, 3.3730e-05, 9.9997e-01, 1.0673e-08],
#         [8.8827e-01, 1.1173e-01, 6.6731e-20, 4.4283e-27, 3.2569e-17, 6.2217e-21,
#          3.8002e-26, 2.3371e-22, 9.5691e-19, 1.2595e-20],
#         [2.9987e-09, 1.0000e+00, 9.5868e-17, 9.4323e-27, 7.5979e-24, 7.5263e-28,
#          1.6253e-35, 4.4414e-36, 1.9549e-30, 1.1738e-28],
#         [5.0090e-17, 1.0000e+00, 2.4872e-17, 4.8931e-19, 2.5135e-19, 1.9990e-25,
#          1.4735e-31, 1.0748e-29, 2.2273e-26, 7.0866e-25],
#         [6.2358e-13, 9.9975e-01, 2.6135e-05, 2.1904e-04, 1.6731e-07, 2.2653e-15,
#          1.0276e-21, 1.0535e-17, 1.1700e-15, 2.0820e-14],
#         [7.4161e-15, 7.0199e-17, 3.0157e-02, 9.4606e-01, 2.2140e-02, 1.6423e-03,
#          4.0256e-08, 1.0422e-11, 7.1787e-14, 6.5873e-18],
#         [6.5217e-08, 1.6500e-12, 1.3558e-04, 1.9720e-01, 8.0182e-01, 8.4527e-04,
#          9.1050e-09, 1.3270e-10, 2.2740e-13, 4.0426e-14],
#         [4.9672e-17, 2.6648e-14, 4.2763e-10, 2.2750e-09, 1.6174e-05, 9.9998e-01,
#          8.9636e-07, 8.0394e-10, 8.0290e-13, 2.6752e-15],
#         [1.1441e-17, 1.1442e-18, 5.4903e-16, 5.4331e-12, 9.0050e-02, 9.0987e-01,
#          8.2947e-05, 7.2233e-09, 3.2241e-09, 1.2849e-10]],
#        grad_fn=<SelectBackward>)
# Epoch: 10.36, Train Loss: 0.00, Val Loss: 4.41, Train BLEU: 0.00, Val BLEU: 6.56, Minutes Elapsed: 672.16
# Sampling from val predictions...
# Source: 希望 不 像 中间 那 张 那么 怪 <EOS> <PAD>
# Reference: hopefully less awkward than that one in the middle
# Model: <SOS> you don don the . . <EOS> <EOS> .
# Attention Weights: tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0472, 0.3347, 0.6180, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0001, 0.7568, 0.2431, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.3267, 0.0000, 0.6733, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0847, 0.0000, 0.9153, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.9347, 0.0000, 0.0650, 0.0000, 0.0003,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.9539, 0.0006, 0.0455, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)
#
# Epoch: 10.39, Train Loss: 0.00, Val Loss: 4.37, Train BLEU: 0.00, Val BLEU: 6.59, Minutes Elapsed: 674.38
# Sampling from val predictions...
# Source: 这种 人 不存 存在 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Reference: it doesn &apos;t exist . <EOS> <PAD> <PAD> <PAD>
# Model: <SOS> there &apos;s not exist . <EOS> <EOS> <EOS> <EOS>
# Attention Weights: tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.9998, 0.0002, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0050, 0.9950, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9687, 0.0313, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.2873, 0.7127, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]], grad_fn=<SelectBackward>)

# %%
summarize_results(load_experiment_log())[['dt_created', 'num_epochs', 'learning_rate', 'clip_grad_max_norm', 'val_loss']].head()

# %%
plot_single_learning_curve(results)

# %%
# Epoch: 199.00, Train Loss: 0.32, Val Loss: 13.19, Train BLEU: 98.94, Val BLEU: 0.27
plot_single_learning_curve(results)

# %%
# with attention energies = v_broadcast.bmm(torch.tanh(self.attn(concat)).transpose(1, 2)) # switched order  
# Epoch: 199.00, Train Loss: 0.63, Val Loss: 12.82, Train BLEU: 92.05, Val BLEU: 0.38
plot_single_learning_curve(results)

# %%
for i, token in enumerate(vocab[SRC_LANG]['id2token']): 
    if i < 20: 
        print("{}: {}".format(i, token))

# %%
for i, token in enumerate(vocab[TARG_LANG]['id2token']): 
    if i < 20: 
        print("{}: {}".format(i, token))

# %%
import torch
x = torch.arange(0, 3*5*10).view(3, 5, 10)
print(x)
y = x[1:, :, :]
print(y)
z = y.view(-1, 10)
print(z)

# %%
t = torch.arange(0, 2*5).view(5, 2)
print(t)
u = t.contiguous().view(-1)
print(u)
v = t.permute(1, 0)
print(v)
w = v.contiguous().view(-1)
print(w)

# %%
a = torch.arange(0, 2*1*300)
print(a)
b = a.view(-1, 1, 300)
print(b.size())

# %%
for i, (src_idxs, targ_idxs, src_lens, targ_lens) in enumerate(loaders_full['train']):
#     print(i)
#     print(src_idxs.size())
#     print(src_idxs)
#     print(src_lens)
#     print(targ_idxs.size())
#     print(targ_idxs)
#     print(targ_lens)
    id2token = vocab[SRC_LANG]['id2token']
    test_tensor = src_idxs
    list_of_lists = test_tensor.numpy().astype(int).tolist()
    to_token = lambda l: ' '.join([id2token[idx] for idx in l])
    list_of_lists_tokens = [to_token(l) for l in list_of_lists] 
    break

# %%
#attn.data.masked_fill_(self.mask, -float('inf'))
test_tensor.

test_tensor.data.masked_fill_(test_tensor == 2, float('inf'))
